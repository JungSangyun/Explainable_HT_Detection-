# %% [markdown]
# # Breaking Hardware AES on CW305 FPGA

# %% [markdown]
# This tutorial relies on previous knowledge from the SCA101 course notebooks (in `../courses/sca101/`); make sure you go through these first to understand how a CPA attack works.
#
# In this notebook, we'll apply knowledge from sca101 to break a hardware AES implementation on the CW305 Artix FPGA.
#
# Some out-of-date background on the target FPGA project is can be found here: [Tutorial CW305-1 Building a Project](http://wiki.newae.com/Tutorial_CW305-1_Building_a_Project) (ignore the "capture setup" section, which uses the obsolete ChipWhisperer GUI; this notebook shows all you need to know about capture setup on the CW305 with Jupyter).

# %% [markdown]
# ## Background Theory
# During this tutorial, we'll be working with a hardware AES implementation. This type of attack can be much more difficult than a software AES attack. In the software AES attacks, we needed hundreds or thousands of clock cycles to capture the algorithm's full execution. In contrast, a hardware AES implementation may have a variety of speeds. Depending on the performance of the hardware, a whole spectrum of execution speeds can be achieved by executing many operations in a single clock cycle. It is theoretically possible to execute the entire AES encryption in a single cycle, given enough hardware space and provided that the clock is not too fast. Most hardware accelerators are designed to complete one round or one large part of a round in a single cycle.
#
# This fast execution may cause problems with a regular CPA attack. In software, we found that it was easy to search for the outputs of the s-boxes because these values would need to be loaded from memory onto a high-capacitance data bus. This is not necessarily true on an FPGA, where the output of the s-boxes may be directly fed into the next stage of the algorithm. In general, we may need some more knowledge of the hardware implementation to successfully complete an attack.
#
# In our case, let's suppose that every round of AES is completed in a single clock cycle. Recall the execution of AES:
#
# <img src="img/aes_operations.png" width="250">
#
# Here, every blue block is executed in one clock cycle. This means that an excellent candidate for a CPA attack is the difference between the input and output of the final round. It is likely that this state is stored in a port that is updated every round, so we expect that the Hamming distance between the round input and output is the most important factor on the power consumption. Also, the last round is the easiest to attack because it has no MixColumns operation. We'll use this Hamming distance as the target in our CPA attack.

# %% [markdown]
# ## Capture Notes
#
# Most of the capture settings used below are similar to the standard ChipWhisperer scope settings. However, there are a couple of interesting points:
#
# - We're only capturing 129 samples (the minimum allowed), and the encryption is completed in less than 60 samples with an x4 ADC clock. This makes sense - as we mentioned above, our AES implementation is computing each round in a single clock cycle.
# - We're using EXTCLK x4 for our ADC clock. This means that the FPGA is outputting a clock signal, and we aren't driving it.
#
# Other than these, the last interesting setting is the number of traces. By default, the capture software is ready to capture 5000 traces - many more than were required for software AES! It is difficult for us to measure the small power spikes from the Hamming distance on the last round: these signals are dwarfed by noise and the other operations on the chip. To deal with this small signal level, we need to capture many more traces.

# %% [markdown]
# ## Capture Setup

# %% [markdown]
# Setup is somewhat similar to other targets, except that we are using an external clock (driven from the FPGA). We'll also do the rest of the setup manually:

# %%
FPGA_ID='100t' # change if not using K100t CW305

# %%
Trojan_ID = 'T300'

# %%
import chipwhisperer as cw
scope = cw.scope()
scope.gain.db = 25
scope.adc.samples = 600
scope.adc.offset = 0
scope.adc.basic_mode = "rising_edge"
scope.trigger.triggers = "tio4"
scope.io.tio1 = "serial_rx"
scope.io.tio2 = "serial_tx"
scope.io.hs2 = "disabled"

# %%
bsfile = r"./T300.bit"

# %% [markdown]
# Before setting the ADC clock, we connect to the CW305 board. Here we'll need to specify our bitstream file to load as well as the usual scope and target_type arguments.
#
# Pick the correct bitfile for your CW305 board (e.g. either '35t' or '100t'). By setting `force=False`, the bitfile will only be programmed if the FPGA is uninitialized (e.g. after powering up). Change to `force=True` to always program the FPGA (e.g. if you have generated a new bitfile).

# %%
#target = cw.target(scope, cw.targets.CW305, fpga_id='35t', force=False)
target = cw.target(scope, cw.targets.CW305, fpga_id=FPGA_ID, force=True, bsfile=bsfile)
# Out:
# (ChipWhisperer Target WARNING|File CW305.py:591) Using default Verilog defines (C:\Users\j2217\ChipWhisperer\chipwhisperer\software\chipwhisperer/hardware/firmware/cw305/cw305_aes_defines.v); if this is not what you want, provide them via the defines_files argument

# %% [markdown]
# Next we set all the PLLs. We enable CW305's PLL1; this clock will feed both the target and the CW ADC. As explained [here](http://wiki.newae.com/Tutorial_CW305-1_Building_a_Project#Capture_Setup), **make sure the DIP switches on the CW305 board are set as follows**:
# - J16 = 0
# - K16 = 1

# %%
target.vccint_set(1.0)
# we only need PLL1:
target.pll.pll_enable_set(True)
target.pll.pll_outenable_set(False, 0)
target.pll.pll_outenable_set(True, 1)
target.pll.pll_outenable_set(False, 2)

# run at 10 MHz:
target.pll.pll_outfreq_set(10E6, 1)

# 1ms is plenty of idling time
target.clkusbautooff = True
target.clksleeptime = 1

# %% [markdown]
# CW-Husky requires a different setup when the ADC clock is driven by the target:

# %%
if scope._is_husky:
    scope.clock.clkgen_freq = 10e6
    scope.clock.clkgen_src = 'extclk'
    scope.clock.adc_mul = 8
    # if the target PLL frequency is changed, the above must also be changed accordingly
else:
    scope.clock.adc_src = "extclk_x4"

# %% [markdown]
# Ensure the ADC clock is locked:

# %%
import time
for i in range(5):
    scope.clock.reset_adc()
    time.sleep(1)
    if scope.clock.adc_locked:
        break 
assert (scope.clock.adc_locked), "ADC failed to lock"

# %% [markdown]
# Occasionally the ADC will fail to lock on the first try; when that happens, the above assertion will fail (and on the CW-Lite, the red LED will be on). Simply re-running the above cell again should fix things.

# %% [markdown]
# ## Trace Capture
# Below is the capture loop. The main body of the loop loads some new plaintext, arms the scope, sends the key and plaintext, then finally records and appends our new trace to the `traces[]` list.
#
# Because we're capturing 5000 traces, this takes a bit longer than the attacks against software AES implementations.
#
# Note that the encryption result is read from the target and compared to the expected results, as a sanity check.

# %%
project_file = "./"
project = cw.create_project(project_file, overwrite=True)

# %%
from tqdm.notebook import trange
import numpy as np
import time
from Crypto.Cipher import AES
import random
import time
ktp = cw.ktp.Basic()



traces = []
textin = []
keys = []
N = 20000  # Number of traces

# initialize cipher to verify DUT result:
key, text = ktp.next()
cipher = AES.new(bytes(key), AES.MODE_ECB)
testkey = [[]]
for i in trange(N, desc='Capturing traces'):
    # run aux stuff that should come before trace here
    testkey = []
    text = []
    key, text = ktp.next()  # manual creation of a key, text pair can be substituted here
    
    text = [0xff] * 16
    for r in range(16):
        key[r] = random.randint(0, 255)
    print(key)
    cipher = AES.new(bytes(key), AES.MODE_ECB)


    textin.append(text)
    keys.append(key)
    
    ret = cw.capture_trace(scope, target, text, key)
    if not ret:
        print("Failed capture")
        continue
    time.sleep(0.2)
    assert (list(ret.textout) == list(cipher.encrypt(bytes(text)))), "Incorrect encryption result!\nGot {}\nExp {}\n".format(ret.textout, list(text))
    
    traces.append(ret.wave)
    project.traces.append(ret)
# Out:
# Capturing traces:   0%|          | 0/20000 [00:00<?, ?it/s]
# CWbytearray(b'4f 65 07 8c e3 a1 1d 32 c5 82 ad f6 90 cc e8 01')
# CWbytearray(b'e6 be fc 1f 58 cd e9 3b 63 60 cd 80 93 76 59 1e')
# CWbytearray(b'88 cb d4 c7 41 79 84 10 a5 13 f5 ba 61 05 20 15')
# CWbytearray(b'a5 b5 36 1a 94 10 0b a8 5b 2a 67 3c cc a6 72 37')
# CWbytearray(b'2d dd af bf 45 19 9c 6c d9 d4 a2 ba ce 0a e6 5d')
# CWbytearray(b'3d 45 f5 d7 60 b8 d3 e5 99 eb 60 a9 aa 28 8e 64')
# CWbytearray(b'56 15 13 e7 3e 0e 5e a5 9a 9b 72 fc 9d 3a bb c4')
# CWbytearray(b'ad a5 f4 b4 ff f2 e1 49 de 66 5c cb 30 a1 c3 7c')
# CWbytearray(b'4f 96 c2 9a 82 26 10 39 1e 86 9c b5 b2 d5 4a a6')
# CWbytearray(b'78 8b b6 6d 80 a7 de 59 c8 2a 29 d3 fc 08 e6 57')
# CWbytearray(b'69 04 09 87 90 5a 03 a7 d1 b9 27 40 92 b5 20 c5')
# CWbytearray(b'b5 6c 82 24 e1 9b 17 ad 35 a3 a8 57 db 97 3d 8f')
# CWbytearray(b'6f 6d 36 05 0c cd 76 ca a9 2a 09 aa 2b 02 93 41')
# CWbytearray(b'47 9d 2a fc 20 f7 c9 f3 b9 56 4f 06 e6 ce e8 40')
# CWbytearray(b'f1 9f 1e 72 37 f4 c7 54 eb dd db d3 b1 73 31 33')
# CWbytearray(b'f7 58 5b 8b 6c ec 09 00 0c 52 70 a4 ef 20 fb ad')
# CWbytearray(b'9f dc 09 02 47 ca e6 1d 34 b5 7c fd c7 27 9f df')
# CWbytearray(b'f7 40 37 0d 14 d0 cf 0b 1d b7 36 a2 65 6c ad c8')
# CWbytearray(b'a7 80 79 e2 be bf e2 fd dc ad 70 0c 89 e3 79 53')
# CWbytearray(b'6d 44 f3 bf e2 95 a2 90 9c 98 68 82 f4 72 4c 22')
# CWbytearray(b'46 1e aa a0 86 a4 19 c2 d4 d7 60 03 29 52 dd da')
# CWbytearray(b'b4 f2 43 15 08 7a 7c 6d 0e 48 3b 59 97 c9 d3 3e')
# CWbytearray(b'c9 35 12 25 0f 85 3e ab 29 12 85 ff 07 cd fd 2c')
# CWbytearray(b'0e 2c 8e d6 5e c2 9c ae 07 b9 bf 24 0f 8f e3 50')
# CWbytearray(b'30 3d e9 56 9b f4 68 22 11 2f 61 72 5e 91 03 23')
# CWbytearray(b'cf 1a 58 14 1e 86 0c b3 8c 93 c4 93 2f d7 b1 da')
# CWbytearray(b'c8 7f 15 a3 a6 67 a6 27 97 cc 5f 72 ba b2 39 3a')
# CWbytearray(b'53 2e 62 19 19 e4 84 f2 08 a7 99 be 5a 65 98 4b')
# CWbytearray(b'18 2b fc f2 41 4a a1 39 a4 9d 1b 9b 17 ad e0 80')
# CWbytearray(b'9d 20 0f 56 f4 a8 97 80 fd 3d af dd 67 f8 c2 7a')
# CWbytearray(b'6a 8a 5b 99 21 43 f4 55 6d 48 5b 06 19 7d 02 fb')
# CWbytearray(b'41 ce 7f 72 21 cf ae 3c 43 fe 14 6b de bb c9 fd')
# CWbytearray(b'45 f5 6b 1c 9e 03 c4 99 47 10 58 be 33 26 8a 4f')
# CWbytearray(b'0b eb 89 a2 1e 6d 0c c1 54 3b ad 53 15 45 b6 1c')
# CWbytearray(b'c2 18 f6 97 52 e3 c4 22 f7 f0 b6 35 c3 cd 0a f9')
# CWbytearray(b'22 cf 2c b1 fe 05 94 08 a9 29 d5 ac 40 2a 29 e2')
# CWbytearray(b'be 4a 5d 42 ca d0 24 c6 55 59 67 ed fa f4 04 8c')
# CWbytearray(b'85 84 ff fc 39 42 4f bb a6 9f 74 48 d9 d3 bf f1')
# CWbytearray(b'2d f4 6c 69 9f f7 97 0c ce e5 a9 ed e9 c2 5e 8c')
# CWbytearray(b'20 e6 b9 8f f1 ca 61 7f b8 f0 4b 33 fc c4 85 42')
# CWbytearray(b'0d d2 15 46 d9 b8 4e 8c 06 9d b2 11 51 90 27 12')
# CWbytearray(b'd0 23 ad 2b ca b7 31 57 13 3e 56 b4 2e af 31 37')
# CWbytearray(b'37 16 81 4d fa 69 2f 3a cf f1 61 4d 7e 1e 54 cb')
# CWbytearray(b'f1 db 76 2f 85 1c 5a 45 6f 27 fd 62 1d 73 20 9a')
# CWbytearray(b'36 6e 3c a6 5d 83 4d f8 28 1f 73 ac 24 d5 f3 8a')
# CWbytearray(b'25 2e 8b 73 f1 61 0d 48 c0 54 13 50 37 cd 77 c3')
# CWbytearray(b'99 8d 20 82 5b 05 37 9a 43 ad 1d 37 e2 2c 5f d9')
# CWbytearray(b'14 3a 16 58 8f db 05 09 bb f8 9c f7 e9 06 5d df')
# CWbytearray(b'd3 d9 f5 66 a6 07 7c 4e bd f9 d9 78 c5 30 ad f2')
# CWbytearray(b'9b da 78 a7 c2 4b f5 db d7 c2 c3 5e 92 16 ca 3d')
# CWbytearray(b'15 82 f8 27 a4 db b0 db 0d c0 d7 9c 83 72 df 64')
# CWbytearray(b'a6 24 65 70 56 a6 1d 08 3c 14 0e 5d 55 6d 2f 6f')
# CWbytearray(b'fe 7b 5c df e8 ac 77 1c eb f1 2b 8d 72 d1 a8 01')
# CWbytearray(b'72 7c 62 e2 79 b1 b3 de a9 1f ce 80 44 66 8b 4c')
# CWbytearray(b'23 7d 19 e2 b0 ff cf 72 8b 55 78 c5 19 08 27 39')
# CWbytearray(b'08 54 19 22 e1 f0 53 2a b5 71 ba 63 e1 22 1a ce')
# CWbytearray(b'3a 53 f8 f5 95 3d 46 41 fa c7 7c f8 2a 6f 38 84')
# CWbytearray(b'8f 00 5b a6 6b 0e f2 01 13 bc b8 33 6c 05 76 b8')
# CWbytearray(b'70 4f 24 0d 0d 94 fe ce 19 14 5f 5e d8 ee ee 54')
# CWbytearray(b'ae cc fb c2 e7 68 5f 40 80 62 32 35 d7 9a f6 c0')
# CWbytearray(b'e4 6a 5f bc f7 97 03 6f 72 d2 1e f5 49 c6 bb e5')
# CWbytearray(b'4d 2e 78 7e 53 86 f9 d9 70 84 8c 05 57 0d 0a aa')
# CWbytearray(b'e6 7f e8 ba ea 54 9d 55 f1 7f 4e 4f 3a 19 43 8c')
# CWbytearray(b'cb fd c6 66 d1 14 16 0d 48 21 fd e9 92 0f cb 10')
# CWbytearray(b'3b 4b 0b 74 d0 c2 e8 27 93 50 83 52 0a 7e d5 20')
# CWbytearray(b'75 ec ae c1 56 77 ef 2d 35 da ca 6c cb 27 22 b2')
# CWbytearray(b'c2 10 4c 3d 13 5a a7 48 26 a0 51 aa ac a9 f5 e9')
# CWbytearray(b'78 81 52 58 32 c6 50 66 df fc e9 0a 6c bd 8c fa')
# CWbytearray(b'ff 87 9a cf ca 64 66 50 c4 4a c9 5b 1f 5f 29 3e')
# CWbytearray(b'c8 3e 96 52 b5 80 90 09 35 e6 99 22 74 75 0d eb')
# CWbytearray(b'20 e2 b6 c8 f7 90 99 24 cf 28 48 db a8 d7 58 98')
# CWbytearray(b'03 0d 39 78 50 24 43 23 db b5 bd a1 88 69 3f f3')
# CWbytearray(b'c3 75 78 5c be 18 c1 ee 12 0f a5 fb 52 26 94 9b')
# CWbytearray(b'a1 c4 9d b3 17 c3 c5 2c ce ad 0d fb 77 e8 6d d1')
# CWbytearray(b'6b ca a3 85 29 62 f8 d5 c5 e8 f2 0e 90 6e 9b 4e')
# CWbytearray(b'6e cb a3 4b 4e 6e 47 fa 1e 5a dc 23 17 82 b6 0a')
# CWbytearray(b'8c 21 c6 26 21 ac 49 b0 23 4e 81 00 66 a4 ba 05')
# CWbytearray(b'b3 a6 b8 54 ea eb b8 03 67 5e 48 25 2e 1b dc 2e')
# CWbytearray(b'f5 6d 80 ce c8 e0 19 2b cb 3d 32 f1 f4 11 65 b9')
# CWbytearray(b'28 27 54 7e 13 4a 1f 77 7b be 76 8c f8 6b 6f d6')
# CWbytearray(b'a1 62 5c bc ce 5b bb 13 6b e2 a6 d7 ef aa e0 56')
# CWbytearray(b'93 50 2f a7 63 2c 2a dd f8 e2 74 e4 b6 ab 43 53')
# CWbytearray(b'41 a8 5f 0f f7 44 68 eb 46 48 df 83 03 c5 cb 2b')
# CWbytearray(b'79 9a 53 36 e6 2a a8 b9 d2 40 51 56 69 f4 40 1e')
# CWbytearray(b'43 e9 07 b7 66 d8 ce 88 ce 31 de 23 0c 2f c4 11')
# CWbytearray(b'f1 33 46 53 b4 13 4b b5 c1 b9 42 d1 6a 7e 24 39')
# CWbytearray(b'c2 02 2e 70 68 c6 fb 3c 63 26 b8 c9 ed d5 bf d4')
# CWbytearray(b'57 20 d5 34 73 ac 45 9e f3 c8 50 f5 12 ad bb 9e')
# CWbytearray(b'5d 69 a8 74 fa ad 5d 8f b2 7f 75 5b bc e7 2c f7')
# CWbytearray(b'6a 2f d9 a4 f7 36 78 6d fa be 2e 2b ca ee f2 ef')
# CWbytearray(b'4f a9 23 c1 4b df cd a2 88 ad c1 ea c2 59 04 5d')
# CWbytearray(b'4d 70 01 cb 90 50 29 8f e7 44 3c 55 10 3d a6 d7')
# CWbytearray(b'24 1f cb 49 f5 c8 3f 84 1c 3c 79 58 15 3b 75 90')
# CWbytearray(b'aa 31 b3 bb 1a 14 3b b6 99 44 29 4f 24 b0 e5 c1')
# CWbytearray(b'5b 69 7a 34 b4 3b 4e 47 82 31 a5 2b ee b0 f4 39')
# CWbytearray(b'b0 30 fd 76 7a eb 34 6d c9 f0 63 0d 00 66 73 b8')
# CWbytearray(b'6c 58 32 30 52 a6 45 8a 5f b5 f4 21 c4 a8 52 92')
# CWbytearray(b'0a 4a cf c5 08 94 ec 27 7e f5 b0 d7 13 d9 94 58')
# CWbytearray(b'0c 44 e4 cf fc b9 4e a3 bf fe 57 59 53 e1 fd 01')
# CWbytearray(b'd9 84 f9 a9 5a 54 0a 3e 4b 38 65 7a 17 fa 53 49')
# CWbytearray(b'71 e6 b6 61 54 0f 92 c6 c1 61 61 5d fe d8 20 3b')
# CWbytearray(b'd3 6f ce 9b b3 a2 a1 b0 df 6f 18 7c ed f7 37 74')
# CWbytearray(b'41 32 ad ed e5 8a e6 6e 56 25 35 3c 3f 5d 30 e4')
# CWbytearray(b'f2 eb b3 f9 ae ac 98 8e bb 13 b6 ad d7 5b 7c ae')
# CWbytearray(b'08 a8 01 0f 72 ac cb 65 b8 99 0b 3e 8c 5f 75 40')
# CWbytearray(b'c8 1d f6 f1 4c 9e 49 8d d8 92 77 88 63 6a 5c 37')
# CWbytearray(b'5a e4 9c 45 93 13 4a cb da 07 9a 8e b5 c9 b7 4d')
# CWbytearray(b'a1 f3 b0 3e 40 86 0f ba 3a 09 5d a4 e9 a0 be 94')
# CWbytearray(b'31 5e a1 b2 b6 7a 17 72 19 ed e9 2c 7a fc a7 55')
# CWbytearray(b'60 4a 33 86 1e 1a ee 4f 3a 5e c7 93 93 cd 65 dd')
# CWbytearray(b'91 aa 48 f5 7b eb 6e 84 72 0d 4a c0 bd bb b1 6e')
# CWbytearray(b'11 87 d1 bd 5b 70 69 52 df 26 6a af 29 3e 53 6e')
# CWbytearray(b'82 59 3a 53 c4 ce 4b 05 d8 d3 99 d1 13 6d d8 2e')
# CWbytearray(b'42 3d 3c b0 e6 10 72 3a 11 67 f1 b3 4e 6d 12 b8')
# CWbytearray(b'6f f5 d5 73 75 30 a8 7e 7a ba 15 bf 5d 22 a4 bd')
# CWbytearray(b'81 88 2c 92 58 98 ae 08 d9 7e 10 a8 6c 9a ad f0')
# CWbytearray(b'fb 79 83 15 0a 74 39 1a a8 23 3b 49 9f 9e ed 48')
# CWbytearray(b'd7 50 ea b6 73 f5 28 be e3 1e af 1a ba 4f 18 aa')
# CWbytearray(b'2c c2 48 70 21 58 40 39 14 4d 3d 4a 0f 93 bb 22')
# CWbytearray(b'e7 90 80 c8 4f 6c 80 c4 26 05 b5 31 39 7d e6 3d')
# CWbytearray(b'fc 9e 24 43 23 78 7f 0d ab 7b 9a 66 5d 61 e1 7c')
# CWbytearray(b'6d 89 86 c1 af 78 88 d1 80 24 6c 9c f5 55 ac 88')
# CWbytearray(b'5a 34 6f e4 2b fc 36 6c a5 4b f5 ab c9 6a 68 3b')
# CWbytearray(b'13 09 a5 53 43 d5 66 af 8b a7 42 9b 10 67 61 f4')
# CWbytearray(b'fa 6d ab 8b 0a 6f 97 4d 33 0f 3e 55 86 5d 96 69')
# CWbytearray(b'0c d6 2f 10 37 02 77 6a 04 b1 77 46 0b b3 16 7d')
# CWbytearray(b'df b7 72 dc 7d 3d 86 7b 52 8b 30 17 d7 fb fc cf')
# CWbytearray(b'71 6f ba 7b 47 a3 cb 01 9e fa 6e 54 99 43 5c 57')
# CWbytearray(b'9c 82 16 00 e4 f0 c2 8a 0d be b2 e3 77 e0 61 67')
# CWbytearray(b'77 49 aa af 0e e2 24 b3 6e c4 6f 3e 06 d6 1d 7c')
# CWbytearray(b'62 0a c0 04 84 6a f3 7d 57 54 f8 94 31 cb 36 32')
# CWbytearray(b'59 da 7d 0c 5d a3 b0 8d 5e e6 a2 ae a0 1a 1a e4')
# CWbytearray(b'd9 32 be 75 03 7b f1 27 24 33 0b 1c 4a b7 dc 5c')
# CWbytearray(b'3d 76 46 86 6f 3e 15 f9 ae f4 73 03 a2 00 55 a4')
# CWbytearray(b'cf 1e 5b ef 9f b1 bc 65 54 2b f7 40 1e 56 50 59')
# CWbytearray(b'cc da 4e 3e 28 92 db af ca 15 c8 b5 42 fe 38 40')
# CWbytearray(b'f5 bb 36 43 f0 77 e0 54 ac 0e fb be f5 b6 18 54')
# CWbytearray(b'b6 9e 11 25 17 b5 3e 09 1b 9e c1 0e bb 88 48 44')
# CWbytearray(b'e8 8d bc 13 cf 3c e5 03 26 f1 72 15 17 6e 84 1f')
# CWbytearray(b'60 d3 97 95 5d 81 d2 aa 33 cb 72 48 7e 7d 04 93')
# CWbytearray(b'75 8e 7a f5 84 9a 9a 36 ba 5f e4 72 3d 52 ba 70')
# CWbytearray(b'23 a4 16 e4 60 83 db d8 c3 11 cc e9 4c a0 10 9e')
# CWbytearray(b'45 99 0d b2 3e 69 09 57 58 9c 88 91 53 fa 33 fd')
# CWbytearray(b'8f de 6b 49 27 81 36 5c 20 48 7d 11 b6 16 34 52')
# CWbytearray(b'06 f1 c3 7e e7 f2 fd d0 04 1a 4c 96 be 4d c5 a3')
# CWbytearray(b'98 e3 04 1b e2 6e 47 82 36 ea da d5 73 72 fa 8f')
# CWbytearray(b'e3 ec fe 66 11 27 a1 03 0c 18 66 e9 27 5f b1 46')
# CWbytearray(b'89 97 b8 15 35 78 60 e2 e1 05 5f eb ed 66 e2 7d')
# CWbytearray(b'd5 95 9f 37 f4 90 bb 59 15 66 8c c7 ac cf 34 fd')
# CWbytearray(b'14 2f d0 c1 3a d9 70 d8 26 c9 e3 33 07 27 9c 40')
# CWbytearray(b'f1 65 2e 22 91 32 c6 66 2d ca d5 77 01 64 0a 1c')
# CWbytearray(b'54 34 07 7a f2 a0 32 12 c4 3f 93 0c dd 45 af 75')
# CWbytearray(b'e1 76 35 55 6a 14 bd 17 25 00 77 a9 05 6f f0 9f')
# CWbytearray(b'f2 2a da 74 a9 86 a6 a6 43 5b b2 18 a9 13 8b e5')
# CWbytearray(b'63 47 94 c8 c8 40 3c 72 53 2b aa 0c e2 b2 fe b3')
# CWbytearray(b'5b a3 19 74 fb ab 02 f7 32 76 25 45 03 6d 15 63')
# CWbytearray(b'74 72 01 ea e0 40 cb c1 46 ca f8 1a b4 a3 8c 6a')
# CWbytearray(b'1d e7 c8 e0 f4 83 9c 6d 10 1e 69 42 47 c3 29 c3')
# CWbytearray(b'27 14 70 85 98 52 69 3e 32 c6 d7 30 4f cd 6c fe')
# CWbytearray(b'8e a6 75 2e 6d 55 d5 ca dd 35 f2 15 a2 97 43 61')
# CWbytearray(b'50 92 f7 88 41 f9 2f c3 1e 94 f0 16 b5 c0 9c b5')
# CWbytearray(b'cb 5c 78 66 f2 88 df 63 14 af 76 52 fa d1 d3 9c')
# CWbytearray(b'29 87 d7 af 7b 3e 04 91 a4 2d 62 79 59 a8 6c a4')
# CWbytearray(b'c6 ac 88 dd 8e 9b 2c 8b 2f 2b 11 3d ef 7d dd c3')
# CWbytearray(b'33 4f 96 71 c8 20 53 6a 08 db 70 67 07 a9 a6 e1')
# CWbytearray(b'71 35 21 40 63 88 96 86 cf 55 37 39 3f f3 af 84')
# CWbytearray(b'f2 0e a4 66 2c 0b ee a1 c4 92 eb 98 ea a4 92 c6')
# CWbytearray(b'1f 61 30 f5 ea f4 4e 36 02 a7 fd 0f 7d 2f cb 1b')
# CWbytearray(b'80 03 36 d0 4a 29 71 c9 d0 6f f4 cc 4f b1 a1 40')
# CWbytearray(b'6a 85 24 77 bb 9f 8b 4f 1a a0 25 04 fc 87 40 bf')
# CWbytearray(b'73 6e a5 47 9e 17 a4 95 74 c5 06 bb 22 1d ab f9')
# CWbytearray(b'a2 bf 4c 24 d0 47 e8 17 8e 91 5f f3 83 4d 39 53')
# CWbytearray(b'eb c1 b0 44 50 b1 4d c4 31 03 6b cb 15 d4 7e 1f')
# CWbytearray(b'b0 65 34 d2 73 82 9c 5e 57 2b ed 18 fc 41 18 03')
# CWbytearray(b'ac 3f 43 09 12 fb 12 33 02 69 56 90 c2 21 fa 88')
# CWbytearray(b'7f 70 5f 32 65 2b 42 5b 2b ec 53 b7 04 36 66 b5')
# CWbytearray(b'4c 29 bb fa 6d 24 46 cd 11 44 6a ed 68 ad 38 58')
# CWbytearray(b'a6 a6 1e df 39 1f 22 62 a2 35 dc 31 8e 50 a1 72')
# CWbytearray(b'59 63 2a 9a f3 dd f0 56 a1 f9 db 59 d8 b7 dd 12')
# CWbytearray(b'd8 e0 24 5c cb fc 62 22 c3 57 e8 f7 b2 a8 9e 3b')
# CWbytearray(b'38 04 e1 68 80 fb 34 99 ed 05 24 93 53 e4 37 bd')
# CWbytearray(b'19 56 e3 66 d3 ed 86 1c 52 3b c3 b5 cc c2 6c f4')
# CWbytearray(b'91 30 2b c6 21 dc 20 87 df 55 4c 3f 23 b1 c4 fc')
# CWbytearray(b'32 59 0e fd 65 c8 d1 00 81 d4 51 38 26 0b 59 ed')
# CWbytearray(b'a4 9f e2 f1 fe 6a 2c d6 cb 83 ff a2 5b b9 20 ba')
# CWbytearray(b'dc 4a b8 be 35 e0 1a 50 2e 1c 0c 7d de 4c 01 e8')
# CWbytearray(b'c0 81 2e 45 81 ff a2 48 fe 38 13 c1 97 70 28 d5')
# CWbytearray(b'4e 35 e2 f4 c5 b1 85 2e 3c 20 bf 6e d0 69 56 f9')
# CWbytearray(b'3c 48 e3 24 25 25 34 07 70 06 3a b9 a5 34 6b 39')
# CWbytearray(b'4e ec f3 b2 39 62 92 23 0d 32 30 bf 47 74 4f 8f')
# CWbytearray(b'21 04 11 34 99 a6 ee 2e 63 cf cd 97 5d 19 3b 96')
# CWbytearray(b'c7 1f ca b5 f8 4a 6b b0 7f ec 58 a1 21 aa ee ea')
# CWbytearray(b'5d da d6 ea df 28 a5 46 e8 a3 4e b8 bb 96 da e9')
# CWbytearray(b'49 71 d2 ac 43 a1 f3 3a 28 cc 72 04 bd 0a 9a 98')
# CWbytearray(b'b3 9b 6a 9f 6d 07 64 ff be 06 07 f8 e5 1e 67 71')
# CWbytearray(b'ee 67 70 21 41 e5 c1 a3 6c 8b 94 ed b5 e6 d5 01')
# CWbytearray(b'5e 8a 4a 85 ab 4a 51 6b f2 9d ab 6f 5d 60 d7 dd')
# CWbytearray(b'41 2c d6 6b 18 ee 10 6c c6 40 3d fb 68 76 4c 0c')
# CWbytearray(b'e1 73 da 21 33 f5 e6 fa e5 27 df e9 55 1d 3a d2')
# CWbytearray(b'4e 99 57 87 eb 75 8e dc ba 04 89 20 85 85 bd f4')
# CWbytearray(b'89 54 c1 53 86 fe 67 b6 43 fc 6a 5c 73 e7 28 65')
# CWbytearray(b'03 f2 f5 c9 54 5f 91 fe 69 97 b3 94 2e 57 00 a0')
# CWbytearray(b'91 7b 6c c6 9a cf 1b 5c ca 24 d3 65 51 eb 2a f8')
# CWbytearray(b'a6 01 ae 52 5c d1 5a 55 00 dc d6 b5 a3 b1 db 79')
# CWbytearray(b'7d 38 46 53 87 06 a8 ee 3e 79 b4 d4 fc 7b 74 b3')
# CWbytearray(b'7c d0 15 8e 4c 01 04 50 6e 6d 36 1c a0 d1 29 99')
# CWbytearray(b'3b 13 61 d3 14 f3 93 4c 6f cf 4c 90 56 a2 02 a4')
# CWbytearray(b'4a d3 01 0b 02 79 6c 95 b8 36 c5 37 c5 df 72 3f')
# CWbytearray(b'12 ac 84 44 a3 19 90 f3 c1 13 e3 97 c0 02 df ef')
# CWbytearray(b'a5 76 c9 7a a4 e4 35 25 cc 61 6f 34 07 f0 f4 10')
# CWbytearray(b'19 54 3e 1d a3 69 4f 24 07 f4 6f c5 44 31 24 fd')
# CWbytearray(b'af ef d6 5a 6c 83 ba ea d3 cd 23 7f c7 85 c9 b1')
# CWbytearray(b'68 0c 37 41 a1 c2 1b 0c 55 fe eb a6 05 e6 c0 9b')
# CWbytearray(b'87 fb e1 fa 3e e2 d4 8f 13 be 51 7f c0 83 29 a1')
# CWbytearray(b'96 21 71 06 80 e1 54 32 9b b1 ae 6d 56 b4 80 56')
# CWbytearray(b'18 d6 75 e6 3b de 3b f6 cc b6 ed 4f 77 49 d0 91')
# CWbytearray(b'72 b8 6b 7d ab 0e 69 a3 dc 43 90 3c 28 04 08 06')
# CWbytearray(b'79 44 18 76 4d 8f 46 54 c3 62 a9 86 ab 26 48 1a')
# CWbytearray(b'90 46 c6 74 7f c2 14 8d 97 11 b1 61 78 ac 82 2f')
# CWbytearray(b'8b e4 46 9b 60 ff 37 bd 2e 49 00 10 3e 8c 04 5e')
# CWbytearray(b'fe 12 0a ad 81 9e 35 43 a5 cc cd b1 25 d1 3b e2')
# CWbytearray(b'5c 29 11 14 01 69 09 d3 e3 47 63 0e 4f d1 f2 42')
# CWbytearray(b'ea f0 a8 66 df 9f aa f5 89 f2 a7 0b a9 84 ad b5')
# CWbytearray(b'87 5c 4f b2 e5 84 6c eb 41 2c 49 ad 17 7c d6 86')
# CWbytearray(b'50 dd b9 8d e4 5a 94 3c de 81 50 f2 25 3c 99 9a')
# CWbytearray(b'd0 cf 6e d5 79 00 f4 03 4d 80 03 76 2a 0a 40 07')
# CWbytearray(b'e6 3d 05 89 65 ef 79 55 50 fb 4e 63 98 dd 35 39')
# CWbytearray(b'30 21 75 7a 8a f1 b3 c7 ba f3 90 77 0e f2 58 30')
# CWbytearray(b'18 98 01 b8 fe 59 68 13 f6 ff b9 b5 31 3b f0 36')
# CWbytearray(b'ed fc 70 53 41 03 8a b3 6a ae 55 f5 14 e7 3e fd')
# CWbytearray(b'54 dc 70 80 8d 88 04 77 e3 1f ce d0 cf c1 2f 3b')
# CWbytearray(b'2f 0d 7f ff 6a b3 04 71 6c 8f 46 af d8 9e a1 6a')
# CWbytearray(b'87 a8 b1 7d 2f 54 0c ae b8 33 25 11 7b a0 38 a3')
# CWbytearray(b'37 6c c1 10 f2 3b 1c 71 65 71 e7 55 c5 90 8a e4')
# CWbytearray(b'28 21 8f 1c 22 ad 6a 6c 3c 25 c8 d0 17 ec c5 4c')
# CWbytearray(b'c1 d1 dd dc 07 09 77 47 fe 81 40 95 5e 14 3b 84')
# CWbytearray(b'db 5f 97 10 f5 5a 92 5e cb bb 17 e1 43 e7 9d c6')
# CWbytearray(b'b6 e5 09 54 ac 42 3a 50 32 85 67 b1 a9 64 6a 9b')
# CWbytearray(b'8f e4 07 fe 14 34 f4 5a ec e9 81 91 ac 9f f0 f8')
# CWbytearray(b'ac 9f 90 5e 83 04 df 89 c6 64 c6 09 4a b9 3d 46')
# CWbytearray(b'be 01 b7 73 9a f1 8f 1d 0c 65 25 63 60 fc a5 51')
# CWbytearray(b'5a 1a 5f d5 4a bd 90 09 20 4e 29 01 7a d7 17 36')
# CWbytearray(b'1e e1 79 0a e1 4d ce 2c 4e 0a 8b 09 1f 29 55 34')
# CWbytearray(b'dd 22 69 e1 88 9f b2 ab 4c ec b7 03 b7 e1 7a 35')
# CWbytearray(b'ce 87 b8 e8 a0 01 c5 e7 c1 d1 ae b6 a9 26 e0 be')
# CWbytearray(b'ae 9c 5d 10 87 c4 dd 3f 2b bb 05 5c f9 a4 7b 07')
# CWbytearray(b'54 cc 71 b1 fb 5a 7a 91 bb db 9f 03 a1 21 97 20')
# CWbytearray(b'1f 5a b8 97 4e 8a 0a e7 c8 1e 4f 12 5c 74 ba df')
# CWbytearray(b'34 e0 64 3f 88 d4 fe 2c 1b 4b fe ef be 79 33 7f')
# CWbytearray(b'06 3e 80 c0 c5 46 ba 9c 92 f8 d3 42 b6 29 a8 84')
# CWbytearray(b'a1 f2 e6 8a 31 8e c5 9f c7 7b b7 24 ff 10 e1 d6')
# CWbytearray(b'9e 9f 45 a5 c5 c6 88 64 c2 46 eb ea f6 71 81 4f')
# CWbytearray(b'3b 3d ca 45 15 de 67 68 5e 8d aa 95 94 46 71 1b')
# CWbytearray(b'db 3d 3d 02 97 84 78 15 41 73 95 ba c9 58 87 6a')
# CWbytearray(b'67 6d af b2 5b b9 c1 87 46 54 14 4a 56 5a 4f fb')
# CWbytearray(b'dc 6b 5e 49 4c ff df eb 2f 89 34 d4 5d b9 ab 6a')
# CWbytearray(b'6f 49 93 00 0c 91 31 05 17 f1 6e f4 4e 07 f7 f7')
# CWbytearray(b'a9 28 93 74 52 2f 19 52 e8 a4 f8 ec da ff 17 47')
# CWbytearray(b'5d 30 0b f0 fc 53 14 f4 0b 7a 51 fb 44 1e 58 16')
# CWbytearray(b'f3 76 7f 32 f0 4d a3 79 58 bf d1 d4 4b 15 ea ca')
# CWbytearray(b'7a 09 ae 3b 68 22 e6 dc 54 21 6e 49 39 f9 7a ca')
# CWbytearray(b'40 c2 c5 41 7c 3c f5 0e 94 42 36 50 f4 cc 24 d8')
# CWbytearray(b'4b 77 76 4f b1 57 36 ec 6f 88 14 c8 a9 aa 5f 95')
# CWbytearray(b'97 75 ea 83 fb 85 2e 9a ad dc 7d ec 80 59 4e 21')
# CWbytearray(b'7b a5 a0 da 27 4c fb fb 3f d0 9b 31 59 80 36 f4')
# CWbytearray(b'ab fa ec 34 83 da af e9 7d 05 9d fb b0 20 5c 88')
# CWbytearray(b'ce 3f 95 2f 3f b6 12 ce 06 bc 73 06 59 27 b2 73')
# CWbytearray(b'62 d0 78 3c f2 7e 98 a2 f6 3c 9f a2 50 f6 75 ae')
# CWbytearray(b'24 50 cd ac 85 1a 57 f2 88 10 ac d5 3f 53 4a be')
# CWbytearray(b'9d 26 15 aa ea f5 3e e6 74 a5 bc 23 f9 fc 06 b7')
# CWbytearray(b'ae 6b 4f ab 77 5c fd 03 a3 95 c1 36 6c 12 85 1c')
# CWbytearray(b'09 5a 43 1c 11 c9 65 11 d1 1f 04 2e d6 db ee 46')
# CWbytearray(b'36 b0 08 91 b8 f6 bf 06 60 a7 8e 56 1f b7 d8 54')
# CWbytearray(b'db a9 6f 32 9f 8b f9 d8 e6 45 9c 02 94 e0 c8 d8')
# CWbytearray(b'c1 31 3f 8c f3 9b b9 df 80 3b 45 fa 42 55 e5 97')
# CWbytearray(b'd4 95 f3 7c 43 53 9e cd 87 b5 6c 7a 83 ce 2c 9c')
# CWbytearray(b'8e 5a d5 1e 74 9e 6e c7 f4 0c e5 7f 95 0b 3c 56')
# CWbytearray(b'7e 2e 45 9f 38 24 03 62 b2 ff 19 c9 40 07 fc aa')
# CWbytearray(b'76 b1 fb 7d 26 88 cc 2a ef 09 38 cf 4e 72 6e 72')

# %%
from tqdm.notebook import trange
import numpy as np
import time
from Crypto.Cipher import AES
import random
ktp = cw.ktp.Basic()



traces = []
textin = []
keys = []
N = 20000  # Number of traces

# initialize cipher to verify DUT result:
key, text = ktp.next()
cipher = AES.new(bytes(key), AES.MODE_ECB)
testkey = [[]]
for i in trange(N, desc='Capturing traces'):
    # run aux stuff that should come before trace here
    testkey = []
    key, text = ktp.next()  # manual creation of a key, text pair can be substituted here
    
    text = [0xFF]*16
    for r in range(16):
        key[r] = random.randint(0, 255)
    print(key)
    cipher = AES.new(bytes(key), AES.MODE_ECB)


    textin.append(text)
    keys.append(key)
    
    ret = cw.capture_trace(scope, target, text, key)
    if not ret:
        print("Failed capture")
        continue

    assert (list(ret.textout) == list(cipher.encrypt(bytes(text)))), "Incorrect encryption result!\nGot {}\nExp {}\n".format(ret.textout, list(text))
        
    traces.append(ret.wave)
    project.traces.append(ret)
# Out:
# Capturing traces:   0%|          | 0/20000 [00:00<?, ?it/s]
# CWbytearray(b'44 ed 68 e4 8c 80 c4 93 93 91 cb bd 96 ae f2 41')
# CWbytearray(b'4c 3c 18 d4 21 8b f2 f2 39 df 22 13 1a 75 4d c8')
# CWbytearray(b'ab 38 4c 5b b1 12 d5 2b c7 ee c7 75 ef f3 94 c7')
# CWbytearray(b'61 c0 f8 f6 59 ce 89 d9 4b e0 86 30 92 74 f9 f0')
# CWbytearray(b'f8 96 e8 ae ed 9c a4 1b 3a 1a 5e 23 9f ae 28 13')
# CWbytearray(b'5a 06 30 eb ae d4 d2 e8 27 ba c6 95 b3 a3 40 7c')
# CWbytearray(b'54 53 2a e6 40 44 d9 ba fd 42 83 94 a1 64 68 c0')
# CWbytearray(b'29 69 7d 6d 6b 42 d3 5c 48 bb 59 aa ab 03 39 d4')
# CWbytearray(b'66 08 be d9 d9 99 2e 15 36 0b 20 db 46 51 f7 87')
# CWbytearray(b'cc 24 71 30 b8 75 fa 3d ca ac 95 01 56 9c b4 e9')
# CWbytearray(b'41 f5 b8 ee 27 d7 b2 49 95 3f 7d d3 ec d5 82 8e')
# CWbytearray(b'e9 3a be d0 f3 fb c4 43 8a 0f ce 05 3b b2 f3 35')
# CWbytearray(b'08 6b 6f 3e 05 0f 29 5f 14 bf 3f 24 93 01 f0 bc')
# CWbytearray(b'fc 14 a7 7f 2f cc 97 30 30 4c 3f 67 12 a9 44 3c')
# CWbytearray(b'f2 9d 75 66 29 07 1a 09 37 a1 c0 7b 25 22 86 5d')
# CWbytearray(b'f2 28 8e 26 fa 8e 3f 76 32 e1 83 eb 02 73 66 30')
# CWbytearray(b'2b 39 ff 07 49 74 ff 32 1a 6a ac 5c 7c e1 ee d8')
# CWbytearray(b'04 fb 72 3a 83 ee 8b 39 4c 1d 2b 43 5d e8 2b b1')
# CWbytearray(b'0c 3a 74 77 24 6d dc 05 c5 76 b3 89 09 d7 8c 42')
# CWbytearray(b'21 22 5e 15 4b 8f ff 63 c2 c8 8b 7e e2 e7 0a e4')
# CWbytearray(b'bb 94 bf 2d e0 2b 3b 8a 1e 87 f3 10 ae f7 86 f4')
# CWbytearray(b'89 6f 0e 57 5a 6c eb b7 42 fe 10 fd a8 8d 63 ea')
# CWbytearray(b'46 32 47 7f 60 71 40 53 26 dc ec 11 3e c9 cb 9d')
# CWbytearray(b'3b 78 6b eb 32 15 41 70 f5 ac bf 4f ca 13 de 4a')
# CWbytearray(b'7b 17 7d d1 17 83 dc 8d 68 4d ae 86 00 59 21 cf')
# CWbytearray(b'c7 1d 33 45 03 75 39 a5 7c 2c 3f e4 8e e2 54 46')
# CWbytearray(b'19 23 ca ca ed 83 eb 26 c1 db 21 52 d2 0c 20 3a')
# CWbytearray(b'73 1d 51 e1 54 de c8 1d 72 b2 60 7d 75 dd 6a d7')
# CWbytearray(b'e1 61 c7 51 a0 94 a1 03 b3 b1 58 b3 c5 9c 1f ca')
# CWbytearray(b'a6 ff 5d e6 6e b0 ad 99 b2 8f 7a 4d 27 8b bf bd')
# CWbytearray(b'2c d6 b0 1f 25 1c 48 65 f1 11 ce a7 7a 06 88 50')
# CWbytearray(b'30 4b ee 20 97 07 c3 1b b5 29 a7 4a 3e 4c 25 41')
# CWbytearray(b'97 45 a8 f2 98 38 70 2a 84 94 3b 5b 17 2a da 04')
# CWbytearray(b'5d f7 12 a5 ed 76 75 60 c2 02 6f fe 04 5d b9 6e')
# CWbytearray(b'3c 43 4f e6 b4 b7 2c a0 53 7f 6a 49 cb b4 e7 3b')
# CWbytearray(b'77 b4 12 06 d8 ee 94 9f 3c 48 c3 f0 b9 58 cf f1')
# CWbytearray(b'd8 8f f9 1e fe bc 59 ec ca ac ff e7 75 c9 1e 16')
# CWbytearray(b'89 49 0b 57 61 da 40 98 3e c9 55 be fd be 4e d3')
# CWbytearray(b'84 c2 6a e9 cc 3c f6 8f c1 35 fc 4c 2d 4e 10 82')
# CWbytearray(b'20 01 d4 be 1b 7f 48 d8 9d 2b 7c 94 43 30 19 d9')
# CWbytearray(b'ea 76 b6 6b 71 90 fc 66 f1 f0 15 7e 2e 26 48 9f')
# CWbytearray(b'3d d2 42 05 2c 23 3c ae f8 e7 ff bf 0b 3e df 7e')
# CWbytearray(b'51 0a cd f9 a0 53 09 41 69 25 2e 70 a9 72 57 68')
# CWbytearray(b'c0 69 12 e6 5c 59 f8 10 c4 1f 36 bb aa 03 1f b9')
# CWbytearray(b'10 8e 28 32 d5 e0 ed 56 cc ac 9d 40 58 5d fd ea')
# CWbytearray(b'f9 f9 23 ce 5f f4 a7 be b0 27 62 d4 11 e8 e2 84')
# CWbytearray(b'97 17 06 c8 28 4e 1f 37 a5 d6 60 24 fd 8b 57 3e')
# CWbytearray(b'fd d7 85 b3 35 f3 60 c5 9d 71 b4 6f 66 18 c4 10')
# CWbytearray(b'9d 08 5f 3e e9 01 ab aa 2b 90 4d 2a 72 6e 71 7c')
# CWbytearray(b'ba 7e 6e 9f 50 99 62 ba 16 97 d5 8c ce a8 d1 b4')
# CWbytearray(b'59 7e 50 91 d6 ca a9 84 23 64 35 16 f2 01 5a 13')
# CWbytearray(b'ea 1a 66 ba ee af c2 5d e3 bd 08 9f 40 80 67 2c')
# CWbytearray(b'14 2a 2c 58 03 f3 c8 2d 03 f4 bd a9 5f 63 50 d8')
# CWbytearray(b'a3 25 58 e2 33 d0 07 ac 67 a0 cc e7 28 0a d5 90')
# CWbytearray(b'f0 07 93 53 21 3a 73 51 0b be b1 f3 1a de e4 78')
# CWbytearray(b'd0 9d 03 db 18 e3 67 50 52 10 fb 5e d5 ee 92 bc')
# CWbytearray(b'17 23 15 2c e6 ad 2b 99 f8 ed 74 7c d2 7c b2 1c')
# CWbytearray(b'cd 2a 4e a9 e4 df 61 d2 fa 68 98 f3 c1 f6 fb 7c')
# CWbytearray(b'a1 c9 3e d5 3d dc da 37 e5 62 2e 44 08 78 30 0b')
# CWbytearray(b'de 15 a5 37 b8 f5 fc 45 8b b0 94 da 0f 22 04 33')
# CWbytearray(b'7b 50 99 1e 42 76 0c 02 2a 61 05 5c 2e 41 96 07')
# CWbytearray(b'22 66 bd 75 cd 39 18 57 8d 76 16 83 77 57 ec 3e')
# CWbytearray(b'ef ac 23 ca 5e 8b d8 35 3f 1d 95 8f 29 2c 62 ec')
# CWbytearray(b'f2 79 88 d2 b3 7d 01 3b df 4e 6b 5d 2e 05 52 6d')
# CWbytearray(b'62 78 b0 c0 74 a5 c8 9a f0 e0 15 ef 9e 5a e8 d3')
# CWbytearray(b'10 a6 a2 be ef 5e fa 4c 18 b2 e0 07 8d cd db 5a')
# CWbytearray(b'99 12 03 64 40 1c 91 87 be 76 8d 1d f1 9d ee 74')
# CWbytearray(b'b0 f7 25 35 90 5b c4 3b 7d cd c8 8a 49 d0 be bf')
# CWbytearray(b'74 09 26 79 26 54 1b cc 06 55 d9 02 cf c8 ea cd')
# CWbytearray(b'af 36 15 92 b5 06 6e 43 48 60 72 5d 52 7a 14 1b')
# CWbytearray(b'47 c4 4b 98 89 ba 64 5b 4e a8 51 bd 0c 48 82 5e')
# CWbytearray(b'36 70 0e 2d 17 0d a5 3d fc 19 1c 3a e9 0f 49 81')
# CWbytearray(b'a0 d7 6a 23 ab 66 52 1f ac 38 e1 65 12 b5 64 1d')
# CWbytearray(b'ac ba 7d 2d fe 84 46 51 71 c8 4d 36 d9 f1 4f 15')
# CWbytearray(b'ff a9 1c d5 d5 e3 b8 5b bf 44 bb cc 8c 0c 14 88')
# CWbytearray(b'b7 69 49 da e7 c3 94 a7 bc f6 ec 7f a4 6e 69 8f')
# CWbytearray(b'5b 9b 47 a9 04 22 52 a7 d2 0b de 73 34 7d 36 75')
# CWbytearray(b'f0 e3 57 e1 75 24 5c fb 6a 0e e7 90 98 58 a8 3d')
# CWbytearray(b'68 b6 18 50 be 96 ee 51 e8 fc 91 51 ee f4 16 8e')
# CWbytearray(b'ac 8a 5a 13 ce 46 f8 4e 81 8c c2 d6 e2 f4 98 0e')
# CWbytearray(b'd5 9d 28 89 06 a5 2e 86 ae 99 86 22 66 fd a1 7a')
# CWbytearray(b'b7 c2 05 57 1f c7 04 03 43 fd 49 57 49 a5 f9 92')
# CWbytearray(b'b2 29 43 b1 e6 83 fd ce f5 6b e9 f4 34 18 96 05')
# CWbytearray(b'01 33 8e 56 20 01 1d 15 dc e7 4a 9b 36 ef 25 fb')
# CWbytearray(b'cc 5a 6f 75 97 10 1b 84 43 16 a3 9e 33 9c 49 7e')
# CWbytearray(b'a7 92 83 42 00 2c 9f d1 19 31 95 ac 06 16 0d 25')
# CWbytearray(b'78 3b 72 ff 4d 61 92 8f a4 44 01 ad 06 16 c5 a1')
# CWbytearray(b'1f 97 54 a7 d4 69 a6 c0 61 dd 2b 41 c9 87 29 1c')
# CWbytearray(b'b9 8a 29 1d 48 b4 6f d5 1e 8d 98 2a 75 70 26 1d')
# CWbytearray(b'6a 49 8b dd 77 ec 8c bf 19 06 f2 2d a4 bd df 40')
# CWbytearray(b'6c 78 cc bd 62 cf 9f 3a ab d1 39 dd 3c 5e 23 2d')
# CWbytearray(b'0f 5c 04 7d 2f 1a 83 99 3d 7c 5d 9a 7b 4e 22 b2')
# CWbytearray(b'69 34 69 14 c6 cb 3f 72 02 ca 0d 64 fb 0f 06 a7')
# CWbytearray(b'c8 bc fb 40 e7 d1 8f 78 de e5 92 58 49 fb eb 23')
# CWbytearray(b'40 70 51 3e 08 85 b3 9e c3 f8 db ed be 80 8f d5')
# CWbytearray(b'28 bd 4b f9 99 35 3a 53 3b ce 70 f8 84 d1 df 89')
# CWbytearray(b'd0 46 9d a8 f2 2d 16 07 b0 6f be 4e 4f e8 39 49')
# CWbytearray(b'3e 02 f0 20 32 4d 21 b2 55 fa 1e b6 13 e5 9b 50')
# CWbytearray(b'e7 b5 20 6a 27 27 80 36 68 ec 0d 6a 60 f8 55 dc')
# CWbytearray(b'7d 9a 71 9b 19 a0 c4 d8 59 a8 7b d8 1f ff 3b 3b')
# CWbytearray(b'b5 3c b0 34 76 e5 38 c4 f0 c3 00 42 b9 4c dd e9')
# CWbytearray(b'd0 77 58 32 da 70 af 66 f4 a2 44 53 84 5d 19 08')
# CWbytearray(b'32 48 19 98 0c 44 ac 21 58 29 cb 79 cc 57 2b 75')
# CWbytearray(b'55 90 88 b4 31 2e 9a 42 df 2b 0d d3 94 f6 4e 43')
# CWbytearray(b'e9 03 1c 35 3b b3 3a c6 6a 76 31 9a b2 dc ae 13')
# CWbytearray(b'f1 e8 3a 69 5d 08 3f be 4a 61 55 1c d1 f2 56 41')
# CWbytearray(b'69 8d 57 78 54 d6 94 dc 3c 2f a3 e7 ac 5f f5 88')
# CWbytearray(b'5d d1 0b 16 cc d7 0d 57 4c 2d fe 44 91 d4 8c dd')
# CWbytearray(b'f7 f8 b7 b2 9f 85 09 e2 34 5e 95 15 9b 96 51 ca')
# CWbytearray(b'cc 10 93 0a b0 da 7f 7c 6b 84 37 be 6d 11 5c 93')
# CWbytearray(b'46 1c 3f 35 50 cb e2 ff 5b bb 96 c8 5f d9 42 73')
# CWbytearray(b'1b 39 47 8a c0 c2 b5 3e b9 dc 85 9b a3 f9 42 64')
# CWbytearray(b'a3 55 39 65 f9 17 0c a5 3e 1a 36 e4 0d 0b a3 70')
# CWbytearray(b'64 8c 65 7b c9 0b 77 0f 69 29 eb c7 3c 00 71 d5')
# CWbytearray(b'f9 e1 e3 3a 8a 0b d5 ce 35 c5 70 71 76 ee 69 9e')
# CWbytearray(b'63 b3 dc e0 36 a9 de be 00 4a 80 66 66 9f c2 8c')
# CWbytearray(b'6c 01 f8 fc 05 8a 2e 7b cc 76 cd e2 8e 74 e3 cd')
# CWbytearray(b'99 84 2c 9c 5e 89 05 bd 93 d6 25 71 2d ae e7 82')
# CWbytearray(b'78 bc e1 b4 35 e8 55 31 20 75 f3 a0 8a b1 62 11')
# CWbytearray(b'06 0c 24 44 39 0d 22 dd 52 38 bd af 3d 65 9e 44')
# CWbytearray(b'd7 28 28 68 e4 02 0e 15 e2 29 11 b5 16 a7 7f e0')
# CWbytearray(b'f8 0f 56 a6 ea cf 6e 5b 6f 5f a5 2a 59 df 66 a5')
# CWbytearray(b'83 12 b5 2b 77 ef 05 21 97 50 90 09 3d f2 c4 c3')
# CWbytearray(b'1f 92 39 7b 20 ad 42 46 4d 41 61 b7 4a b1 d1 3f')
# CWbytearray(b'38 63 06 64 86 d8 43 86 df 38 d7 df ac 2c 5e 93')
# CWbytearray(b'27 79 bb 1c a9 db 48 1c de d3 6b ad 43 22 92 41')
# CWbytearray(b'75 1b ba 86 3c bb 22 13 f0 de 7f bb cc 55 cb a9')
# CWbytearray(b'f1 fe ba 48 10 3b 31 c9 ec 68 92 a1 65 6a 09 42')
# CWbytearray(b'57 bb 0e d7 6c cf 56 42 4b 18 3c dc 28 60 c0 7d')
# CWbytearray(b'2b 87 ef 97 18 1a b2 30 50 61 9b 2e ea 92 e5 3c')
# CWbytearray(b'0a 5e 55 b0 41 00 9f fd 35 b7 8f 5e fd 3e 1b 89')
# CWbytearray(b'5b 26 d6 ab c7 a7 16 ab 86 a8 35 61 cb ec a7 55')
# CWbytearray(b'35 b3 e7 1f 7c 9a a4 e1 9a 21 af e8 de 7e 9f 71')
# CWbytearray(b'64 b1 50 86 a8 08 64 62 78 66 09 10 85 d8 3f 57')
# CWbytearray(b'68 2a 08 e4 85 4f a5 e2 3b c6 0d 93 c6 a9 d4 3f')
# CWbytearray(b'49 b9 43 11 39 91 a9 64 ab 6a 76 bb 4a 2f 49 97')
# CWbytearray(b'd0 25 dd 1a 01 a9 84 e7 44 08 29 a7 19 5e ce 77')
# CWbytearray(b'8d 18 05 45 7d 2c 61 0b 2c 1e bb 82 5f 93 3f fe')
# CWbytearray(b'26 a6 4a 5b 24 ac b8 8d 09 9c a2 5d f4 fa c2 fa')
# CWbytearray(b'e1 06 57 91 40 c9 f0 b0 01 9a b1 c9 be d3 0e 49')
# CWbytearray(b'2a 5a 70 0f 49 58 05 84 b2 be 54 8a 4d e0 90 7e')
# CWbytearray(b'06 87 b8 a9 a9 b4 02 1e 6a 94 14 27 3b 4b cc b4')
# CWbytearray(b'44 9b 59 3b 5f 30 00 0c ac 6f e5 67 47 b0 da a2')
# CWbytearray(b'65 65 e1 4e de 99 e9 6d 77 1f d0 01 58 f9 c6 3f')
# CWbytearray(b'44 3a 93 24 84 a5 48 db 29 89 69 60 67 5c b0 6d')
# CWbytearray(b'38 f9 84 12 a5 9a 43 04 8b 6d 00 2c b7 ec 20 ed')
# CWbytearray(b'8a 83 6d 67 cd dc bb df 0c 02 a0 43 51 ae 94 31')
# CWbytearray(b'57 2f 1f af e7 50 84 c6 a4 7d 90 7b 8d 09 23 c2')
# CWbytearray(b'84 73 3f 64 b8 38 6c 0e e8 c4 87 76 13 9a 99 7a')
# CWbytearray(b'33 a7 ea 40 c8 33 7c 96 a3 dd d7 55 ce 22 da 5e')
# CWbytearray(b'a9 86 9c 16 5c ba 31 36 df e3 b3 01 db fc e1 23')
# CWbytearray(b'1b 21 b0 84 c2 0b fa 2c e3 1a f7 4a 78 7d 66 6f')
# CWbytearray(b'70 f6 d0 eb c5 59 5f b6 e4 19 b1 83 2e 20 a1 eb')
# CWbytearray(b'ec ab 1d c6 31 c1 fc 66 c8 ff 30 98 5d d8 09 d6')
# CWbytearray(b'b4 b8 4a 3b e1 6e db fe b5 c9 c9 d5 ba da 5d 8a')
# CWbytearray(b'09 a0 a4 80 01 34 15 7c 8a ba 03 6d 6b bc 87 ea')
# CWbytearray(b'62 70 69 74 98 4a 1a ab dc e6 bd d3 f3 0f 16 b9')
# CWbytearray(b'da f6 37 22 9b 60 1a b6 33 33 e2 33 53 2e 22 22')
# CWbytearray(b'dd 2d ca ae 34 3e 29 d9 48 7c 3a 77 ae 92 eb c6')
# CWbytearray(b'50 c8 e7 b9 ef 9d 9a 87 2a ed 33 39 82 77 6c 7b')
# CWbytearray(b'7a 7b 61 12 8e b8 01 21 af 59 d4 54 b0 fa bb 07')
# CWbytearray(b'8f ff f4 2a 0c de 44 16 d0 b8 a3 1d 16 87 26 0f')
# CWbytearray(b'2e 7b 1b 71 aa 38 3b 9f 89 82 34 0c 71 06 06 0c')
# CWbytearray(b'cd 51 4c 85 17 74 57 44 e8 1b ba ac 82 bf b5 b8')
# CWbytearray(b'db 35 4c 24 7e b0 3f 28 7d d1 21 19 e7 a0 56 fa')
# CWbytearray(b'67 48 08 02 5b 63 ce f3 34 bf 77 0b 9a 67 8f 7b')
# CWbytearray(b'79 75 fe 6e b7 f1 bf 70 ff f9 a9 04 f2 c2 1a a5')
# CWbytearray(b'63 7f 51 39 f2 aa 56 60 a9 8a 03 aa e6 82 f5 e3')
# CWbytearray(b'cb 88 b4 d6 29 67 8a 05 8f e4 ed ad 86 78 f4 b5')
# CWbytearray(b'65 27 ef f2 01 54 a9 e7 1b a0 ba 00 17 ee 9e a1')
# CWbytearray(b'eb 12 4b 52 de 19 d0 69 fa 8c 0e b4 f8 80 87 8f')
# CWbytearray(b'ac 76 e4 f7 0f 81 61 a9 d9 90 b5 3f f4 32 6a 92')
# CWbytearray(b'54 3b df 1a 0e 60 9a f0 a9 ac dc d6 d0 67 7f 18')
# CWbytearray(b'7e 24 c7 49 9c bf 99 35 72 61 7f 4b 8e b1 b7 6c')
# CWbytearray(b'e1 fa 2e 43 53 2c 7e d0 6a b5 6b 1d 2c b4 75 a7')
# CWbytearray(b'a0 10 ab b0 e2 bd 56 da 71 cd 3a e4 71 1b 8a a6')
# CWbytearray(b'30 2a 62 1d 85 15 3c 20 f8 ae ef 44 b7 0e a5 a4')
# CWbytearray(b'08 5f 88 0c 4b 98 ec 65 d1 67 77 d9 37 05 61 98')
# CWbytearray(b'ac 6e 3c f5 12 f7 1c 00 06 c3 4b cd 07 c8 5f e3')
# CWbytearray(b'f8 ac 80 d3 2f 25 d8 d3 05 ee 49 0b 6a f6 9b 5d')
# CWbytearray(b'5e 03 58 8e 32 54 4e b5 6f 33 98 18 78 b0 46 80')
# CWbytearray(b'd9 49 c5 03 9c cb 18 36 71 cb a3 ac a8 e9 48 c9')
# CWbytearray(b'7b 90 f5 fe 28 4d f6 85 01 ea c9 2c a6 17 c1 04')
# CWbytearray(b'87 23 17 71 63 70 5a 88 de ad 09 5c 28 32 b3 4d')
# CWbytearray(b'82 c1 87 5b b1 b5 cd ac ed 1d 13 69 f5 31 26 ab')
# CWbytearray(b'd1 eb 3a 05 fa f6 33 36 65 85 86 42 ac 84 ad 3f')
# CWbytearray(b'89 59 7a 01 a2 2c bc a0 d4 2c c6 01 06 ed 93 f2')
# CWbytearray(b'f2 09 f2 d2 61 63 22 ce 18 2b f6 b8 04 9a 5c 79')
# CWbytearray(b'c5 ff 08 ab ca 0e 0e 6a 8b c9 44 b8 fa 74 f6 02')
# CWbytearray(b'e2 ef 4c a2 dd ca 05 a4 46 17 7d cc 68 d2 3b 30')
# CWbytearray(b'15 91 4f 40 47 a8 65 a0 b7 8a 68 17 68 70 e7 42')
# CWbytearray(b'50 d4 29 b8 65 ba 1f c2 59 e1 cd 63 09 f9 00 3f')
# CWbytearray(b'7e e4 ef 2c 26 53 bb 2f 89 0e 56 5b 01 7b 74 ab')
# CWbytearray(b'd5 da 16 33 f5 d0 6d 99 36 8c bf 60 25 66 08 29')
# CWbytearray(b'96 51 1a 51 72 7c 2f a2 46 09 f1 b7 23 94 f1 56')
# CWbytearray(b'7d cd ce c2 95 44 f1 e2 4f 9c 11 00 9b 1d a4 d4')
# CWbytearray(b'3a 81 35 10 aa b8 a6 26 64 54 fb 23 5a 32 67 b4')
# CWbytearray(b'7d 58 a5 e1 78 d5 30 24 da 9c c9 04 de e5 b5 f4')
# CWbytearray(b'3b 94 00 68 61 45 28 cb b1 31 e4 c9 09 5f f4 2c')
# CWbytearray(b'f8 83 ed ad 48 c4 4b 3e 63 2b 0f ff 50 ef e1 5f')
# CWbytearray(b'6e 61 8a 18 e0 6e 8b 1c 29 8a 7c 3a ed 69 b0 c8')
# CWbytearray(b'0a c6 92 9b ac 37 38 49 7d 75 0c d5 5a 19 4c cf')
# CWbytearray(b'35 6c 50 3c 55 27 fc 0f ba d3 a0 ad 93 17 47 3c')
# CWbytearray(b'4a d5 95 f3 26 5b 5d 41 a6 fe e7 da 5d b8 4e ec')
# CWbytearray(b'6a 2a f7 25 5d 0a 54 d3 23 ef cf 77 23 0e 66 ea')
# CWbytearray(b'95 57 1d 9c d2 20 3d 59 3e 45 8c 22 ba 1b 99 69')
# CWbytearray(b'21 9e 8b bc f0 ba df 3d 50 2e 85 53 2c 77 56 dc')
# CWbytearray(b'97 d6 e9 f8 d9 96 a4 35 6f 5f a8 bd ac 8e 4c 57')
# CWbytearray(b'93 c0 c8 48 6b 40 3f 04 ff 15 0e 00 ce 00 2b 4d')
# CWbytearray(b'dc 33 95 d0 51 35 40 76 68 93 91 ce 9d 67 80 47')
# CWbytearray(b'56 cf 6e 5c 0d a2 4f fc 77 cf 55 c3 41 84 20 2b')
# CWbytearray(b'9e c8 7f 93 92 9b 53 0a 66 f6 68 08 a6 09 7c 76')
# CWbytearray(b'b6 d9 61 cf 33 32 fb 8b b1 5c e9 7e 0f 1e a7 ec')
# CWbytearray(b'ef b3 1f 87 68 6c 7f c4 10 37 1a c6 89 3c 4a b7')
# CWbytearray(b'2c b5 b3 28 33 c8 74 e3 7f e0 f2 dd 21 08 5f 35')
# CWbytearray(b'31 67 f6 09 78 ef 0a 12 02 4c 66 63 4c 83 4e 8c')
# CWbytearray(b'97 f5 d0 62 64 0b 26 05 06 d8 6b dd 5c 29 f9 82')
# CWbytearray(b'66 61 c1 dd d6 78 56 9a b9 ad e1 0a 9f fc 77 1d')
# CWbytearray(b'54 b9 09 ec 7d 44 cf 87 a7 af 66 7b 7c 6e 62 2c')
# CWbytearray(b'80 4e c2 0b 74 f8 d2 f5 c5 d6 8f ae 0f 5a f1 04')
# CWbytearray(b'bc 20 ca f8 e8 15 b3 43 1a df 38 58 3c bd 58 a3')
# CWbytearray(b'60 0b 09 90 be 58 3c 6b 9b 02 1d 4a a3 37 d2 22')
# CWbytearray(b'1d b4 c1 29 d2 4b bd 4a 20 9d 98 87 7f c0 d2 b7')
# CWbytearray(b'41 8b 3a c3 f0 e3 73 9f 24 b3 04 54 a4 0d 34 a8')
# CWbytearray(b'99 a4 8a d4 ba dd 53 38 30 c3 c0 61 29 7b 74 a5')
# CWbytearray(b'aa 71 05 4a fc 83 47 b1 3b 5a 1a 62 f0 e0 e7 73')
# CWbytearray(b'15 42 39 f5 ae 97 c8 f3 59 2f 85 bc e6 ff 91 2d')
# CWbytearray(b'e7 a4 ef 87 61 28 65 46 4e 52 39 04 cb ab 2e 70')
# CWbytearray(b'a8 f9 1c b7 da 05 3f 3e 9f 7c 7c 8f 03 61 4b 60')
# CWbytearray(b'be e7 14 ee df a4 9c 27 5c 94 67 0a 03 c6 ea d1')
# CWbytearray(b'2e 2d 56 f7 53 76 b7 59 92 38 be 4f ca d4 53 f5')
# CWbytearray(b'51 0a cc 29 cb 0a 9e c6 a2 b7 84 9a d5 94 27 1e')
# CWbytearray(b'af 02 2f cc be 66 3c 09 39 69 ae 70 3a 2d 15 9b')
# CWbytearray(b'15 14 ae 0e 39 c5 08 b6 ed 89 88 78 ff 08 08 91')
# CWbytearray(b'74 9e 4e 26 1f 5b a2 4f db 73 f0 1c 71 ef fd cf')
# CWbytearray(b'ab 7d 32 f1 82 97 cf 1b 56 8f bd f1 68 18 16 a5')
# CWbytearray(b'7c bb 0f c0 a9 2a ec e9 50 2a 27 94 f9 0c 0c 40')
# CWbytearray(b'fe 00 c9 06 70 76 40 6e 69 1e 61 69 6f 67 82 df')
# CWbytearray(b'7a 60 aa db 1a 7b d0 55 d8 2d e1 c1 63 e7 9c 5e')
# CWbytearray(b'f1 73 1e 84 12 16 7f ef 47 7b 49 88 bd ac 7a f2')
# CWbytearray(b'd4 f4 9f 29 a4 9f 6b 2d 15 7b 5d 18 0c d7 e7 6b')
# CWbytearray(b'd9 b0 55 90 8b 0b 81 05 63 92 eb 17 79 70 b6 b5')
# CWbytearray(b'4e 4e 60 f3 db 59 56 bd ce 8e 22 d1 59 5e ab 16')
# CWbytearray(b'1a e8 55 8e 1d 40 0d 12 59 be 8f d8 bd aa f9 8e')
# CWbytearray(b'9c 77 ee 95 d5 fe 06 fb 38 41 e0 07 09 e1 0b 6a')
# CWbytearray(b'a4 6a da d3 79 1d f4 f2 31 52 a0 07 70 f3 b7 29')
# CWbytearray(b'6b 29 38 9b 1f 3f aa 5b 98 ba 9d b5 23 62 e0 ee')
# CWbytearray(b'b7 6f 53 5f e2 18 85 f7 63 ce 86 72 14 7c 0a 97')
# CWbytearray(b'36 ce 54 9c 29 9b 74 ad 6d bd d1 e9 6e d1 b9 ba')
# CWbytearray(b'bf 0c 9b 99 e9 eb 3c 2e 84 c3 e6 a9 87 49 b7 6d')
# CWbytearray(b'ad 40 69 73 21 21 90 a1 4e 07 02 6e e6 02 a3 4e')
# CWbytearray(b'bd fd 8d bb bc fa e1 ad 86 e0 26 51 11 ef a0 95')
# CWbytearray(b'3e 11 e6 e9 c0 95 78 49 22 51 16 59 35 82 55 0c')
# CWbytearray(b'89 6a e6 2a 99 ba 5b e0 05 79 fb ec 97 3c 80 f9')
# CWbytearray(b'4c 20 9d 28 ec 06 05 8b 47 e6 04 eb da c3 c3 23')
# CWbytearray(b'8d 9d 2b 5d 11 b9 64 03 92 22 40 ee dc 94 d2 4f')
# CWbytearray(b'30 2f 02 28 24 1d 82 80 de 3f 84 07 45 5d f8 a5')
# CWbytearray(b'39 d7 89 3b 75 34 31 a7 67 72 e6 0c 99 d9 57 df')
# CWbytearray(b'e5 6a 89 0f ff 85 e9 bb d6 4d 03 86 93 20 4f c4')
# CWbytearray(b'bd 44 bb e2 05 a4 f2 f8 4a fd 89 72 0f cb 16 6a')
# CWbytearray(b'51 85 78 bf d6 0b 8e 06 88 4c ab f3 5d 6b a3 e8')
# CWbytearray(b'79 32 0d 6d 10 78 b6 74 83 50 97 1c e5 01 62 2f')
# CWbytearray(b'b2 b0 1f dc e9 ac 06 45 cc f9 6a 41 91 ca f3 c9')
# CWbytearray(b'e6 28 e4 02 32 0a df fb f0 53 ab 7e 54 a5 2e 0d')
# CWbytearray(b'f5 99 19 3f 4b c9 49 11 9a 33 82 5f 60 9a 72 c6')
# CWbytearray(b'ff 6b 13 4b 31 3d dd 80 1a ee 96 f1 52 e4 89 e2')
# CWbytearray(b'cb f5 87 ac 21 9d ff 86 1e 02 8f f6 0d 72 a4 a9')
# CWbytearray(b'91 a8 03 d8 6a 1e 55 25 04 8a 80 48 b2 3c 06 c3')
# CWbytearray(b'4f de cc cc 5b 68 a3 a0 a6 f9 d9 6c bc af 73 3f')
# CWbytearray(b'f8 8b 69 01 69 f3 66 53 f1 fc 73 3d bf 70 56 26')
# CWbytearray(b'51 9c 39 ec 0f e7 a7 52 d1 ef d2 ee c3 c8 d7 31')
# CWbytearray(b'fc 3d 37 b9 06 c4 b0 01 cd 0b 7e 45 df 53 ab 99')
# CWbytearray(b'9e 2d 80 4b 49 62 23 a4 fc 09 06 f3 27 21 e2 98')
# CWbytearray(b'de aa 8b e4 8c 6d 03 4f 45 13 7b 42 be ba 2d 47')
# CWbytearray(b'38 1b ca 97 aa 28 b6 34 69 b4 3e 3f 75 59 cf 37')
# CWbytearray(b'93 4a 71 c6 24 35 f7 ce 3d da 57 8f ec 56 cc f2')
# CWbytearray(b'5c 39 6f 23 9d 15 f4 92 a1 b0 22 c7 8f 16 3a cc')
# CWbytearray(b'78 5d c0 ac 17 98 7b 7a dd 18 0f 49 7d fe 36 55')
# CWbytearray(b'56 70 2e 76 aa 32 85 4a b3 ba 7b 5e f7 f2 0f 83')
# CWbytearray(b'c2 da 7c 97 9c 67 14 15 7f 52 38 1c 83 09 c5 3c')
# CWbytearray(b'5f e9 d3 3b 96 c9 36 5d 85 fd 12 81 48 36 d0 f4')
# CWbytearray(b'02 15 65 d7 e7 05 d9 2e b7 6e f9 e9 95 3b 98 05')
# CWbytearray(b'73 a0 84 d3 5f 91 67 f2 3f 15 e5 b0 9f bc 06 f0')
# CWbytearray(b'a2 38 25 52 1b 04 79 4d ed 57 07 60 db a8 67 ca')
# CWbytearray(b'a9 f2 c4 97 a8 7b 49 08 bf b1 23 2b d4 2e 34 da')
# CWbytearray(b'd5 cc 88 00 2b 02 b4 0d 8d ee 55 73 04 70 9b 98')
# CWbytearray(b'5c df 60 0e 8d a4 bc bd 82 b6 33 00 67 a7 18 1c')
# CWbytearray(b'90 7f 9b 5e 93 e6 21 7d c2 ab db 74 3d 9a 79 0e')
# CWbytearray(b'd7 d6 b5 eb 2c bb f1 f4 c6 be 2b 04 f9 b6 91 71')
# CWbytearray(b'4b 03 62 b2 cd 52 15 7c bb 99 34 df 86 f4 6e 26')
# CWbytearray(b'e7 6d ca 32 e3 e0 e6 ae 60 26 aa 6b b6 24 5e 07')
# CWbytearray(b'94 49 c8 38 3b 65 b0 4e aa 4d 0d d0 f7 8c 7a 1c')
# CWbytearray(b'e7 52 fe 2e ae 42 7e 06 cd d4 04 43 03 ea 18 59')
# CWbytearray(b'21 36 7b c5 0b 60 d0 61 b7 17 73 fc ac 44 86 38')
# CWbytearray(b'43 09 71 ca f3 e0 01 4e 46 36 e5 e6 06 5d 62 15')
# CWbytearray(b'61 e6 63 a6 6a 50 a7 18 8d 25 ba 88 a0 6c 37 71')
# CWbytearray(b'05 d2 eb 71 f7 9d a9 30 0d ab b0 0a 3f d9 ca d4')
# CWbytearray(b'79 63 07 a0 d7 86 bc 1a 69 cf 3c 89 92 7b aa e6')
# CWbytearray(b'82 5a 5f c3 02 85 e1 13 5e f6 07 eb b7 47 ab 14')
# CWbytearray(b'36 7c 6c 4f 3c 31 a1 07 5f 0f 42 4b 61 02 cd d2')
# CWbytearray(b'a3 f9 a6 76 90 f3 86 e4 2e f2 93 46 6c 20 a9 e9')
# CWbytearray(b'56 7a d8 0f e5 5e c2 3d 1a 58 fa f7 2b a2 7a 59')
# CWbytearray(b'9c ba 33 eb ca 90 bc c2 af 88 1c 44 a5 87 8b 60')
# CWbytearray(b'03 59 d0 91 30 fb e7 1d 0c 27 71 6d ee a2 3c 2c')
# CWbytearray(b'37 d3 36 10 ec d6 bd 62 6c f7 ad 8a d7 12 32 61')
# CWbytearray(b'9f c5 81 ef 0d e8 f9 75 8d 69 dd f5 02 63 37 7b')
# CWbytearray(b'f4 7d b7 f6 fc 4a 10 fe ea 13 a9 80 3b 09 38 1e')
# CWbytearray(b'd3 66 99 8f 32 4b 1c ba 58 17 54 49 1d a6 b3 d4')
# CWbytearray(b'9b 59 c4 fc 14 c9 2e 12 85 ae b6 a8 a9 6a d4 1a')
# CWbytearray(b'42 95 79 c3 d2 db 42 1b 70 36 b2 32 24 49 fa 7d')
# CWbytearray(b'3f 3d d5 3d 3f a0 43 93 d7 2a f8 15 15 55 5e e2')
# CWbytearray(b'b8 19 df 92 c0 ac 94 52 e4 6d 37 38 6c 8b 86 da')
# CWbytearray(b'54 09 a3 ef 32 e3 2a 56 40 af a1 b0 fc df af ad')
# CWbytearray(b'cf 3e aa 01 12 43 f8 38 cb f4 77 28 3b 1c 34 f9')
# CWbytearray(b'99 fd 35 62 fc b8 76 63 c5 40 94 dd 85 38 ed b5')
# CWbytearray(b'9a 89 c5 1a 5d 74 2d 7e 9d 15 7f f6 a6 23 d2 f7')
# CWbytearray(b'af 10 b0 3f b1 7c a1 d2 f6 4b 08 c9 60 d0 0f 9b')
# CWbytearray(b'5e de eb e8 ed ec 83 fa 7f 0a 22 6a 3a a2 e6 e5')
# CWbytearray(b'1d fe 3c 1a d0 c2 11 80 d6 f9 92 f3 2f 4c 3c 4d')
# CWbytearray(b'68 9f aa 27 6a 2f 9d 5f d3 06 4e f1 70 54 71 7d')
# CWbytearray(b'a2 7d 77 23 0b 23 43 e7 d9 9d fb 8e 0d fe 73 35')
# CWbytearray(b'0c 6b 7a bc ec f0 f1 94 d5 15 65 53 93 e3 35 ea')
# CWbytearray(b'df e1 83 fe 24 13 8d f8 87 2f 67 7b 40 d8 92 1e')
# CWbytearray(b'04 9d a6 61 d4 67 7e e5 77 dc 71 49 5b 43 7e 18')
# CWbytearray(b'bb c0 55 8e d5 65 0a 52 c6 d0 ae a3 23 f5 2a ca')
# CWbytearray(b'8b 5f dd ba 62 1f 35 59 6f 9a 02 85 3d 71 0d 7c')
# CWbytearray(b'94 87 4d 62 97 55 89 1d 07 97 8e 8f e3 b0 17 83')
# CWbytearray(b'96 ff ef b3 bc 85 52 a9 a3 b0 06 7f 96 22 39 ab')
# CWbytearray(b'5e bc fc f7 af e6 fd 82 6f 2a 35 36 82 0e 48 4e')
# CWbytearray(b'14 21 e5 f4 9d e9 e7 43 cb 60 b6 6c f4 05 ab e9')
# CWbytearray(b'0d 18 72 21 42 af 9c 1e ee b6 cb ec 6c 72 9c b6')
# CWbytearray(b'd0 57 86 a6 a4 e2 8c 6d 26 65 c1 fb 39 17 de 56')
# CWbytearray(b'd8 23 fa ba 8a f7 21 84 9d ea 56 76 3c e5 4a f2')
# CWbytearray(b'3c 5d a7 4d 8e e9 97 f1 9b f0 cc 2d 35 23 71 a9')
# CWbytearray(b'18 53 ff 9b 7a 27 f8 5a 27 d1 b4 6e f8 74 70 de')
# CWbytearray(b'12 09 16 9a c0 c2 c8 1e bc cd 95 15 97 6c 8c 0f')
# CWbytearray(b'ca 0d 26 c7 ae 64 fd b7 cb 87 6a 24 c8 82 ed 6d')
# CWbytearray(b'27 5e 25 8a 73 06 b2 5b b5 61 b4 b9 a6 0b bb 93')
# CWbytearray(b'50 36 92 98 e4 13 41 2b 02 f9 bb 98 76 9c 9a 89')
# CWbytearray(b'd2 07 9b 5a bd 20 df 4f 5c 5a 82 2c c4 86 eb f4')
# CWbytearray(b'aa 1b c3 a2 0d 46 ef 50 cd 20 f7 66 61 bb 64 30')
# CWbytearray(b'70 d7 3e 32 f9 80 54 f6 57 b5 6c 8f 5a 0a 34 31')
# CWbytearray(b'4d 24 54 a0 9b a0 cf 8a 36 71 d6 01 06 d2 93 e2')
# CWbytearray(b'6b c5 06 91 c5 12 54 2f 68 f5 ab 7a c3 27 d7 ec')
# CWbytearray(b'ca 52 e1 47 52 3f 55 db 3d c5 4d 8c 8e 95 70 bf')
# CWbytearray(b'2e 55 de 8e 36 75 ac 71 b5 54 99 d4 fb 75 16 c0')
# CWbytearray(b'3f e7 b8 8d d7 21 8a c6 1e 7f a4 89 1f 44 60 d0')
# CWbytearray(b'41 1b 74 bf e0 4d 97 1d 74 13 7f 65 0c d9 42 58')
# CWbytearray(b'0f 81 e2 1d b9 01 ee cc de a3 7c d9 1a 3e 3d 18')
# CWbytearray(b'57 97 2b 14 c8 0f 6a b5 83 ec ef 45 a0 7d 58 9b')
# CWbytearray(b'5c e0 6a 70 1b ee 48 30 12 52 73 0c d3 53 27 95')
# CWbytearray(b'83 f8 fa a8 c2 62 9c 96 7c d3 50 1c 25 c4 69 06')
# CWbytearray(b'77 7b 89 9c 5f 96 33 04 bb de 07 4a 7b 3d e6 d8')
# CWbytearray(b'96 7e 5c 66 2b 7e e6 c3 33 25 b1 5f 12 9c 64 0b')
# CWbytearray(b'b4 93 0c fe 79 25 29 42 de bf 35 d6 0b ad 01 8f')
# CWbytearray(b'86 8f 2d d8 5b 1d 12 85 71 47 70 c8 05 f9 08 c6')
# CWbytearray(b'6f 21 4a 23 b7 e3 6f fe ab 00 1f f4 69 1a 85 68')
# CWbytearray(b'43 80 ab 87 42 fe 6d 62 b6 65 65 7d 0d aa ee aa')
# CWbytearray(b'e4 47 31 1c a0 b1 4b a8 d4 00 bb 91 41 c3 cb fc')
# CWbytearray(b'c6 68 bd 1a 2c 4c 75 7c 1f 21 97 1a f9 46 4d f3')
# CWbytearray(b'00 c6 6a 17 79 8c 83 91 0b de de a9 04 84 3c c1')
# CWbytearray(b'58 93 83 16 77 a8 ad e1 1b 07 72 ea d3 fe 20 9e')
# CWbytearray(b'63 58 cb d5 53 e2 2f c8 73 76 22 78 18 46 f8 73')
# CWbytearray(b'52 8f 41 05 f5 7f df a3 99 fb fb fd 43 0a dd 28')
# CWbytearray(b'c1 9d 78 21 53 54 46 b8 1d 9a e6 c9 16 b5 85 46')
# CWbytearray(b'3d 9d 2a 05 6a b4 02 84 d2 41 38 e4 62 68 26 8e')
# CWbytearray(b'41 93 07 15 2a 47 3f dd a1 6f aa ba 83 08 d9 ed')
# CWbytearray(b'5f f7 5f d9 dc b0 42 39 3f 0d 8e 6a f7 96 0f 78')
# CWbytearray(b'17 8f 7e 86 71 d2 2e 26 f9 ec 4e 13 44 2b 81 75')
# CWbytearray(b'b1 96 af cc d0 93 51 c7 57 13 95 35 6b 3c d8 06')
# CWbytearray(b'a2 69 85 4f b2 be 25 ac 20 e2 ed 09 31 08 6b e0')
# CWbytearray(b'44 bc 35 15 f9 1f 1a a9 b7 00 b8 38 c5 61 b0 53')
# CWbytearray(b'bc 42 2b 94 e0 31 c9 03 a9 58 62 50 a4 40 72 af')
# CWbytearray(b'06 f2 e9 fb be e2 72 10 f7 58 10 f8 dc 2d a0 c3')
# CWbytearray(b'fc c4 23 e8 d4 10 d6 9f c2 62 f4 43 14 1f 39 a8')
# CWbytearray(b'40 82 48 fa e2 f9 e1 42 ff 55 d0 5a 57 67 91 83')
# CWbytearray(b'16 7c c3 27 a9 b8 c7 13 ba 47 95 43 20 02 00 76')
# CWbytearray(b'07 a7 1d a4 17 d0 bf 15 ac 2f 06 eb bc 97 64 b3')
# CWbytearray(b'44 65 f5 ab 83 52 8c af 0d 0c 93 7e 25 ed 69 21')
# CWbytearray(b'93 a5 4e 96 07 4f 36 cd 16 96 b7 62 1c 00 f8 da')
# CWbytearray(b'21 29 92 42 ce b1 8a 66 2b eb e3 3f d4 ef 51 3a')
# CWbytearray(b'ee d6 d2 8c 7a 53 f6 11 b9 16 33 c0 6a 7a 52 f7')
# CWbytearray(b'19 17 2e 8e 31 45 05 f5 a9 4a 17 9d 2d 28 c9 5a')
# CWbytearray(b'e7 ca b7 f6 e9 d6 6d 4d 98 2f da 87 8a 21 98 35')
# CWbytearray(b'52 74 cb 87 86 de 98 06 02 1d d1 e1 80 c3 a8 be')
# CWbytearray(b'c9 d2 09 8a 4f 0d 7b 83 26 88 ff 5b a8 87 13 9d')
# CWbytearray(b'ba e4 3d 72 aa 5c 88 81 12 93 b1 0e a6 71 07 ee')
# CWbytearray(b'07 da ec 1c e2 41 e0 0e 02 93 58 19 de e6 76 38')
# CWbytearray(b'37 00 44 c1 d0 cb aa c0 dd d8 0d 58 bf e1 65 e4')
# CWbytearray(b'56 6b 47 49 10 2c 98 55 79 85 cc ab 38 ed cb af')
# CWbytearray(b'6f ea 09 75 28 a5 13 42 e8 91 5c 85 05 d6 ad 6e')
# CWbytearray(b'e0 ba 81 4d 2b be cd 8b 36 c2 b8 78 e9 b4 9e 0b')
# CWbytearray(b'70 5a 36 8c de 3a b9 6a 5e 43 38 e8 a0 32 c8 8d')
# CWbytearray(b'4c dc 9e b7 0c 7e af 98 eb 58 e3 be a0 46 2d e3')
# CWbytearray(b'cf f9 24 67 93 4b 80 0c 78 82 8c a0 fb 92 b9 8b')
# CWbytearray(b'ad 39 c4 48 6c dd 40 f3 6a d8 f0 b8 1d 61 19 53')
# CWbytearray(b'5f a6 6c cf d2 e5 99 d2 a9 e2 f6 0a 8f 2a 56 38')
# CWbytearray(b'96 b3 f1 f0 e5 51 24 d8 8c 50 07 7e 33 72 a1 7b')
# CWbytearray(b'32 e7 eb 65 c2 aa 08 7c 90 6f 92 f1 22 42 70 bf')
# CWbytearray(b'36 c8 c9 e9 db fe 1c 73 2d 01 5c f6 d7 83 a6 b9')
# CWbytearray(b'31 d1 95 71 54 a1 d0 53 1c 78 92 7b fd f4 49 f8')
# CWbytearray(b'44 7f 1b 4e ba 29 16 c9 1a 69 c9 69 e2 44 97 88')
# CWbytearray(b'ec 24 a1 af 74 bc bf 91 4b fd 52 88 cd d6 4e c7')
# CWbytearray(b'67 e1 35 1c 18 a9 30 8a 1e 23 b7 7e 9e fa f9 34')
# CWbytearray(b'90 21 27 0d 3b df 2a 19 78 f1 cd 27 6c a0 24 76')
# CWbytearray(b'04 fc a8 8d fa 18 e0 89 36 b6 69 c3 da 88 df 02')
# CWbytearray(b'fa 4d d6 99 f7 94 c0 ee 7c 5e f7 e8 69 9c 5d b5')
# CWbytearray(b'19 3d 9a ff e7 0f 2c b7 6d 03 6c 6b c8 88 d5 88')
# CWbytearray(b'3a 33 e2 69 64 64 3b fd ac ba 62 25 bb f3 01 a1')
# CWbytearray(b'bf 77 04 2b 94 44 50 e3 c5 e3 64 ec bb 37 cb 84')
# CWbytearray(b'6e e6 2a 5b 9c 6f a5 65 e8 9e 76 c9 0f b7 b2 0b')
# CWbytearray(b'56 bf 92 f2 11 f3 2c bf 2d 67 f7 be d0 aa be 27')
# CWbytearray(b'd0 2a 6e be d7 d9 12 aa 22 e2 1f 50 a2 0a 06 3f')
# CWbytearray(b'c1 0c 02 05 1d 7a 32 75 82 08 eb 1a b1 0c f4 32')
# CWbytearray(b'13 03 16 e8 9f 8f 58 8b 29 9f 28 4f de f2 e2 10')
# CWbytearray(b'90 9f 28 93 2f 9f 3e 72 ce bd 12 0d 4a 06 f9 0f')
# CWbytearray(b'ad 2c 63 e7 a8 92 0e c2 64 83 a4 dd 4e 0f 13 39')
# CWbytearray(b'82 88 1b 55 65 23 93 43 07 7d 6f a5 e0 90 47 54')
# CWbytearray(b'eb 9a 5b 01 60 8e fc 1f 1e f6 a2 b1 f2 98 8b 23')
# CWbytearray(b'0e a5 9f d4 e5 b6 f4 e9 8e e0 0e e6 3f 5b dc 86')
# CWbytearray(b'52 a3 51 45 da d5 0a 69 f4 5d da ee 0b 56 02 da')
# CWbytearray(b'a0 05 c6 db ef d6 66 87 cf 00 22 fc ea 5e c4 5e')
# CWbytearray(b'15 4c d3 98 1d 0c 51 b6 f6 48 a9 6f 0e da ac 26')
# CWbytearray(b'18 ed 54 c9 d8 2c 45 b4 85 c4 0c c2 91 b6 e5 c6')
# CWbytearray(b'e1 69 84 17 96 d3 75 ff a5 f6 61 cb 8e c2 12 93')
# CWbytearray(b'63 ff 63 ae 8f 26 91 e2 cd ce 8e de e1 d1 8f 2d')
# CWbytearray(b'a0 b5 e5 5e 2a d4 23 de 53 13 73 4c e1 99 1e 65')
# CWbytearray(b'ac 54 1b 3e 71 dc a7 73 2a e2 b1 a7 c6 54 e0 6a')
# CWbytearray(b'6d ed 40 b8 38 12 82 dd 31 63 5a c9 21 ce 85 af')
# CWbytearray(b'de 81 a0 73 de 99 12 e1 af 28 d7 84 57 e3 45 55')
# CWbytearray(b'9e 96 42 c5 0b ab 98 24 00 33 ed 3d e8 fc a9 4a')
# CWbytearray(b'93 f7 4a df 51 78 3f 64 ea 58 6b de 31 e8 1d 3e')
# CWbytearray(b'41 c5 b8 a1 24 a6 70 97 28 65 6c b0 1e ca 78 d4')
# CWbytearray(b'40 71 91 32 c6 54 2a 3b c1 57 43 5d 7a 95 c7 0f')
# CWbytearray(b'dd cc fa 55 ca 23 01 72 bd 54 87 c9 b2 cf 6c e4')
# CWbytearray(b'ca 59 66 12 d4 ec da 0a 42 19 ac 64 4b c5 32 2a')
# CWbytearray(b'0f 8b 7b 10 bb b2 ee 90 37 1a 72 b9 62 a9 64 87')
# CWbytearray(b'1a 4e 40 e2 09 56 f0 e2 0c bc 03 84 f5 e2 67 9b')
# CWbytearray(b'23 dd c3 96 7c 4a 72 d5 c4 b1 34 fc 69 50 7e 3e')
# CWbytearray(b'7c 33 5a 74 5d 30 f3 c1 a8 0b 76 2f 6f 52 04 dd')
# CWbytearray(b'9c 38 2c 1f 13 9f d2 b9 aa 53 45 7b 57 1e ba 35')
# CWbytearray(b'16 77 e8 15 ff 48 91 7f 7e 2a 59 65 3c 47 5e 79')
# CWbytearray(b'52 d7 8e ed 8f 4f e8 da 43 27 3f 38 5d b9 dd 26')
# CWbytearray(b'16 76 f7 e7 d6 34 b6 13 43 b9 d7 58 75 1f 64 7c')
# CWbytearray(b'08 7e 79 24 c7 25 1d 35 a9 1a fe 7d 8f 08 9f bb')
# CWbytearray(b'2d f9 90 04 da 08 20 de 0a 9c e4 46 3d a9 10 7a')
# CWbytearray(b'5a ed c0 30 43 54 ee a2 e7 74 50 c0 30 4c 8c 34')
# CWbytearray(b'7a 9c 98 be c6 bf 82 54 a3 74 12 2d cf 4e e5 6b')
# CWbytearray(b'5d 54 bc 96 e8 61 95 99 5f 66 99 e6 b7 6e 9a ca')
# CWbytearray(b'1c b6 11 40 22 22 aa 92 3d 76 98 2b 2e 23 c8 a9')
# CWbytearray(b'01 d7 f5 5b c5 a0 52 86 39 4e 98 03 81 d7 a4 88')
# CWbytearray(b'75 d9 9a 2b 37 98 06 d5 da ba 15 cf 9c 20 cf 18')
# CWbytearray(b'dc 59 22 5c 93 27 e4 ee a4 36 33 6f ab cd 9d 1a')
# CWbytearray(b'57 08 bc 11 34 0f 81 46 8e 6f 7b fe 03 a2 ac 6c')
# CWbytearray(b'a9 98 7f 2b 75 fa e8 62 6b e9 33 72 9c 0d 55 dd')
# CWbytearray(b'45 27 a7 cf ad 1e b9 b5 8b 9b 80 dd 22 a2 17 bf')
# CWbytearray(b'b4 15 4b 47 a1 7e 04 e7 3e 3b 12 fe e6 31 f6 68')
# CWbytearray(b'4b 85 10 a0 d5 e0 22 18 08 09 84 89 9e 27 0e 1e')
# CWbytearray(b'd9 0b fb b7 2f 2a 30 75 be 78 ff 59 1a e6 49 8e')
# CWbytearray(b'da e7 fe 75 65 60 30 15 37 e9 04 3c e3 78 30 e3')
# CWbytearray(b'29 69 89 52 97 07 82 e2 da 22 3b 45 61 f4 68 87')
# CWbytearray(b'5d f2 ee 77 11 11 6d 9c fc 5c bf 15 c6 d1 47 97')
# CWbytearray(b'ac ab 80 8d 92 6a c4 4d 8f 03 ec 85 90 69 d2 18')
# CWbytearray(b'50 93 26 ae f7 50 6e 82 45 d9 1f c1 89 13 9f 9e')
# CWbytearray(b'22 ad 61 a7 b7 ee 6a b0 34 3d 74 29 d0 2c 0a 32')
# CWbytearray(b'8d a8 f1 7a b2 d6 3c 74 05 ab 25 bb 0c 04 fe b0')
# CWbytearray(b'6d 55 e9 b6 f6 4f 46 c4 3f 7e 90 a2 3e a5 7d ba')
# CWbytearray(b'ec e4 3a 31 82 2d 73 4f 7d 5e 8f 63 47 23 65 bd')
# CWbytearray(b'8b 60 f4 c5 69 a4 8d f6 51 7e 3e a0 4d c7 90 b7')
# CWbytearray(b'd0 ad 01 cd 19 e4 42 64 1e 8e c4 5f 9d b5 8e 82')
# CWbytearray(b'a9 da c2 54 f3 ca 28 71 4c 52 ea 60 e4 ca e3 4a')
# CWbytearray(b'18 2e 0c 0d cc 28 cc 07 d8 d7 7a 16 55 20 56 8b')
# CWbytearray(b'0d 95 d8 e9 80 de ca c2 27 91 ad fe 97 59 dd ca')
# CWbytearray(b'1c 0d 20 83 63 ff f2 07 b3 cf 5d 06 92 0c 57 31')
# CWbytearray(b'3d cc c3 5a 93 dd 18 60 e2 4f 96 3f 56 28 00 c6')
# CWbytearray(b'4e 49 cb 40 76 08 93 e8 bb f9 89 f3 30 fd fd d6')
# CWbytearray(b'94 00 f9 ec b9 c6 c3 5b 79 87 e3 74 01 b7 16 7a')
# CWbytearray(b'06 96 aa 45 83 0e 79 db 0a 5b a2 a4 5c a5 2d 2b')
# CWbytearray(b'c8 67 cc f9 2e 7f 11 1e 2d 53 38 b7 e9 c2 4d 98')
# CWbytearray(b'8a 50 e2 20 66 e3 73 9d 58 c1 01 e9 af 1d 5e 9e')
# CWbytearray(b'60 27 53 ba f8 af 22 32 f7 0a 2e 95 c4 b6 02 9a')
# CWbytearray(b'be 17 8e e0 e9 32 e2 69 fb 66 46 7e a5 08 29 f6')
# CWbytearray(b'48 63 14 8e e1 f2 1b 21 11 24 a9 a4 c5 8f a5 70')
# CWbytearray(b'ae 94 b5 89 07 45 6c 1b 30 b5 72 6d 97 02 3a 5b')
# CWbytearray(b'd6 a6 3b cd d9 5c c7 64 25 f0 45 c0 67 13 c2 b7')
# CWbytearray(b'35 1e a8 78 a2 6c 55 42 ad 14 da 3d 86 9a cf f5')
# CWbytearray(b'de 7d 1a d2 18 23 c6 4a 08 40 bc 71 76 9a ca 7e')
# CWbytearray(b'32 fb 34 82 db 98 31 82 f5 2a bb a6 09 a8 d3 17')
# CWbytearray(b'bd 54 60 e9 a9 ba 9d 3e 70 50 67 24 d6 92 af 90')
# CWbytearray(b'1c dd 1f 01 77 5a 68 97 55 17 6c 99 c7 11 6f d0')
# CWbytearray(b'da a5 1e c0 cd b7 86 e3 93 8f 50 9e 84 f1 dc 68')
# CWbytearray(b'72 46 ca 4f 62 36 6f 18 5e 80 67 71 2d 89 7d 10')
# CWbytearray(b'af 8a 0a 27 f9 fa 33 53 36 bf 6b eb e3 60 7f 85')
# CWbytearray(b'89 b8 6e 79 6e cc b8 e1 ba 23 49 89 c2 cf 31 fc')
# CWbytearray(b'56 60 5d 57 e8 08 b5 6e 92 af 64 70 87 29 f6 7c')
# CWbytearray(b'f5 d1 7c 10 c3 c9 f5 9a 8a b1 e9 3f dc b4 90 bf')
# CWbytearray(b'ac 16 26 c0 09 ae 85 b5 c2 37 56 6b 0f 4b d7 99')
# CWbytearray(b'8b aa 93 11 c6 05 65 c2 41 0b 94 92 c9 3c 72 65')
# CWbytearray(b'64 ae 05 15 38 57 49 94 6e da f5 23 f4 f4 47 03')
# CWbytearray(b'82 0c 63 f8 3e cc ff 6f e6 35 b3 34 36 04 a3 95')
# CWbytearray(b'd8 c7 45 43 eb ad 26 85 4a 98 ae 52 f8 54 c6 4e')
# CWbytearray(b'51 bc f4 14 d2 af fb ee b8 72 5d 22 0f e1 b2 ef')
# CWbytearray(b'ca 12 a4 eb 2a d4 e7 18 60 73 60 26 0a 16 ae 5c')
# CWbytearray(b'66 5d 63 19 1b d4 d3 ee 38 96 46 25 bc 59 38 5f')
# CWbytearray(b'23 ac a8 20 99 ec 57 62 ae 08 a8 b2 52 0b 27 72')
# CWbytearray(b'b2 4f c7 01 f9 84 c1 e8 d0 20 0a 2f 89 fe 37 15')
# CWbytearray(b'0e 65 4c 8b 20 55 a0 c2 82 6d dc 5c e7 01 64 87')
# CWbytearray(b'54 8f 13 f6 28 2b bc 57 01 0f f4 cb 39 8c 2d 3e')
# CWbytearray(b'c4 af 7d b7 63 69 35 9f 49 35 52 36 28 e2 a5 a1')
# CWbytearray(b'a4 f7 27 1e 91 ea 1d a6 8f 92 78 a9 b5 03 82 23')
# CWbytearray(b'f4 b1 0e b3 ce 90 f0 8c d6 02 1f ae 1b b9 71 45')
# CWbytearray(b'ed a1 31 65 2c 3b 89 9e d7 d0 fd fb 31 fb 18 08')
# CWbytearray(b'a7 d7 84 77 14 97 8b 9d e3 37 b1 9d cb 85 65 51')
# CWbytearray(b'6c 81 d5 a5 c1 90 06 af a4 e2 d1 37 9e 6a 97 06')
# CWbytearray(b'ea 7c 2d b6 14 38 24 d9 19 7a f0 24 39 8f fc b7')
# CWbytearray(b'15 2f 94 ea 9c 7f b0 8c 99 cf fd e9 cf 5e d5 64')
# CWbytearray(b'62 52 c0 7f 2e af 5a 09 42 e7 f2 89 fe a8 ac db')
# CWbytearray(b'67 e4 69 6b bf 77 df bc 27 c0 66 d2 50 bb f2 1c')
# CWbytearray(b'92 32 54 33 68 a3 a3 c3 ea e3 aa 52 bb b6 ad 5e')
# CWbytearray(b'5a fb e9 2c d6 be 60 e0 ef 77 5b a2 cf 94 fc c3')
# CWbytearray(b'be 38 57 b6 06 a7 51 ea 59 c5 b7 bb fa 31 5c 4e')
# CWbytearray(b'97 77 07 b4 ea 64 4a 40 3c 4d a2 76 dc a9 be d5')
# CWbytearray(b'b1 36 e4 92 7f 05 8d ca 29 de 1d 53 ad 0f ea e2')
# CWbytearray(b'0b a6 fd d5 d2 52 58 28 05 6e f6 9d 35 d1 9f a8')
# CWbytearray(b'02 ab 25 82 c0 b7 9e 38 39 15 d5 70 ee 3a 7f 53')
# CWbytearray(b'2e a1 66 d2 6b 7b e7 35 a3 b3 43 3e 7c 6b ff 5c')
# CWbytearray(b'7f 0a 4c 98 ed cc 85 bb aa 16 ae 17 ef 54 a3 f9')
# CWbytearray(b'62 a6 d6 46 5e f4 f7 53 da e7 c2 9e 08 44 c1 89')
# CWbytearray(b'b2 46 c5 05 fb e8 02 8e 7b 99 b9 63 c3 74 21 39')
# CWbytearray(b'8c 6f 2f 72 28 f7 bc 25 db 75 b6 10 33 d9 92 d1')
# CWbytearray(b'9b fe 1b 07 75 7e cc bc 8b 8f 2f c1 8b c1 6a e5')
# CWbytearray(b'4b 44 f5 9f 35 00 da 64 c1 27 5e bc 0e ec e3 06')
# CWbytearray(b'cb 87 d6 a6 93 c7 39 51 9c e8 72 4b 32 aa b4 70')
# CWbytearray(b'39 96 23 ef d2 c1 70 a5 ea ab 64 7f c0 6c 01 dd')
# CWbytearray(b'80 24 b5 e7 08 58 11 1f 6b 11 5a 96 88 ec 43 75')
# CWbytearray(b'bd f0 6f 1f 2f 51 91 1c aa b8 58 66 bb 6e fd 4d')
# CWbytearray(b'0a de fe e5 64 f7 ae d4 f4 8c 34 e0 23 52 93 57')
# CWbytearray(b'2e 86 e6 ac 6a b8 c7 3c 71 d6 47 81 76 c6 a2 d4')
# CWbytearray(b'd8 3e 9c 17 b9 ab d8 b5 6d e9 2b b4 56 cd 71 3f')
# CWbytearray(b'9a 4a e7 35 b0 39 94 fa 00 44 73 bf db 9f a1 b7')
# CWbytearray(b'e9 b0 fb cf cb 5e e7 87 ff eb 4b e0 0f 10 5c d9')
# CWbytearray(b'5c b6 85 20 ea f9 ee ea 18 71 4a 02 f3 4c 8b 03')
# CWbytearray(b'cd 9e 64 25 42 54 4c b2 19 9c 05 af 58 e2 e9 a3')
# CWbytearray(b'f6 06 bd 0b 72 c1 3f 35 65 e0 34 9e a9 90 e4 7f')
# CWbytearray(b'10 1d 14 c6 0c 83 f9 e8 24 0a 79 8d 25 37 ce 0b')
# CWbytearray(b'84 34 27 6b 36 21 2c f6 c2 79 4b 38 6e d6 0d f5')
# CWbytearray(b'29 80 d3 67 c3 de 4e 5e 5c 4e 1d e6 26 56 a2 13')
# CWbytearray(b'fb 7c 52 0d 43 3a ab d1 5b fd 80 7c 3b 45 68 70')
# CWbytearray(b'30 54 da 73 dd d5 93 74 ee 52 68 4e 8a aa a8 31')
# CWbytearray(b'11 e6 c1 3c 18 ac 63 c4 2b 90 d9 a5 18 0d 66 46')
# CWbytearray(b'80 21 19 c8 32 08 fe fe 86 8b ae 44 e8 1d 86 cc')
# CWbytearray(b'dd 4f 9f 7a c4 d5 e5 a4 66 8e e5 36 33 3d 5c 0b')
# CWbytearray(b'7d 55 f8 88 f6 78 25 4c 6a 6a 2f dc 27 21 d2 64')
# CWbytearray(b'9e 59 e3 00 05 d9 f2 6f 71 71 a8 76 f2 29 bf f4')
# CWbytearray(b'80 f8 aa 2a 9d 82 af 24 59 f8 2b ff f7 d1 6a 2d')
# CWbytearray(b'3d d8 05 e3 35 a9 3c 37 40 3f 6c f7 d8 3b ef 66')
# CWbytearray(b'39 b4 a1 d4 b9 cc a9 ff 99 43 9f cb 70 bf 93 9b')
# CWbytearray(b'52 c0 e7 25 9b 7b 14 8b a5 e4 98 42 d3 d4 93 2c')
# CWbytearray(b'7b 82 32 b8 c4 cc e1 b7 f4 19 23 2f bb c6 ce b7')
# CWbytearray(b'77 39 55 7f 68 8a 54 d3 8c d9 0f 9e 3f d2 b7 1a')
# CWbytearray(b'c1 66 2c 9c ee e9 dc 77 15 96 31 b7 43 47 b8 74')
# CWbytearray(b'02 82 37 33 58 52 17 57 0f f2 13 29 02 15 b4 f7')
# CWbytearray(b'3f 89 30 7c d2 3c ab cf d0 8f 31 93 34 5a 77 1a')
# CWbytearray(b'3b 98 f7 ea 05 5c c0 0e 25 90 02 dd 5b 9b 4b 17')
# CWbytearray(b'83 e9 48 d7 de 31 5e 19 a4 f0 14 72 43 00 6a 49')
# CWbytearray(b'3c 9a 0c 8a d6 4f 8a cf 2d ba ee 09 61 6e 38 1a')
# CWbytearray(b'38 e1 cc 52 11 10 80 8a 2d 0a d1 b4 05 3b 99 8f')
# CWbytearray(b'27 dc 88 92 dd 66 76 41 b1 42 16 80 84 c4 4e 54')
# CWbytearray(b'73 42 e9 cb 5c 2c a6 cd dc b0 85 3d 6c 33 f4 3b')
# CWbytearray(b'15 c6 95 52 12 c5 0e c5 86 00 1d f2 86 89 fc a8')
# CWbytearray(b'78 e0 0e 00 f8 6e 5b 0f a6 8d 1e 6d 84 de 1b c3')
# CWbytearray(b'6c 2e 8b 13 f3 74 55 5c f4 d3 0d 02 25 30 b6 2d')
# CWbytearray(b'f8 7a 85 85 b2 34 94 42 2e 8e 10 1c 31 c8 0d 79')
# CWbytearray(b'58 68 50 a6 1d e4 c3 a4 b2 4f bb 41 8c 85 20 92')
# CWbytearray(b'd0 c6 7c 3c 3e 7d 2a f6 ff d5 af b2 43 40 8f 4c')
# CWbytearray(b'b6 5c 29 db bc e5 aa 2c 39 b3 af c9 e8 79 74 e2')
# CWbytearray(b'68 30 37 07 d2 63 53 42 2c a8 fd 95 c4 75 63 82')
# CWbytearray(b'48 96 2b 49 5a 8c 02 f8 04 79 b0 d6 e2 36 ca 2c')
# CWbytearray(b'7d 87 8e 8a 0c 4e 3a 5d 50 b8 59 ba 35 d3 f4 0f')
# CWbytearray(b'37 2c 19 7e a6 a7 4d 51 0b 28 8e ca ef 1b 86 be')
# CWbytearray(b'd3 fa ee a1 44 a4 6a 1e 20 3a 0e d0 b1 00 f9 3a')
# CWbytearray(b'16 d2 e1 1b ba 3f 11 e4 3c cd 8c f6 17 69 c3 d1')
# CWbytearray(b'fd 08 e1 48 8f d3 83 5b c1 43 44 e3 27 a6 b7 63')
# CWbytearray(b'ba b3 01 13 90 16 e1 c2 c5 79 ce 36 2c 7b a5 5d')
# CWbytearray(b'39 0b c9 13 24 31 71 07 5a 31 ba 5e 2f 7c 32 1f')
# CWbytearray(b'15 a5 05 c8 50 ae 79 84 ab 53 4d 14 4d 17 2f 12')
# CWbytearray(b'a9 60 a3 d0 f4 d1 fa 58 be 63 17 73 65 f2 36 9c')
# CWbytearray(b'10 78 33 fd 3f 8a 62 66 01 34 26 d4 a7 95 e4 d9')
# CWbytearray(b'f9 fc 3d e0 6e 14 65 2f 29 e7 ff ca 5d 10 fb d4')
# CWbytearray(b'39 6f f6 5f 66 c8 b2 fb b0 f6 76 eb 33 7f f9 79')
# CWbytearray(b'60 b6 10 54 8f 3f 0c 3a 79 62 60 7b 16 f5 1d a5')
# CWbytearray(b'4f eb 66 5b 70 1a 3b 00 e5 64 60 28 a8 27 3d 77')
# CWbytearray(b'ef 10 d6 82 d3 c3 46 66 f9 4a d7 fc c2 57 0a 31')
# CWbytearray(b'91 10 95 bc 15 a4 c6 b3 d7 19 2e 75 c6 1b 9e a5')
# CWbytearray(b'5e 36 16 f9 85 94 7c 0b 84 48 b5 ad 30 77 2f ae')
# CWbytearray(b'7d 33 28 90 47 db 8d ff 6a 6a 20 86 82 62 eb 14')
# CWbytearray(b'b8 02 d6 e8 7b e3 7d 98 e3 6b 04 54 a2 4e 51 0a')
# CWbytearray(b'b8 36 b8 ca 79 82 75 0c e1 d2 ca 38 68 75 2b 01')
# CWbytearray(b'2a e8 89 a4 56 f7 e2 cc 8a 2e 6d 42 90 ba 44 a7')
# CWbytearray(b'ca 6d 8e 9b ac f4 60 c8 cf ef f7 f6 4f 7e 5c ae')
# CWbytearray(b'6b 9b 21 ac 55 93 d6 d9 c2 e0 61 27 a0 9c 39 aa')
# CWbytearray(b'5a 1f a4 4e 61 7c d6 16 e9 ec 28 d8 67 ef 12 b8')
# CWbytearray(b'fa 9c 5c 80 5a e9 92 e9 eb d9 55 0b f7 ae 5e 7c')
# CWbytearray(b'11 0c c1 32 5d 86 6d b3 d1 56 a2 a7 41 4c 94 83')
# CWbytearray(b'8d e3 23 9f 22 80 8f 6a 73 ae 17 fc 67 9c 1d 0f')
# CWbytearray(b'57 7b 9f 76 c3 fa f2 5f be 0c dd 6e 8f fb f1 c9')
# CWbytearray(b'b5 5d 0c cc 37 69 17 d2 2f 60 8d 52 f0 0b df f0')
# CWbytearray(b'0f 9a 56 fe 65 ee 90 50 0a 8b ae 35 94 2f 02 b8')
# CWbytearray(b'8a ee c4 8e 71 0d 0d a7 65 0e e2 52 21 8b 6e a1')
# CWbytearray(b'80 10 c1 84 c9 fc 34 03 52 c9 86 51 c5 fa 4f 73')
# CWbytearray(b'd3 c8 af c7 53 68 9b 89 f0 0e e1 26 c7 c7 a7 27')
# CWbytearray(b'77 5f 2c 27 33 7f e0 68 1a e1 60 ce ae b4 f9 c4')
# CWbytearray(b'5d 41 93 a5 04 cb e4 90 e0 08 80 5a e1 0d 09 e6')
# CWbytearray(b'05 45 0d d0 88 04 42 68 b9 72 b8 47 bb 95 94 fa')
# CWbytearray(b'54 8b 02 a4 3d e3 04 cf 20 b4 0a fb 42 91 e8 5b')
# CWbytearray(b'e1 f3 45 be 11 10 a1 d2 e2 56 de 6a 18 f6 35 43')
# CWbytearray(b'42 c9 0f 8a 0e f7 7c ea 1a c7 80 e9 59 52 b0 db')
# CWbytearray(b'9e 45 7f 38 5c c4 bd d1 0c 19 91 3d 43 b6 3c c8')
# CWbytearray(b'1d 88 72 92 9b d1 cf 68 84 e6 76 ee d6 29 24 0c')
# CWbytearray(b'b6 08 eb 52 79 d8 e4 c8 36 50 4e 8e 40 2b a3 11')
# CWbytearray(b'c5 aa 07 cc d6 c7 b9 06 62 ec 83 76 7d 34 0e 93')
# CWbytearray(b'31 8a dd 4e 88 52 4b cd 20 bf 58 96 4e 76 c1 f2')
# CWbytearray(b'28 39 0b 7d b6 c7 02 e1 f9 ce 3a aa e7 0b 34 c5')
# CWbytearray(b'ca 86 8d f3 d8 8c bd 67 b4 f1 10 be 97 5a 9f 55')
# CWbytearray(b'64 0f 6b 64 70 06 d1 f3 09 d8 82 9c 8f 18 74 79')
# CWbytearray(b'7f 42 6c 8a 87 66 7f a9 63 f7 34 e8 9a 9c fe cf')
# CWbytearray(b'b6 c2 01 37 ac f8 fd c8 12 56 4a 1e 78 0a 99 2c')
# CWbytearray(b'f5 1a a6 6b 54 fd 35 10 81 6d 85 3c 78 df 1b 63')
# CWbytearray(b'5f 51 ea 09 b3 6f 21 aa a2 61 4a 16 4e 7b 69 4e')
# CWbytearray(b'd1 21 03 7e b7 9e e7 57 50 26 7d 56 14 7f 35 8c')
# CWbytearray(b'b1 b5 5f 37 77 f3 c7 ca f1 eb 77 62 c5 f1 b4 4e')
# CWbytearray(b'48 43 43 a6 9c 37 61 33 e1 60 a0 d1 16 e4 74 a1')
# CWbytearray(b'2d 5b 3a cd a2 e9 36 51 d3 a1 56 81 9c c2 54 da')
# CWbytearray(b'38 67 a5 5b 7d a4 68 72 ee 94 a1 16 35 86 88 e6')
# CWbytearray(b'4f 1a b4 f2 d0 e3 ac 44 6d 3b 3e 12 c5 97 3c da')
# CWbytearray(b'1f a4 fd b1 10 81 78 91 23 90 b6 40 ff 2b 32 b2')
# CWbytearray(b'7e 7b 09 ea 2d 1b ab 9a de d8 12 61 17 3f c3 3e')
# CWbytearray(b'13 b4 d2 e0 7f 22 1f 5d c1 d7 41 40 cc 5c a6 6e')
# CWbytearray(b'41 ce 12 21 35 f2 44 d9 4d 72 f6 24 d8 38 5a 1b')
# CWbytearray(b'5a 5d 6d 87 39 b4 bc fc 77 c0 21 c0 cb 0f 8b 56')
# CWbytearray(b'75 a4 88 dc b0 a5 c7 be 09 41 33 db 21 d8 60 2e')
# CWbytearray(b'24 bd be 0f 98 bc 1c eb 5b 4e 6f a6 55 73 1e 51')
# CWbytearray(b'49 66 e8 de 50 65 3e d5 e8 b9 26 ed 84 08 85 11')
# CWbytearray(b'f1 6b 8f 04 62 ea ec c7 75 1d e8 ea 65 68 4d 27')
# CWbytearray(b'4f ec ed 4c 6b 7d 27 83 a7 2d ae 49 61 52 74 e7')
# CWbytearray(b'3c ad 92 5c 09 42 c6 81 ef ec 08 a7 80 89 00 eb')
# CWbytearray(b'e2 87 51 a7 da 9e b1 83 a6 18 51 88 1d 7b 4b 38')
# CWbytearray(b'17 60 f0 d2 ba 81 39 a6 5b ee 88 0f 7d 96 c0 fd')
# CWbytearray(b'2b a5 9f 0e 1b 8a 27 5a 02 79 24 79 17 0b b3 f0')
# CWbytearray(b'84 8e be 91 23 8a 05 93 97 c7 4f 33 50 c0 4a 66')
# CWbytearray(b'7e b7 0f 70 2e 15 34 f0 30 9d a0 4b 69 37 8a f5')
# CWbytearray(b'5f ef dd 62 a9 8e a0 f2 57 1b 02 da 4f 83 14 22')
# CWbytearray(b'da ce 32 27 81 a7 69 6a 94 5c 4d 35 8a af ee 47')
# CWbytearray(b'da ef c8 f9 44 e9 a6 df d4 52 23 67 18 b1 c9 02')
# CWbytearray(b'ee b2 40 71 9d 49 d6 37 00 52 43 e9 2c 19 cf 80')
# CWbytearray(b'95 c1 10 3b 0c 38 71 2d 05 d2 b5 39 63 fe 6b c9')
# CWbytearray(b'a9 6f 87 c6 8e b9 83 d3 3c 56 8a 13 1b 3e 5f d1')
# CWbytearray(b'5e c7 45 9e 8b ef f9 63 be 6d 7c 5c 5a f9 8b 57')
# CWbytearray(b'7c c4 6f f7 8d 27 15 7d 87 b7 d2 68 37 d8 88 e0')
# CWbytearray(b'4d 88 95 83 87 69 0f d9 46 5e 28 b9 06 da 4c b0')
# CWbytearray(b'88 f0 84 ea e6 d0 b5 9f 38 a5 15 ca 71 ba 6d 67')
# CWbytearray(b'76 39 3b dd b6 b3 b8 bc 6a 98 88 42 ef 30 68 f6')
# CWbytearray(b'a9 61 98 ca 84 ba b9 4f 0d 81 ee 98 38 19 31 b1')
# CWbytearray(b'6d 5d 6e 08 4c 33 e8 7e da b2 3b bd 77 70 97 32')
# CWbytearray(b'd8 a4 d8 08 d0 3b 0c 5e 19 00 de ce dc 02 54 4a')
# CWbytearray(b'01 2a 51 46 b2 49 7a b9 32 95 fb 54 ed 58 4d 2f')
# CWbytearray(b'dc 85 a1 f6 a6 28 80 0f 6e 7f e5 66 8d 72 a5 ed')
# CWbytearray(b'aa 24 3b 13 f6 02 2f 8a a4 8d 7b 03 f8 e1 26 9a')
# CWbytearray(b'03 c3 b2 6e f3 80 41 8b 9d e5 33 e1 15 67 c5 7b')
# CWbytearray(b'91 23 0e 0e 53 43 78 94 dd 57 ec 98 6f c3 7a e8')
# CWbytearray(b'ee dc 10 83 30 29 ba 2a ad a8 b8 23 34 79 af d6')
# CWbytearray(b'c2 bd 47 b4 c4 68 2a d7 dc 1b 3f fa d1 66 f4 4e')
# CWbytearray(b'3f ff 15 ca b5 96 63 cd d2 84 6f 74 6a 8c 8a 71')
# CWbytearray(b'51 cf ae 28 83 73 19 91 d7 e3 2c 76 dc 53 66 74')
# CWbytearray(b'b3 94 bd ee 15 34 8b 1e d4 86 76 93 2c 3d fa 7a')
# CWbytearray(b'cd 6d 6d 1f 38 2b 70 50 3b 9a a4 18 7e 77 cd b0')
# CWbytearray(b'ff b0 59 d5 c5 bf 55 d7 93 22 e0 e4 77 44 a6 50')
# CWbytearray(b'10 47 79 4a b1 58 fe 38 df 9d ed 88 2f e4 e8 cc')
# CWbytearray(b'23 73 d1 0d cb 83 2b 4a e2 f0 f8 e7 35 0d e9 b9')
# CWbytearray(b'44 ff 38 66 f5 98 65 aa 95 20 f2 eb c3 c6 c3 51')
# CWbytearray(b'82 6d 52 b2 14 e6 e8 87 be f6 9f ab bc 5d 88 08')
# CWbytearray(b'3a be 43 56 9f aa 8d c8 de 25 30 61 85 7a ec 52')
# CWbytearray(b'52 3a 9d bc 73 9b 82 c5 0b f8 11 71 06 75 ec 84')
# CWbytearray(b'c8 82 1d a0 18 50 b8 28 5c bb a3 c8 bb 82 e8 23')
# CWbytearray(b'20 32 42 34 a8 61 56 4c e7 37 8b 5e 2f 67 99 ad')
# CWbytearray(b'8c 6a 35 82 01 ad 2c cb 70 69 3e 92 62 56 40 8e')
# CWbytearray(b'd2 1b 56 1e 06 4c 54 ed 23 52 1a 62 fb 20 b8 89')
# CWbytearray(b'db 32 81 2f 7e 3d 23 bd 0e 95 b0 29 24 1f 06 2e')
# CWbytearray(b'ab 66 0b 2a 82 02 49 a6 79 99 c4 90 70 4b 24 53')
# CWbytearray(b'f1 21 a8 e9 a3 64 ea c8 67 14 65 4b 62 4b c7 cc')
# CWbytearray(b'f3 0b 82 7b 2f 21 f7 c6 8f 67 69 bf db 68 bc 19')
# CWbytearray(b'df c9 37 75 70 11 d4 86 50 97 00 76 ca 0f 98 70')
# CWbytearray(b'47 93 70 16 78 8d 29 e1 09 5d 7a 4f c1 69 ad 5c')
# CWbytearray(b'5a 63 12 64 e1 f7 89 25 23 7e 2b 3d 42 50 d3 c7')
# CWbytearray(b'ef 54 51 75 53 1c e8 6c f2 4a 3d d9 d4 bb 25 34')
# CWbytearray(b'37 0f 1a 41 c3 d7 79 00 02 b1 52 5d 2c 45 75 cc')
# CWbytearray(b'fa 83 b6 1d 05 4b ed e3 24 c2 f6 1a 70 83 a1 be')
# CWbytearray(b'c6 0d de 6d 1a 87 c5 c4 9c e7 05 1e 27 d8 76 eb')
# CWbytearray(b'51 89 9b 15 b4 db e4 53 75 fb e1 19 4e 1d 01 a2')
# CWbytearray(b'68 eb 21 77 c3 47 d1 bc 62 a1 a8 d7 c2 66 1a d0')
# CWbytearray(b'59 e8 74 15 81 0b 84 e2 d1 db 11 21 51 0e 7b 58')
# CWbytearray(b'b7 23 f3 69 e3 05 97 8e 67 a0 f2 e9 aa 96 9d 8c')
# CWbytearray(b'62 3d 0d 74 c0 5a d3 fb 66 68 b9 d6 e7 ff d9 dd')
# CWbytearray(b'd8 16 81 d2 26 e4 7b ed 56 48 d9 13 9f a4 91 d6')
# CWbytearray(b'ee c7 f3 67 93 4b 55 a6 73 21 8a 3d 41 af 28 46')
# CWbytearray(b'17 7f 2e bf a1 70 1f 2a 8d db c2 c9 27 8b 86 72')
# CWbytearray(b'92 63 8b 21 71 79 0c 03 c2 7f c6 11 3d de de 87')
# CWbytearray(b'38 08 4d 70 bc 09 48 97 d4 b8 cf f0 d4 ba 37 f4')
# CWbytearray(b'fd 5e a4 ef fc 8a 4a f9 6c 5d 07 1a 6c 44 ef 40')
# CWbytearray(b'e6 b3 be c3 75 b7 9b b8 62 af c4 b7 1e 2d 34 8b')
# CWbytearray(b'25 3a ee 80 da 03 4a cc 65 63 fc c0 9b 24 82 c2')
# CWbytearray(b'87 fb 07 32 56 3a 24 7f 66 71 13 09 43 e7 6f 59')
# CWbytearray(b'4e f3 11 fa 8c c3 52 98 d8 04 be 68 28 c3 2f b9')
# CWbytearray(b'41 cc 17 da 93 66 0d d4 76 c8 6a 46 15 a8 8c c1')
# CWbytearray(b'c0 65 95 f0 5c d6 b6 56 4a c9 80 5f 98 90 ed e2')
# CWbytearray(b'61 37 6a 40 7d 6e 30 59 a8 c8 bc e7 35 3e d2 e0')
# CWbytearray(b'df a4 bf 70 b0 89 e0 9c 41 17 6b 51 92 df 6b 3f')
# CWbytearray(b'11 b8 56 e5 29 5d 73 33 53 b6 1d dd 3a 61 79 dc')
# CWbytearray(b'26 61 1a 42 17 53 32 01 ff c9 e2 e0 80 1d 27 f9')
# CWbytearray(b'3c f8 16 0b 81 78 44 49 d6 31 7f 63 2e 21 98 ac')
# CWbytearray(b'72 1f 43 2b 46 37 26 db 29 68 01 d1 7b b4 6e f3')
# CWbytearray(b'db a2 48 e6 f3 e6 10 e4 1b 21 7c 89 33 41 d8 ba')
# CWbytearray(b'64 4f 46 c3 5b b5 fa fd ba 32 b8 e3 16 0e c0 74')
# CWbytearray(b'4e 74 77 04 6c 36 74 3e f3 94 d7 09 c7 ff 5b 63')
# CWbytearray(b'5f 30 85 96 f5 a9 bc c4 1f dd 3a 1f 12 8d d2 6a')
# CWbytearray(b'53 ee 05 c2 53 ed 70 2c 74 5f 25 8d 86 68 e5 f9')
# CWbytearray(b'a2 11 82 71 7b 99 6e ee c9 24 3c 8f 7d 78 c7 7f')
# CWbytearray(b'ed 3f a9 b5 24 40 57 dd 64 cb a9 c6 c1 18 07 cf')
# CWbytearray(b'e4 0c 25 e5 28 8a 26 ca 91 0d 38 41 53 9c b6 b2')
# CWbytearray(b'74 44 81 62 1e fc f4 a6 9c 01 3e 21 4c 4d 15 7c')
# CWbytearray(b'6e ba fa a6 2e 6c e7 75 10 81 42 73 29 d0 0f 39')
# CWbytearray(b'93 6f d6 c1 08 56 ef 4f 97 48 69 36 10 0c a4 24')
# CWbytearray(b'89 08 bf 9b 74 dd b8 ae 1d 9c ac 33 18 82 50 d6')
# CWbytearray(b'b6 31 b6 0f 91 12 01 c0 ae 99 71 fd 97 41 e0 77')
# CWbytearray(b'4c 6b 09 49 5f 09 80 3f f3 8f 53 63 cc a9 b8 d9')
# CWbytearray(b'56 cf 08 a2 38 e5 64 1b 2d 76 dc 6c 43 fe cc ff')
# CWbytearray(b'16 2b 68 a9 c7 3f 04 f1 24 bf ee 5f 6c a6 88 5a')
# CWbytearray(b'dc 84 74 2b 01 65 56 ac 52 38 71 13 41 41 3a 04')
# CWbytearray(b'f3 ca 48 b7 69 98 22 70 7c 26 dd 28 8c cb 0d ad')
# CWbytearray(b'96 9d a3 a5 1b ae f4 21 49 9c c5 f4 7a 4e b7 65')
# CWbytearray(b'ba 95 ce f6 01 e2 8e 61 99 09 fb 86 f7 be a4 39')
# CWbytearray(b'35 59 ac ab 67 ab 0c 50 55 36 70 03 8f 52 4b 34')
# CWbytearray(b'b9 8d 14 60 ed 1d c0 29 c3 47 6f a0 95 74 5c 80')
# CWbytearray(b'9e e2 a9 98 97 c0 10 43 4d fd 11 8d 77 2b 28 5d')
# CWbytearray(b'15 2a 9f 80 d7 d3 25 4d b1 7d 2f ac b7 e2 1b e4')
# CWbytearray(b'4d 11 57 52 db 7f 7a 0e 1d 51 24 b5 39 fc 81 28')
# CWbytearray(b'90 58 64 e4 14 04 41 0b 1d a8 f7 d2 36 48 38 bf')
# CWbytearray(b'a6 4c 97 32 00 0f d7 6e 80 a5 b3 04 68 9a 8b 91')
# CWbytearray(b'de 03 24 a3 f8 d7 1a f1 b0 26 d6 55 b7 45 0e f6')
# ...
# CWbytearray(b'5c 58 4b c5 58 55 e2 db 90 08 4e 81 d8 72 fa 67')
# CWbytearray(b'ef 34 0e db a8 93 7a eb 13 d1 0d 19 f7 fb 90 1b')
# CWbytearray(b'60 fd 7d ee 89 b4 ac 7c 9e c6 c7 71 0f 46 b9 00')
# CWbytearray(b'ac 51 6b 0d 0e f4 b6 a8 f9 e6 90 c8 41 a1 9b fb')
# CWbytearray(b'f3 07 62 46 99 d3 3e 37 e7 3a 8f a2 13 1f dd 2a')
# CWbytearray(b'1a 6e c2 5a 8a 4c c4 a5 ff 27 f9 83 dc 66 66 eb')
# CWbytearray(b'1b fc c9 e2 7e ba 6e 20 14 6e fa 57 40 1e 4c d5')
# CWbytearray(b'a7 2e 0c 99 75 55 be eb 44 cc 57 e4 15 c2 8e d2')
# CWbytearray(b'4e 9d df e7 08 eb a1 f5 ef 92 68 e7 11 c1 62 60')
# CWbytearray(b'a8 01 47 d2 09 98 8a 4c e5 29 b3 c6 5b 2c fe 81')
# CWbytearray(b'9a 9d 52 33 9c c8 69 6c 03 20 60 46 90 9a 52 60')
# CWbytearray(b'75 05 71 3e 2d 2f 42 e0 82 2e ba 58 52 29 af ad')
# CWbytearray(b'f6 76 0d 16 2d 76 e8 76 16 49 60 31 cc c1 f0 6c')
# CWbytearray(b'aa 1f 9d 11 23 75 0d 9f cf 8e fd d1 f2 b3 91 aa')
# CWbytearray(b'43 41 3a d0 8a a6 36 99 62 4e 28 e7 18 87 ac ba')
# CWbytearray(b'2b b8 48 97 e6 11 77 6a 80 f7 6b aa bc f9 87 3a')
# CWbytearray(b'24 9a 86 c7 a3 72 c0 a6 74 3f 91 31 26 09 7c 46')
# CWbytearray(b'85 20 8c 8f c4 4d 35 4c 6e 91 e9 49 6a 61 f5 5b')
# CWbytearray(b'b4 d3 05 64 6c 76 dd 48 a0 ab 7e e5 e0 67 6e 02')
# CWbytearray(b'ec ed a7 33 90 e0 d3 54 b3 64 c7 79 ac a1 f5 96')
# CWbytearray(b'ff 38 6f 55 ca a3 1a 2a 23 4e a2 e6 1e f2 6d b1')
# CWbytearray(b'34 cd 8f 03 2a 95 84 00 59 c0 b5 eb bf 3e 45 60')
# CWbytearray(b'3b 59 ba 08 4c 1f 25 96 c7 12 35 61 33 a9 ac 04')
# CWbytearray(b'38 13 56 44 6a 10 da dd 8e ee 42 ae f2 9f c1 69')
# CWbytearray(b'1f 33 04 4b f0 1c 73 c8 05 f3 da 9a d7 ee 5a af')
# CWbytearray(b'ed 38 b1 6a 27 4e a6 67 7c a1 05 e2 a8 ab c7 98')
# CWbytearray(b'64 d3 3c 13 c3 96 f0 ae c3 85 4a d2 50 8f dc bf')
# CWbytearray(b'5e d7 06 10 5b 69 fa fe 3f 47 04 1a 71 42 67 34')
# CWbytearray(b'a8 2c 8f 03 e6 c1 3d ae 3a 3c b4 7a eb 7c dd 23')
# CWbytearray(b'f4 d9 72 de a5 42 66 02 00 db db 63 bc 15 70 a3')
# CWbytearray(b'1a 91 a0 18 af 12 40 58 5c d6 61 d4 21 3b 0c 0b')
# CWbytearray(b'e9 19 88 9e 8d 47 be ca 37 03 ad be fc 0e 37 df')
# CWbytearray(b'ea 4c 6a 4f f2 b3 1c 0d 62 35 fb aa 65 b4 f0 c8')
# CWbytearray(b'81 6b 17 fa fc 97 15 c5 06 e9 68 5b 1c 0c ed 82')
# CWbytearray(b'dc a0 81 0d 55 47 db 06 c8 fe 8f 82 05 87 31 9a')
# CWbytearray(b'b3 b9 5a c1 4f ea 90 45 db ad e4 78 d1 72 61 be')
# CWbytearray(b'6d db ce b7 60 75 3f 05 20 c9 da cb 30 a9 cf b2')
# CWbytearray(b'3a db f7 08 a0 f6 f9 fa 12 a7 8e 74 bd 2a a4 98')
# CWbytearray(b'e1 1e 49 66 13 31 fe 51 f4 01 a0 b5 3e de 5b b0')
# CWbytearray(b'44 bb 74 90 b4 85 f4 68 8b 4e f0 86 43 d7 a8 af')
# CWbytearray(b'8a 3c 5f 5b 92 08 db 62 37 13 3c 15 86 61 9d 91')
# CWbytearray(b'04 b1 fd f4 b3 01 7c 6e 5f 37 95 ac 5b b8 87 b1')
# CWbytearray(b'd2 ce 5e 16 be 96 d3 dd bc 5d 04 14 39 a0 e0 9c')
# CWbytearray(b'de cd ec ac 8f 72 92 12 28 06 87 e8 42 7a 5e d0')
# CWbytearray(b'92 8d 48 40 89 d6 2e 03 e6 0d ce 37 5f 1c 18 72')
# CWbytearray(b'76 e0 1a 63 ba 88 78 59 73 7c d0 32 10 4c e5 46')
# CWbytearray(b'6c 6f ad d3 c4 03 99 2c b0 f1 17 5b 1b 8f 8c 87')
# CWbytearray(b'c5 4e 83 43 e2 28 ef 73 49 de 2e ef 68 6d 37 1c')
# CWbytearray(b'1a ed ce 35 b8 e2 cd 5b 5e 5b 97 9e b2 6f 6b 9e')
# CWbytearray(b'5d fe 34 65 af 1a 22 a4 b1 ee 9b 3a 34 74 c2 9b')
# CWbytearray(b'22 dd 70 45 2e 9e 5b f7 d8 65 06 c3 08 10 b7 71')
# CWbytearray(b'57 37 79 77 31 d3 59 fe c3 dd b9 da 92 35 ef 99')
# CWbytearray(b'c4 cd ec 5e d9 c3 59 66 d0 86 1a 30 b1 ab 2e fa')
# CWbytearray(b'86 d1 a6 7c bd fd 6f 8e 8d 83 a4 f0 a5 46 43 8f')
# CWbytearray(b'14 c1 37 16 b5 11 93 95 a2 3f b4 c8 b6 6f 37 63')
# CWbytearray(b'46 18 47 df f1 ca bc bb 60 d2 d8 4a e9 a7 d7 ca')
# CWbytearray(b'df 13 87 f3 0f a0 ea 61 6a 46 e4 9d 81 33 64 9c')
# CWbytearray(b'b4 9c 5f ba a4 81 6e bb 7b 38 af 81 7b 70 6c 8e')
# CWbytearray(b'91 97 76 57 1b 59 34 68 f9 cb ac 8c 68 bb 08 ee')
# CWbytearray(b'a3 88 96 18 fb 49 14 40 30 0f eb 96 9a 93 bd 2b')
# CWbytearray(b'0d de 05 36 c7 13 28 19 2a 86 f6 e3 48 f8 ff fa')
# CWbytearray(b'29 4f 17 38 ae 9a f5 64 81 e0 b3 c6 a8 07 a4 10')
# CWbytearray(b'8b cf d0 ea 1f 5a 18 b3 ad 34 5a 17 a2 4f 5a 4d')
# CWbytearray(b'9d dc e9 fb 56 83 7b cb 25 05 f2 82 54 30 03 7e')
# CWbytearray(b'88 2c 70 88 4d 46 7a 6f bb 87 6b 7d 25 d8 22 08')
# CWbytearray(b'f4 e6 af ae 36 35 c4 50 7c f3 23 af e1 27 bb 61')
# CWbytearray(b'13 40 23 9a ab c1 ae f8 ad 27 d1 32 cd af d1 6e')
# CWbytearray(b'e7 e1 e1 42 a6 ca 93 a5 bd 86 fb 72 cb fd fe 70')
# CWbytearray(b'66 44 30 d5 b7 bb 24 17 41 ec 72 4e ce e7 af ee')
# CWbytearray(b'd9 f0 03 73 13 f9 e7 e7 f7 19 b0 ac 21 85 60 d5')
# CWbytearray(b'ba 1a 40 10 f9 19 f6 2d 85 31 0e 9d 75 67 40 8e')
# CWbytearray(b'f7 59 42 3c b4 c8 ee 5e 7c eb d4 e5 1d 60 fa 87')
# CWbytearray(b'd5 14 aa 16 60 c1 50 34 fd 5e fb 9d e4 df c4 9a')
# CWbytearray(b'6e cc 66 32 35 b8 a0 62 aa 48 ba b2 89 40 5c f5')
# CWbytearray(b'24 c6 e4 3f ce 0f f8 db 8e 70 7a 12 8c 37 65 c6')
# CWbytearray(b'23 1f e8 aa bb b6 a6 4c 35 9c b7 cc 62 45 f0 d5')
# CWbytearray(b'29 60 19 b5 b6 a7 84 d1 ca 7a a0 08 55 f9 d5 2f')
# CWbytearray(b'9d a2 81 d3 02 f4 8b c9 1c 0e 73 fe b7 f7 c3 8c')
# CWbytearray(b'b0 1c e4 f0 28 9c a8 4d b6 3f db 34 6d 9b ef 1c')
# CWbytearray(b'0e d1 7b 6f 7f 3e d2 d5 44 2a 93 d7 83 b9 3f 6e')
# CWbytearray(b'b8 59 60 7e fc b2 99 a6 42 7d 6c 8e a9 93 dc ab')
# CWbytearray(b'cc fa 6c f5 fb bc 45 c3 bd 67 cf a7 86 ea 32 1d')
# CWbytearray(b'26 cb 20 48 f7 b9 1f 6e 1f e9 62 4b 21 0c 21 c6')
# CWbytearray(b'dc 39 c6 ba 27 73 79 14 e1 fd 74 1e 8d 00 53 3b')
# CWbytearray(b'c5 38 4b bd 30 16 42 72 de 13 b7 64 34 98 15 14')
# CWbytearray(b'97 c9 67 5a f7 f9 83 05 1b fc 06 69 ef 8a c8 db')
# CWbytearray(b'ac 79 4e 3d 42 97 21 f5 e0 0d 7f db 45 42 a6 9b')
# CWbytearray(b'0d 5c 5d a3 e1 40 35 f9 37 a8 69 ac d3 37 54 37')
# CWbytearray(b'2e 93 d4 09 e8 26 37 ee c8 21 33 2f 05 a5 a1 50')
# CWbytearray(b'04 d2 e7 50 ce 19 ff d6 66 58 e5 77 31 25 03 33')
# CWbytearray(b'89 00 0f 22 c2 30 ca 25 03 fb d4 5f bb 2b f3 ba')
# CWbytearray(b'27 5b 4e 63 81 67 d1 5e 5c c0 4c 4a 6c fe d0 a6')
# CWbytearray(b'dc 44 d4 36 f5 e8 15 54 43 fc 19 84 c6 9a f1 b0')
# CWbytearray(b'4b 9f f5 45 99 9a a7 21 86 ef 41 09 61 6c e5 66')
# CWbytearray(b'85 a3 6c 83 57 a3 2c 1b f5 e2 f6 60 28 28 e0 e4')
# CWbytearray(b'a2 a4 0a d5 9b 5c 90 5c e9 a1 4c ca c4 53 40 76')
# CWbytearray(b'48 96 31 66 40 53 ff 95 e2 e6 4f 31 04 71 ae 59')
# CWbytearray(b'b9 6b 96 46 bd a2 16 c1 0d 63 55 8f cf ef 4e ab')
# CWbytearray(b'b4 f9 e2 2a aa d0 3f 00 60 2a 5e ca ae 24 f1 ee')
# CWbytearray(b'97 ec b4 70 9a f4 26 8a 77 ed 05 e6 b4 ce 5b 3b')
# CWbytearray(b'66 3a 89 cb ca 77 9d 92 00 8b c0 c8 b3 3f bf d9')
# CWbytearray(b'd0 24 ce bf 85 ee 5d c2 47 f3 89 a8 8d a8 06 5d')
# CWbytearray(b'e7 3c 7a b0 99 86 ab 60 a3 5f 8d ac 03 02 2e 0c')
# CWbytearray(b'd8 0a e8 9c fc 6a 6b 97 13 30 de 3c 8f 5b 51 0f')
# CWbytearray(b'30 f0 a8 86 20 90 fa 92 81 bd 44 c7 77 a7 e7 93')
# CWbytearray(b'40 4c 55 7c 3d 64 4b 5d 01 b8 c8 8d 8e 2d 11 bc')
# CWbytearray(b'32 45 48 c4 d4 7b b0 ec f3 28 3b 6d 54 82 57 32')
# CWbytearray(b'a4 b7 a6 3e eb 4e da e0 c4 fa 1e ed 3a 32 7f 0f')
# CWbytearray(b'96 24 5c 41 3a 81 29 7c 51 47 52 b5 d6 7e a3 db')
# CWbytearray(b'ef 07 b2 c9 97 45 a7 ab d8 64 fe 3c a9 21 1f ce')
# CWbytearray(b'df c6 e8 a7 b9 a3 0e 4c b8 c7 03 01 ff 0c 2a b4')
# CWbytearray(b'07 d8 30 c6 eb d2 13 c9 b6 a0 54 f6 b8 dd 27 a4')
# CWbytearray(b'43 af bf 49 b2 ee 96 24 01 a8 59 b0 88 01 77 69')
# CWbytearray(b'88 ad 66 9c 00 36 06 21 ee 0c 97 1e 82 26 e1 b7')
# CWbytearray(b'ff 03 a6 64 d1 44 c9 f8 15 f9 d9 90 97 9b e2 8e')
# CWbytearray(b'6f a4 92 02 6e 93 dc 35 72 b0 5d 21 4a 42 71 9b')
# CWbytearray(b'1b 65 79 53 f6 b9 99 9d 59 56 59 d5 7d b4 52 78')
# CWbytearray(b'b2 1a 52 9f af 49 4a 7a c3 e7 a0 c9 65 b7 7e e0')
# CWbytearray(b'c3 3c 68 a4 8d 83 c2 b0 51 1c b0 e9 f1 4f a5 14')
# CWbytearray(b'57 47 95 b5 25 1b 50 b6 4e ee a5 ca 9e cc 09 ef')
# CWbytearray(b'fa 88 4d 98 db 39 94 d6 21 57 d8 b5 0a 8f 3c d1')
# CWbytearray(b'2c 2b bc 34 5e 8e 3e 9c 24 6a eb 0d ea ed 7b 75')
# CWbytearray(b'f2 c6 7f 81 b5 ef d1 4b 40 14 b6 6d fd 27 75 20')
# CWbytearray(b'80 9d ce 6c 60 9c 3f e7 cf 7b 6e 8f b6 7b 9f f3')
# CWbytearray(b'f7 86 cf c5 66 83 c6 ca e1 01 ad 5e 2b 2f 71 2e')
# CWbytearray(b'ff 6f 4f c2 0d 02 ba 90 50 5a aa 3b 93 c0 d3 00')
# CWbytearray(b'c0 25 88 20 2a c9 1d 55 2b c3 77 e7 8b c9 54 7d')
# CWbytearray(b'f0 79 ee e2 c7 4c e7 0c 1d a3 7d 71 19 60 b5 ef')
# CWbytearray(b'ca 1f 38 98 48 db 02 19 66 4b f3 b7 78 a1 e8 78')
# CWbytearray(b'28 5c f4 ef 96 c5 fd a2 6e 76 ca 04 8a 54 a5 69')
# CWbytearray(b'65 be 63 14 cd 04 3e 1c 1a ab 0d 04 98 da 92 61')
# CWbytearray(b'f9 fc bc 14 7f 4e c6 f3 47 c5 a2 96 55 1d 00 62')
# CWbytearray(b'53 e1 a0 ff 8f 1b 53 13 bb 4d c3 a7 dd f6 5c b2')
# CWbytearray(b'3a c2 1a 21 a8 a2 2e 61 b0 8b 46 7e 24 c6 6c 94')
# CWbytearray(b'c5 76 6c 42 39 ee 92 51 0b d4 ea 5d d2 b2 af e9')
# CWbytearray(b'd7 11 0f 3a 45 91 0e ea 92 a3 7a a8 7f d3 c5 41')
# CWbytearray(b'a1 0a 72 5f 34 a4 ec fd af e0 ea 3f 37 4d 22 e8')
# CWbytearray(b'77 61 f2 40 00 c1 af e4 44 a8 6c 08 e8 2a e3 ec')
# CWbytearray(b'12 eb 38 e7 14 92 72 ef a8 e7 85 66 b4 4a 98 cd')
# CWbytearray(b'33 0e f9 ca 0c 0c 94 37 e4 7b a6 82 f8 32 38 1e')
# CWbytearray(b'3a 09 43 32 9a 5a 0f 27 f2 22 b7 0a 31 ac 2a 94')
# CWbytearray(b'ee 82 45 db 6a 8c cc 28 9a 2a 14 ef 0d 8d 08 46')
# CWbytearray(b'ae 08 65 03 5f 69 4b 2a 25 18 c5 be 34 0a 4a a9')
# CWbytearray(b'e7 e0 d1 0e af 51 83 91 14 64 f0 6f bc fa 52 58')
# CWbytearray(b'23 be fa c0 6f 48 2f 65 dd 75 f0 2d e1 b1 d1 82')
# CWbytearray(b'4c 1e d9 5e 89 45 97 87 92 f6 ca ac d1 5f 67 ef')
# CWbytearray(b'a0 2b ed 40 e1 4e 64 24 9a 23 ab 6c d5 7a 61 12')
# CWbytearray(b'c9 56 bd 29 30 a7 2e f1 0f 75 9d 04 61 33 27 3f')
# CWbytearray(b'18 b7 1a 86 f8 28 bb b5 5f 79 bb 35 a9 bd df 40')
# CWbytearray(b'16 18 f1 f5 cf 6c 3b a7 db 38 ae 17 0e 6b d6 be')
# CWbytearray(b'28 dc bb 42 3b d8 2e c8 8d cf 0c ea e3 52 97 29')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 34
#      31 textin.append(text)
#      32 keys.append(key)
# ---> 34 ret = cw.capture_trace(scope, target, text, key)
#      35 if not ret:
#      36     print("Failed capture")
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\__init__.py:501, in capture_trace(scope, target, plaintext, key, ack, poll_done, as_int, always_send_key)
#     498 if key:
#     499     target.set_key(key, ack=ack, always_send=always_send_key)
# --> 501 scope.arm()
#     503 if plaintext:
#     504     target.simpleserial_write('p', plaintext)
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\capture\scopes\OpenADC.py:803, in OpenADC.arm(self)
#     799 self.advancedSettings.armPreScope()
#     801 self.sc.arm()
# --> 803 self.advancedSettings.armPostScope()
#     805 # For Husky, scope.adc parameters must be cached before startCaptureThread turns on fast read mode,
#     806 # because we won't be able to read them from the FPGA once fast read mode is turned on:
#     807 if self._is_husky:
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\capture\scopes\cwhardware\ChipWhispererExtra.py:2252, in ChipWhispererExtra.armPostScope(self)
#    2250 def armPostScope(self):
#    2251     if self.enableGlitch:
# -> 2252         self.glitch.armPostScope()
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\capture\scopes\cwhardware\ChipWhispererGlitch.py:1237, in ChipWhispererGlitch.armPostScope(self)
#    1235 """Called after scope trigger is armed"""
#    1236 if self.getArmTiming() == 2:
# -> 1237     self.glitchArm()
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\capture\scopes\cwhardware\ChipWhispererGlitch.py:1209, in ChipWhispererGlitch.glitchArm(self)
#    1207 def glitchArm(self):
#    1208     """If trigger is set to single-shot mode, this must be called before the selected trigger occurs"""
# -> 1209     self.glitchManual()
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\capture\scopes\cwhardware\ChipWhispererGlitch.py:1201, in ChipWhispererGlitch.glitchManual(self, _)
#    1196 def glitchManual(self, _=None):
#    1197     """
#    1198     Cause a single glitch event to occur. Depending on setting of scope.glitch.repeat this may mean
#    1199     multiple glitches in a row
#    1200     """
# -> 1201     resp = self.oa.sendMessage(CODE_READ, "CLOCKGLITCH_SETTINGS", Validate=False, maxResp=8)
#    1202     resp[5] = resp[5] | (1 << 7)
#    1203     self.oa.sendMessage(CODE_WRITE, "CLOCKGLITCH_SETTINGS", resp, Validate=False)
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\capture\scopes\_OpenADCInterface.py:290, in OpenADCInterface.sendMessage(self, mode, address, payload, Validate, maxResp, readMask)
#     288 address = self._address_str2int(address)
#     289 if mode != CODE_WRITE:
# --> 290     return self.msg_read(address, maxResp)
#     291 self.msg_write(address, payload)
#     292 if Validate:
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\capture\scopes\_OpenADCInterface.py:214, in OpenADCInterface.msg_read(self, address, max_resp)
#     211         scope_logger.warning("The error trace below will show you what led to this:")
#     212         raise ValueError
# --> 214     data = self.serial.cmdReadMem(address, max_resp)
#     215 else:
#     216     self._send_msg_hdr(CODE_READ, address, 0)
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\hardware\naeusb\naeusb.py:889, in NAEUSB.cmdReadMem(self, addr, dlen)
#     883 def cmdReadMem(self, addr : int, dlen : int) -> bytearray:
#     884     """
#     885     Send command to read over external memory interface from FPGA. Automatically
#     886     decides to use control-transfer or bulk-endpoint transfer based on data length.
#     887     """
# --> 889     return self.usbserializer.cmdReadMem(addr, dlen)
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\hardware\naeusb\naeusb.py:635, in NAEUSB_Backend.cmdReadMem(self, addr, dlen)
#     633 dlen = int(dlen)
#     634 if dlen < NAEUSB_CTRL_IO_THRESHOLD:
# --> 635     data = self._cmd_readmem_ctrl(addr, dlen)
#     636 else:
#     637     data = self._cmd_readmem_bulk(addr, dlen)
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\hardware\naeusb\naeusb.py:617, in NAEUSB_Backend._cmd_readmem_ctrl(self, addr, dlen)
#     611 """Reads data from the external memory interface over the control-transfer endpoint.
#     612
#     613 Returns:
#     614     The received data.
#     615 """
#     616 self._cmd_ctrl_send_header(addr, dlen, self.CMD_READMEM_CTRL);
# --> 617 return self.readCtrl(self.CMD_READMEM_CTRL, dlen=dlen)
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\hardware\naeusb\naeusb.py:561, in NAEUSB_Backend.readCtrl(self, cmd, value, dlen)
#     559 if dlen > NAEUSB_CTRL_IO_MAX:
#     560     naeusb_logger.error("The naeusb fw ctrl buffer is 128 bytes, but len(data) > 128. If you get a pipe error, this is why.")
# --> 561 response = self.handle.controlRead(0xC1, cmd, value, 0, dlen, timeout=self._timeout)
#     562 naeusb_logger.debug("READ_CTRL: bmRequestType: {:02X}, \
#     563             bRequest: {:02X}, wValue: {:04X}, wIndex: {:04X}, data_len: {:04X}, response: {}".format(0xC1, cmd, \
#     564                 value, 0, dlen, response))
#     565 return response
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\usb1\__init__.py:1426, in USBDeviceHandle.controlRead(self, request_type, request, value, index, length, timeout)
#    1424 # pylint: enable=undefined-variable
#    1425 data, data_buffer = create_binary_buffer(length)
# -> 1426 transferred = self._controlTransfer(
#    1427     request_type, request, value, index, data, length, timeout,
#    1428 )
#    1429 return data_buffer[:transferred]
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\usb1\__init__.py:1379, in USBDeviceHandle._controlTransfer(self, request_type, request, value, index, data, length, timeout)
#    1377 def _controlTransfer(
#    1378         self, request_type, request, value, index, data, length, timeout):
# -> 1379     result = libusb1.libusb_control_transfer(
#    1380         self.__handle, request_type, request, value, index, data, length,
#    1381         timeout,
#    1382     )
#    1383     mayRaiseUSBError(result)
#    1384     return result
#
# KeyboardInterrupt:

# %%
np.save('./AES_%s.npy'%Trojan_ID , traces)

# %%
from datetime import datetime
import os

now = datetime.now().strftime('%Y.%m.%d-%H.%M.%S')
os.mkdir(now)

traces_array  = np.asarray([traces.wave for trace in traces])
textin_array  = np.asarray([traces.textin for trace in traces])
textout_array = np.asarray([traces.textout for trace in traces])
keylist_array = np.asarray([traces.key for trace in traces])

np.save('%s/%s_traces'%(now, now), traces_array)
np.save('%s/%s_textin'%(now, now), textin_array)
np.save('%s/%s_textout'%(now, now), textout_array)
np.save('%s/%s_keylist'%(now, now), keylist_array)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 7
#       4 now = datetime.now().strftime('%Y.%m.%d-%H.%M.%S')
#       5 os.mkdir(now)
# ----> 7 traces_array  = np.asarray([traces.wave for trace in traces])
#       8 textin_array  = np.asarray([traces.textin for trace in traces])
#       9 textout_array = np.asarray([traces.textout for trace in traces])
#
# AttributeError: 'list' object has no attribute 'wave'

# %% [markdown]
# This shows how a captured trace can be plotted:

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()
p = figure(plot_width=800)

xrange = range(len(traces[0]))
p.line(xrange, traces[0], line_color="red")
show(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 from bokeh.plotting import figure, show
#       2 from bokeh.io import output_notebook
# ----> 4 output_notebook()
#       5 p = figure(plot_width=800)
#       7 xrange = range(len(traces[0]))
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\output.py:124, in output_notebook(resources, verbose, hide_banner, load_timeout, notebook_type)
#     122 # verify notebook_type first in curstate().output_notebook
#     123 curstate().output_notebook(notebook_type)
# --> 124 run_notebook_hook(notebook_type, "load", resources, verbose, hide_banner, load_timeout)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:357, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     355 if _HOOKS[notebook_type][action] is None:
#     356     raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 357 return _HOOKS[notebook_type][action](*args, **kwargs)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:474, in load_notebook(resources, verbose, hide_banner, load_timeout)
#     471 jl_js = _loading_js(bundle, element_id, load_timeout, register_mime=False)
#     473 if html is not None:
# --> 474     publish_display_data({'text/html': html})
#     475 publish_display_data({
#     476     JS_MIME_TYPE   : nb_js,
#     477     LOAD_MIME_TYPE : jl_js,
#     478 })
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:487, in publish_display_data(data, metadata, source, transient, **kwargs)
#     485 # This import MUST be deferred or it will introduce a hard dependency on IPython
#     486 from IPython.display import publish_display_data
# --> 487 publish_display_data(data, metadata, source, transient=transient, **kwargs)
#
# TypeError: publish_display_data() takes from 1 to 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %%
import matplotlib.pyplot as plt
plt.plot(traces[0]-traces[1])
plt.show()

# %%
np.save('./tr.npy' , traces)

# %%
from tqdm.notebook import trange
import numpy as np
import time
from Crypto.Cipher import AES

ktp = cw.ktp.Basic()

traces_t = []
textin = []
keys = []
N = 20000  # Number of traces

# 평문
plaintext = [
    0x32, 0x43, 0xf6, 0xa8,
    0x88, 0x5a, 0x30, 0x8d,
    0x31, 0x31, 0x98, 0xa2,
    0xe0, 0x37, 0x07, 0x34
]

key, text = ktp.next()
cipher = AES.new(bytes(key), AES.MODE_ECB)

for i in trange(N, desc='Capturing traces'):
    text, key = ktp.next()
    text = plaintext
    
    textin.append(text)
    keys.append(key)
    
    ret = cw.capture_trace(scope, target, text, key)
    if not ret:
        print("Failed capture")
        continue
    
    traces_t.append(ret.wave)
    project.traces.append(ret)
# Out:
# Capturing traces:   0%|          | 0/20000 [00:00<?, ?it/s]

# %%
from datetime import datetime
import os
now = datetime.now().strftime('%Y.%m.%d-%H.%M.%S')
os.mkdir(now)

traces_array  = np.asarray([ret.wave for trace in traces_t])
textin_array  = np.asarray([ret.textin for trace in traces_t])
textout_array = np.asarray([ret.textout for trace in traces_t])
keylist_array = np.asarray([ret.key for trace in traces_t])

np.save('%s/%s_traces'%(now, now), traces_array)
np.save('%s/%s_textin'%(now, now), textin_array)
np.save('%s/%s_textout'%(now, now), textout_array)
np.save('%s/%s_keylist'%(now, now), keylist_array)

# %%
# !pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (3.6.3)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (24.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (2.2.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (2025.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from Jinja2>=2.9->bokeh) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from pandas>=1.2->bokeh) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from pandas>=1.2->bokeh) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.17.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
p = figure(plot_width=800)

xrange = range(len(traces_t[0]))
p.line(xrange, traces_t[0], line_color="red")
show(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 from bokeh.plotting import figure, show
#       2 from bokeh.io import output_notebook
# ----> 3 output_notebook()
#       4 p = figure(plot_width=800)
#       6 xrange = range(len(traces_t[0]))
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\output.py:124, in output_notebook(resources, verbose, hide_banner, load_timeout, notebook_type)
#     122 # verify notebook_type first in curstate().output_notebook
#     123 curstate().output_notebook(notebook_type)
# --> 124 run_notebook_hook(notebook_type, "load", resources, verbose, hide_banner, load_timeout)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:371, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     369 if server is None:
#     370     log.debug("No server instance found for uuid: %r" % server_id)
# --> 371     return
#     373 try:
#     374     for session in server.get_sessions():
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:487, in load_notebook(resources, verbose, hide_banner, load_timeout)
#     485 # This import MUST be deferred or it will introduce a hard dependency on IPython
#     486 from IPython.display import publish_display_data
# --> 487 publish_display_data(data, metadata, source, transient=transient, **kwargs)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:637, in _loading_js(bundle, element_id, load_timeout, register_mime)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\jinja2\environment.py:1295, in Template.render(self, *args, **kwargs)
#    1293     return self.environment.concat(self.root_render_func(ctx))  # type: ignore
#    1294 except Exception:
# -> 1295     self.environment.handle_exception()
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\jinja2\environment.py:942, in Environment.handle_exception(self, source)
#     937 """Exception handling helper.  This is used internally to either raise
#     938 rewritten exceptions or return a rendered traceback for the template.
#     939 """
#     940 from .debug import rewrite_traceback_stack
# --> 942 raise rewrite_traceback_stack(source=source)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\core\_templates\autoload_nb_js.js:1, in top-level template code()
# ----> 1 {% extends "autoload_js.js" %}
#       2
#       3 {% block register_mimetype %}
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\core\_templates\autoload_js.js:113, in top-level template code()
#     111
#     112   {% if bundle %}
# --> 113   const js_urls = {{ bundle.js_urls|tojson }};
#     114   const css_urls = {{ bundle.css_urls|tojson }};
#     115   {% else %}
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\jinja2\filters.py:1721, in do_tojson(eval_ctx, value, indent)
#    1718     kwargs = kwargs.copy()
#    1719     kwargs["indent"] = indent
# -> 1721 return htmlsafe_json_dumps(value, dumps=dumps, **kwargs)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\jinja2\utils.py:669, in htmlsafe_json_dumps(obj, dumps, **kwargs)
#     665 if dumps is None:
#     666     dumps = json.dumps
#     668 return markupsafe.Markup(
# --> 669     dumps(obj, **kwargs)
#     670     .replace("<", "\\u003c")
#     671     .replace(">", "\\u003e")
#     672     .replace("&", "\\u0026")
#     673     .replace("'", "\\u0027")
#     674 )
#
# File ~\ChipWhisperer\winpy\python\Lib\json\__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File ~\ChipWhisperer\winpy\python\Lib\json\encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File ~\ChipWhisperer\winpy\python\Lib\json\encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# File ~\ChipWhisperer\winpy\python\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)    178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type URL is not JSON serializable

# %% [markdown]
# Finally we save our traces and disconnect. By saving the traces, the attack can be repeated in the future without having to repeat the trace acquisition steps above.

# %%
#project.save()
scope.dis()
target.dis()

# %%
# !pip install --upgrade bokeh==2.4.3
# Out:
# Collecting bokeh==2.4.3
#   Downloading bokeh-2.4.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (3.1.6)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (24.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (6.0.2)
# Requirement already satisfied: tornado>=5.1 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (6.4.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (4.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from Jinja2>=2.9->bokeh==2.4.3) (3.0.2)
# Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#    ---------------------------------------- 0.0/18.5 MB ? eta -:--:--
#    --------- ------------------------------ 4.2/18.5 MB 28.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 10.5/18.5 MB 28.5 MB/s eta 0:00:01
#    ---------------------------------------  18.4/18.5 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------- 18.5/18.5 MB 28.5 MB/s eta 0:00:00
# Installing collected packages: bokeh
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 3.6.3
#     Uninstalling bokeh-3.6.3:
#       Successfully uninstalled bokeh-3.6.3
# Successfully installed bokeh-2.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# holoviews 1.20.2 requires bokeh>=3.1, but you have bokeh 2.4.3 which is incompatible.
# panel 1.6.1 requires bokeh<3.7.0,>=3.5.0, but you have bokeh 2.4.3 which is incompatible.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
