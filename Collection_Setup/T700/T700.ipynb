# %% [markdown]
# # Breaking Hardware AES on CW305 FPGA

# %% [markdown]
# This tutorial relies on previous knowledge from the SCA101 course notebooks (in `../courses/sca101/`); make sure you go through these first to understand how a CPA attack works.
#
# In this notebook, we'll apply knowledge from sca101 to break a hardware AES implementation on the CW305 Artix FPGA.
#
# Some out-of-date background on the target FPGA project is can be found here: [Tutorial CW305-1 Building a Project](http://wiki.newae.com/Tutorial_CW305-1_Building_a_Project) (ignore the "capture setup" section, which uses the obsolete ChipWhisperer GUI; this notebook shows all you need to know about capture setup on the CW305 with Jupyter).

# %% [markdown]
# ## Background Theory
# During this tutorial, we'll be working with a hardware AES implementation. This type of attack can be much more difficult than a software AES attack. In the software AES attacks, we needed hundreds or thousands of clock cycles to capture the algorithm's full execution. In contrast, a hardware AES implementation may have a variety of speeds. Depending on the performance of the hardware, a whole spectrum of execution speeds can be achieved by executing many operations in a single clock cycle. It is theoretically possible to execute the entire AES encryption in a single cycle, given enough hardware space and provided that the clock is not too fast. Most hardware accelerators are designed to complete one round or one large part of a round in a single cycle.
#
# This fast execution may cause problems with a regular CPA attack. In software, we found that it was easy to search for the outputs of the s-boxes because these values would need to be loaded from memory onto a high-capacitance data bus. This is not necessarily true on an FPGA, where the output of the s-boxes may be directly fed into the next stage of the algorithm. In general, we may need some more knowledge of the hardware implementation to successfully complete an attack.
#
# In our case, let's suppose that every round of AES is completed in a single clock cycle. Recall the execution of AES:
#
# <img src="img/aes_operations.png" width="250">
#
# Here, every blue block is executed in one clock cycle. This means that an excellent candidate for a CPA attack is the difference between the input and output of the final round. It is likely that this state is stored in a port that is updated every round, so we expect that the Hamming distance between the round input and output is the most important factor on the power consumption. Also, the last round is the easiest to attack because it has no MixColumns operation. We'll use this Hamming distance as the target in our CPA attack.

# %% [markdown]
# ## Capture Notes
#
# Most of the capture settings used below are similar to the standard ChipWhisperer scope settings. However, there are a couple of interesting points:
#
# - We're only capturing 129 samples (the minimum allowed), and the encryption is completed in less than 60 samples with an x4 ADC clock. This makes sense - as we mentioned above, our AES implementation is computing each round in a single clock cycle.
# - We're using EXTCLK x4 for our ADC clock. This means that the FPGA is outputting a clock signal, and we aren't driving it.
#
# Other than these, the last interesting setting is the number of traces. By default, the capture software is ready to capture 5000 traces - many more than were required for software AES! It is difficult for us to measure the small power spikes from the Hamming distance on the last round: these signals are dwarfed by noise and the other operations on the chip. To deal with this small signal level, we need to capture many more traces.

# %% [markdown]
# ## Capture Setup

# %% [markdown]
# Setup is somewhat similar to other targets, except that we are using an external clock (driven from the FPGA). We'll also do the rest of the setup manually:

# %%
FPGA_ID='100t' # change if not using K100t CW305

# %%
Trojan_ID = 'T700'

# %%
import chipwhisperer as cw
scope = cw.scope()
scope.gain.db = 25
scope.adc.samples = 600
scope.adc.offset = 0
scope.adc.basic_mode = "rising_edge"
scope.trigger.triggers = "tio4"
scope.io.tio1 = "serial_rx"
scope.io.tio2 = "serial_tx"
scope.io.hs2 = "disabled"

# %%
bsfile = r"./T700.bit"

# %% [markdown]
# Before setting the ADC clock, we connect to the CW305 board. Here we'll need to specify our bitstream file to load as well as the usual scope and target_type arguments.
#
# Pick the correct bitfile for your CW305 board (e.g. either '35t' or '100t'). By setting `force=False`, the bitfile will only be programmed if the FPGA is uninitialized (e.g. after powering up). Change to `force=True` to always program the FPGA (e.g. if you have generated a new bitfile).

# %%
#target = cw.target(scope, cw.targets.CW305, fpga_id='35t', force=False)
target = cw.target(scope, cw.targets.CW305, fpga_id=FPGA_ID, force=True, bsfile=bsfile)
# Out:
# (ChipWhisperer Target WARNING|File CW305.py:591) Using default Verilog defines (C:\Users\j2217\ChipWhisperer\chipwhisperer\software\chipwhisperer/hardware/firmware/cw305/cw305_aes_defines.v); if this is not what you want, provide them via the defines_files argument

# %% [markdown]
# Next we set all the PLLs. We enable CW305's PLL1; this clock will feed both the target and the CW ADC. As explained [here](http://wiki.newae.com/Tutorial_CW305-1_Building_a_Project#Capture_Setup), **make sure the DIP switches on the CW305 board are set as follows**:
# - J16 = 0
# - K16 = 1

# %%
target.vccint_set(1.0)
# we only need PLL1:
target.pll.pll_enable_set(True)
target.pll.pll_outenable_set(False, 0)
target.pll.pll_outenable_set(True, 1)
target.pll.pll_outenable_set(False, 2)

# run at 10 MHz:
target.pll.pll_outfreq_set(10E6, 1)

# 1ms is plenty of idling time
target.clkusbautooff = True
target.clksleeptime = 1

# %% [markdown]
# CW-Husky requires a different setup when the ADC clock is driven by the target:

# %%
if scope._is_husky:
    scope.clock.clkgen_freq = 10e6
    scope.clock.clkgen_src = 'extclk'
    scope.clock.adc_mul = 8
    # if the target PLL frequency is changed, the above must also be changed accordingly
else:
    scope.clock.adc_src = "extclk_x4"

# %% [markdown]
# Ensure the ADC clock is locked:

# %%
import time
for i in range(5):
    scope.clock.reset_adc()
    time.sleep(1)
    if scope.clock.adc_locked:
        break 
assert (scope.clock.adc_locked), "ADC failed to lock"

# %% [markdown]
# Occasionally the ADC will fail to lock on the first try; when that happens, the above assertion will fail (and on the CW-Lite, the red LED will be on). Simply re-running the above cell again should fix things.

# %% [markdown]
# ## Trace Capture
# Below is the capture loop. The main body of the loop loads some new plaintext, arms the scope, sends the key and plaintext, then finally records and appends our new trace to the `traces[]` list.
#
# Because we're capturing 5000 traces, this takes a bit longer than the attacks against software AES implementations.
#
# Note that the encryption result is read from the target and compared to the expected results, as a sanity check.

# %%
project_file = "./"
project = cw.create_project(project_file, overwrite=True)

# %%
from tqdm.notebook import trange
import numpy as np
import time
from Crypto.Cipher import AES
import random
import time
ktp = cw.ktp.Basic()



traces = []
textin = []
keys = []
N = 10000  # Number of traces

# initialize cipher to verify DUT result:
key, text = ktp.next()
cipher = AES.new(bytes(key), AES.MODE_ECB)
testkey = [[]]
for i in trange(N, desc='Capturing traces'):
    # run aux stuff that should come before trace here
    testkey = []
    key, text = ktp.next()  # manual creation of a key, text pair can be substituted here
    
    text = [
        0x00, 0x11, 0x22, 0x33,
        0x44, 0x55, 0x66, 0x77,
        0x88, 0x99, 0xaa, 0xbb,
        0xcc, 0xdd, 0xee, 0xff
    ]
    for r in range(16):
        key[r] = random.randint(0, 255)
    print(key)
    cipher = AES.new(bytes(key), AES.MODE_ECB)


    textin.append(text)
    keys.append(key)
    
    ret = cw.capture_trace(scope, target, text, key)
    if not ret:
        print("Failed capture")
        continue
    time.sleep(0.2)
    assert (list(ret.textout) == list(cipher.encrypt(bytes(text)))), "Incorrect encryption result!\nGot {}\nExp {}\n".format(ret.textout, list(text))
    
    traces.append(ret.wave)
    project.traces.append(ret)
# Out:
# Capturing traces:   0%|          | 0/10000 [00:00<?, ?it/s]
# CWbytearray(b'0d 5f 48 ec 5a 4e 0e af 19 41 a2 0d 0b cb d6 a0')
# CWbytearray(b'74 e2 10 38 06 90 18 b8 17 f0 4d 8f 47 24 97 1e')
# CWbytearray(b'69 6c 31 a9 ea e4 63 dc 1f 32 73 2f 82 48 5b cf')
# CWbytearray(b'1d 27 4a 3f a4 55 6b 13 17 b5 93 6b a1 cd 4f 97')
# CWbytearray(b'90 70 1a 59 0a 5b 22 17 ba 9c e2 4e 93 c0 5e 8e')
# CWbytearray(b'c3 8f af fd d7 ca 29 27 e1 5f 19 23 79 99 7a 0f')
# CWbytearray(b'04 c2 c9 17 5b 94 9d 07 21 af cd ae 07 3f fa af')
# CWbytearray(b'35 81 0a b9 48 11 1e e9 c5 0c da ec a2 c1 90 c8')
# CWbytearray(b'dc f7 3d 08 6c 18 5d f9 86 68 ff 83 3b b7 9d 74')
# CWbytearray(b'b1 05 f2 e3 3c bd a4 37 9e fc 18 42 28 96 1c a2')
# CWbytearray(b'fe 64 5f 3a 87 3c 96 91 11 49 30 42 ce a0 5d c9')
# CWbytearray(b'd8 c9 aa 9f 70 5e dd 8b b4 03 5b 6d 39 f5 ea c6')
# CWbytearray(b'b3 88 bd df c4 52 30 c0 8c fe fa c5 f7 6f 11 36')
# CWbytearray(b'3d 7b f1 4a cd 69 92 b1 0b d1 b8 14 00 79 0a 28')
# CWbytearray(b'99 84 ce 4c e9 0d 9a 02 e2 56 ce c9 6a 3e 5d 33')
# CWbytearray(b'a7 d5 94 9a 0b ad 14 d0 58 58 dc a6 b5 74 2f 4b')
# CWbytearray(b'50 6b f5 fc c7 da ae 01 b0 cd 1b 19 29 39 40 91')
# CWbytearray(b'47 d2 da c0 9a 5c 88 83 79 5e 9f 44 26 c9 79 e2')
# CWbytearray(b'40 25 6b 0d 89 b7 a5 88 01 c3 35 a3 e6 38 10 e1')
# CWbytearray(b'7d 7b 60 17 3a ed 27 89 9e 42 51 c7 1d d6 b5 9b')
# CWbytearray(b'fa 88 88 c6 6a e3 b2 39 9e e9 03 4e 48 8f e4 7b')
# CWbytearray(b'20 c8 1c a2 90 6e 62 71 d6 b7 4a 9d 76 f2 64 76')
# CWbytearray(b'c1 68 0c 0e 20 e1 2c 9a ca 6d df a4 bb b9 16 13')
# CWbytearray(b'f7 55 1c a9 ca 83 94 df 93 85 75 f1 20 8c 00 fb')
# CWbytearray(b'2d b3 2e 6a 5c 04 a8 24 c8 69 57 cf ba fb 9f 17')
# CWbytearray(b'1e 48 e5 e1 0e 60 28 e4 44 52 f9 06 5e c7 a2 01')
# CWbytearray(b'1b 69 30 5f 3c 8c 32 3d 8c 2b a9 bf 73 bb 81 53')
# CWbytearray(b'99 f9 ce ef bd 65 4d 5d 81 7d 14 20 e7 58 d3 bf')
# CWbytearray(b'50 54 4e d5 d3 19 04 ed 8b d4 44 1f 8e 74 d7 2d')
# CWbytearray(b'70 69 11 a1 a9 e6 4f f3 38 ac 3f d2 ea e6 4f b1')
# CWbytearray(b'11 f0 c4 81 03 21 0a a9 bd ca 3e 00 94 e7 24 30')
# CWbytearray(b'c2 8b 1e cc 5e 42 8e 71 e5 7d d5 8b 07 0b ec 42')
# CWbytearray(b'a7 68 5c 10 e4 28 c7 2f 02 ae f2 3b 56 80 16 bb')
# CWbytearray(b'a2 87 45 a1 6c cd 98 a3 d9 f3 25 0c 6f d9 a9 1b')
# CWbytearray(b'ef 4e bf d8 16 d6 6a 4b d6 11 f1 b9 4b bd 60 fd')
# CWbytearray(b'da 0c 84 e4 5d e5 3f 98 76 38 13 cc ba 53 e2 3c')
# CWbytearray(b'74 86 14 b1 fb 04 03 89 91 7d ff 11 a7 3d 05 21')
# CWbytearray(b'95 77 b9 89 84 d3 42 f2 d1 47 c1 db bd 54 f1 03')
# CWbytearray(b'17 4f d4 89 9f bc 90 0c 73 c7 5a 8f db 11 4a 50')
# CWbytearray(b'82 ae e0 09 c2 56 ba 76 96 c5 bd 7a c7 70 b8 30')
# CWbytearray(b'f4 e4 db ac 6c a8 cb 20 64 64 37 40 bb 94 17 94')
# CWbytearray(b'94 64 ca 7e 89 1b 82 a5 33 1b 82 99 34 26 e8 4b')
# CWbytearray(b'77 3d 94 e4 b0 b9 64 a4 15 94 4a e1 ae fa 91 91')
# CWbytearray(b'20 d1 29 48 b3 be d7 8a ac 4f 64 d4 cc 9f 77 6f')
# CWbytearray(b'87 6a bb ce 9c 5f f7 81 50 cd f7 ab f5 30 9f 9b')
# CWbytearray(b'90 6b 18 21 43 41 f2 56 58 12 f4 e8 cd fc 64 69')
# CWbytearray(b'24 2a 30 ba 3c 73 92 65 bc 68 68 80 d8 27 6f 37')
# CWbytearray(b'20 9b 66 34 b5 95 1b fb 6a d1 a3 bf ab 5d cb 68')
# CWbytearray(b'50 26 b6 c7 f9 84 ee d9 e0 38 1f e1 90 42 09 df')
# CWbytearray(b'ec 13 36 75 ae 1c e7 54 c0 6d e5 ee 02 f6 05 d7')
# CWbytearray(b'99 a7 d9 82 29 41 93 a0 24 a7 e3 90 c9 70 3a 4f')
# CWbytearray(b'd7 1b d3 6a 7d 79 05 52 24 86 bb f8 65 ec a9 94')
# CWbytearray(b'8a 75 42 77 ad f5 1d fb 42 bd 5e 12 6e 1a bb 57')
# CWbytearray(b'2e e7 7e 6a 49 f9 73 69 e0 69 d3 c5 c5 93 19 71')
# CWbytearray(b'3d b5 5a ac 89 64 cc 91 9f ee 5c ce a1 a3 0a 80')
# CWbytearray(b'2a a5 65 0c b9 63 b7 19 c5 17 1c 0e 38 3f c7 ab')
# CWbytearray(b'4a 66 b0 1f 07 4e d1 8f 51 78 d9 8c 0a 94 34 c5')
# CWbytearray(b'06 57 ba 70 e7 b2 a8 46 0f 64 21 b0 af be 56 08')
# CWbytearray(b'3f a1 ba 53 65 e3 5e b6 2c 3e 6a e3 a2 37 c7 90')
# CWbytearray(b'90 1d bb 8a df 12 61 8c bb 02 83 eb b4 09 c8 99')
# CWbytearray(b'f9 53 34 67 2f a3 36 4e 3c f6 61 97 6f a5 d6 4a')
# CWbytearray(b'b9 c5 60 8e 8a 0e e3 a4 df dc c6 f7 5f 7c ed d6')
# CWbytearray(b'b3 67 97 f8 99 87 c2 f4 b7 0d 24 91 bc a6 2a 45')
# CWbytearray(b'ad 3f 0f 21 41 9a 02 2a 9f 3d b2 09 80 2b 30 d6')
# CWbytearray(b'e6 08 ec 3e 9c 52 49 c6 39 8b fb 94 98 9d 0c b0')
# CWbytearray(b'c8 97 62 82 92 bc f1 0d b1 b8 e2 c7 eb e1 70 f3')
# CWbytearray(b'71 64 a6 80 1b 77 3f 3c 42 df fc 08 5c 06 3f 03')
# CWbytearray(b'0e 8d d9 cd 41 df 9a fd b0 f3 01 b6 3a 8a 30 34')
# CWbytearray(b'00 8f 1c 4f b3 f9 49 56 1a c5 d7 c0 12 08 36 a5')
# CWbytearray(b'43 9e 94 c5 f3 14 06 d5 81 e8 bc 56 3d 45 95 ea')
# CWbytearray(b'11 55 b8 8f 80 15 a2 3c 00 65 f6 ce 93 f0 85 e3')
# CWbytearray(b'90 24 9d 7e 36 1a f1 2b 58 cd 8f d3 da e3 e5 ce')
# CWbytearray(b'd0 10 a3 57 73 37 7c e5 e6 59 9f 13 a0 52 6f 6b')
# CWbytearray(b'a4 ac bb c1 56 0f 28 96 39 fb 6b 38 8a 9f 02 38')
# CWbytearray(b'9f 94 80 bf ed 55 2c cd 5d 09 d7 7f a7 6b 50 37')
# CWbytearray(b'8b ef 97 26 68 70 a2 ee c7 1f f0 52 5a 33 4f d4')
# CWbytearray(b'3c a2 1b c9 a3 bf 57 a8 bc 79 2c da d2 ad ff 99')
# CWbytearray(b'91 f0 5c bc 1c f2 a6 54 d7 71 49 e9 21 6d a2 e5')
# CWbytearray(b'2c 58 e0 12 a4 0c 2b 7e 6c df 82 09 d1 2b 0c 4d')
# CWbytearray(b'16 ae e8 fe 37 bc 40 77 40 f2 6d e4 30 df cf 6a')
# CWbytearray(b'a5 a7 de 36 77 53 c3 64 f0 a4 86 41 2d f9 19 9c')
# CWbytearray(b'f7 e8 b5 4d 13 cd be 1c 29 37 6f 08 f8 83 78 58')
# CWbytearray(b'38 0b 1a f2 18 11 93 f7 61 0c 1d 6a 7c ab 47 28')
# CWbytearray(b'0e f1 e0 9d f5 4e 8a 76 2a 25 38 6b a4 30 6c db')
# CWbytearray(b'8c 6a e2 5b 71 68 9f cf 86 0f 2b 8a 88 d7 63 92')
# CWbytearray(b'c6 4f 04 28 d6 1a 4f a8 13 19 10 d6 48 ce 5c 91')
# CWbytearray(b'e5 2c bf 00 a7 eb 0c c9 44 62 26 a8 04 ed f6 0e')
# CWbytearray(b'02 1b 18 9b 2f fe 38 79 24 78 26 3b b4 c2 21 7c')
# CWbytearray(b'1d 10 fd 46 40 76 68 41 bd cd 2f 69 ab 4a fd 92')
# CWbytearray(b'b5 2f a9 08 f2 bb ff 86 6c 16 4f 28 72 a1 63 0b')
# CWbytearray(b'5e df 47 c2 15 fb 10 d3 fe 61 b9 c1 97 61 08 18')
# CWbytearray(b'd2 fe 8c 4c 6d ca c8 a6 b9 5b 8f 96 28 2a 5d dc')
# CWbytearray(b'cc b2 4e 6d 3d b1 b0 be e4 3e 95 67 47 c1 60 dd')
# CWbytearray(b'af 64 7b 85 2d 59 9b e2 7b 40 26 58 e4 13 63 b4')
# CWbytearray(b'0b c0 eb 6a 3f 65 c5 fc cf ba f8 8b 78 e6 e2 73')
# CWbytearray(b'42 ff bb 58 dc 4b d2 e3 47 f2 60 86 44 6e 1e 01')
# CWbytearray(b'e2 e6 0a 9e fb 50 33 3d b7 3d e5 b0 33 88 bc 60')
# CWbytearray(b'9f 58 a0 25 a8 82 7b 9b d0 49 46 23 ee 78 c2 fe')
# CWbytearray(b'f5 f4 51 15 f7 00 c0 ee f4 8d 33 f9 a4 cb 6c ee')
# CWbytearray(b'9e 8c a3 cc 2b f8 07 5a 3f 31 e3 f7 df 2d 54 1d')
# CWbytearray(b'72 54 03 36 0c fd 87 b5 bc 87 93 6f a8 7c 2c 57')
# CWbytearray(b'ad f6 5c d6 af e0 33 9e 4f b4 5c 49 21 75 11 f9')
# CWbytearray(b'60 38 d2 ed 7a 70 45 05 d0 33 01 24 23 53 b6 5f')
# CWbytearray(b'ec b8 7a 20 29 cd 97 c8 2a 65 89 30 19 7a 0e fe')
# CWbytearray(b'74 9f 94 f0 53 3c e1 c3 1a 15 37 9d 6c 50 18 36')
# CWbytearray(b'89 a5 f2 f8 d4 10 1c 92 6d 42 9c 94 f6 e2 be e6')
# CWbytearray(b'a4 70 cb 24 07 cc 62 09 c9 aa 60 fc 43 bd 87 07')
# CWbytearray(b'6b 5e c2 4e f9 91 89 a3 c7 79 6a 23 71 83 fb 9c')
# CWbytearray(b'd0 19 f6 47 9c 08 a5 b2 41 70 cb e2 a3 4d 6f 34')
# CWbytearray(b'47 25 1d 25 17 05 a6 fe f6 25 23 f1 f7 66 10 7e')
# CWbytearray(b'bf ab ec a0 b2 3f 6f 41 c5 5c 10 83 eb 5b 0b 3d')
# CWbytearray(b'41 21 86 ca c3 b0 18 c1 ec cc 88 6d c8 43 44 f5')
# CWbytearray(b'44 ac 99 f3 34 d6 7a 7d e6 42 f7 49 44 40 b4 81')
# CWbytearray(b'df 39 5e 62 43 1d 31 7e c1 8d a1 ee 49 05 b7 5c')
# CWbytearray(b'ae 69 b4 c4 22 7f 44 06 f2 72 67 c8 9c df eb 85')
# CWbytearray(b'e1 9e 1d c7 39 dc 32 b8 ab 32 f6 27 93 06 e5 d7')
# CWbytearray(b'18 68 3f 11 b1 5e 31 0c 03 86 ac 1e ac 05 40 a5')
# CWbytearray(b'92 83 8a 9a a5 9f 64 7c 5f 9f 9d 74 f9 24 01 2e')
# CWbytearray(b'3b 4a 8c 90 51 c6 c2 64 f9 43 e3 38 57 d5 7f 3c')
# CWbytearray(b'91 9b a6 4b 40 b3 da d0 ea b6 2e a5 a5 44 13 70')
# CWbytearray(b'60 7a 5d 13 d4 66 66 9e 4d b4 07 d5 29 db a4 7c')
# CWbytearray(b'3e a7 eb 9d 48 33 a3 25 b4 d9 3d 50 a7 22 82 e5')
# CWbytearray(b'3a b9 0b 2a 90 72 60 bc 1e aa bd 2a 6e 5b dc 44')
# CWbytearray(b'29 4f 86 da c5 9d 4f db b1 a3 66 73 e3 39 30 ca')
# CWbytearray(b'2d 7c 6e bf 0f fb 91 95 7f 81 dc 2d f7 c8 d8 9f')
# CWbytearray(b'3b ee f1 03 0f f4 59 ae 35 03 41 50 b6 63 50 86')
# CWbytearray(b'7a 70 ee aa c3 21 ef 44 21 43 63 7c 16 d9 91 b2')
# CWbytearray(b'e2 45 73 60 8d 4f b5 3c 0d cf 10 49 b8 42 2d 73')
# CWbytearray(b'f2 ae 0a 0f 96 7e 20 ad e8 2e 97 78 2c 0b 40 e5')
# CWbytearray(b'21 fc a7 1b ab 34 cf 39 e6 94 09 d4 ef 36 4e f4')
# CWbytearray(b'dd 85 33 8b 7a 86 f0 10 05 14 9a 0a 7a 78 32 de')
# CWbytearray(b'8a 33 42 e2 d0 c2 e6 82 0c 94 e4 71 90 4c 75 e6')
# CWbytearray(b'f0 63 e7 a2 8d 31 6d 7f 46 e6 fd 17 66 8d da fc')
# CWbytearray(b'9a 2e 04 cf 38 35 58 82 22 8a c6 a3 5b 71 90 cc')
# CWbytearray(b'7d 50 15 ed 3e 39 4d 61 59 41 c1 51 2a dd d5 34')
# CWbytearray(b'5c 4e 92 0d a9 62 0c c6 dd 38 ab eb 9b 10 d7 2b')
# CWbytearray(b'c9 16 c2 25 9d 69 ef cb 87 fb 49 f5 fe 3d 95 46')
# CWbytearray(b'0e dd 0a e5 f1 31 33 c3 20 14 96 47 8d 33 e0 90')
# CWbytearray(b'54 fa 4d 5b bc 34 1d 82 8f de ec 19 0e 30 06 b6')
# CWbytearray(b'b8 6b 07 e1 cf e4 58 8e a4 b4 0e 49 01 98 06 66')
# CWbytearray(b'3d cb 16 5a 0d 2e 47 94 e9 dc 85 29 42 f7 1c 2d')
# CWbytearray(b'8a 6d b1 c5 7a bf aa a5 65 8e 69 51 03 37 a6 cf')
# CWbytearray(b'48 d4 f7 d3 38 05 ac 40 75 19 33 2a 0e c9 dc 73')
# CWbytearray(b'7f 38 40 52 d2 db 2a ce 5a 84 f6 1b ac 71 9f a3')
# CWbytearray(b'a3 c1 20 87 60 f1 e9 bc 6a c2 03 dc 37 5a 6f 11')
# CWbytearray(b'fc 4f 15 a0 1d 38 83 c1 d4 65 20 ea 83 75 c8 02')
# CWbytearray(b'8a b0 6a 3a b5 21 0b 71 69 a1 e8 ab c5 73 68 33')
# CWbytearray(b'33 3c 8b 1f b0 e1 4e 47 6b b0 1c 4f 84 34 56 0a')
# CWbytearray(b'27 ed 35 c1 17 04 0f 58 32 44 d9 ba e5 22 0e 37')
# CWbytearray(b'67 72 60 99 ad a5 e3 1b 8c da 05 bb 62 70 93 b2')
# CWbytearray(b'27 5b 41 86 fe d3 64 68 10 ee e3 32 f3 f9 be d9')
# CWbytearray(b'15 23 df 20 67 98 9e 65 6e 9a bf d3 8d bb c8 0f')
# CWbytearray(b'7f 79 9b 17 11 0f ce e1 64 a4 f4 c4 91 51 47 4e')
# CWbytearray(b'08 7c 10 d6 15 27 86 a6 ff 17 6e 5b fe ab b3 17')
# CWbytearray(b'73 31 5b 52 34 34 67 4e 4a b6 de dc 09 d7 9c db')
# CWbytearray(b'08 bb e2 13 a4 49 55 d7 b0 6f bf de 0e ff 87 0b')
# CWbytearray(b'75 00 2b 9f 2c 56 8b d5 13 31 89 b4 73 5d ac 88')
# CWbytearray(b'd9 68 78 7d 9b 48 cc a4 bf 15 7b 4e 1b 53 40 d4')
# CWbytearray(b'90 d3 1f a6 9a 81 90 dd 8c f5 ce 18 b3 b2 18 09')
# CWbytearray(b'a9 8d b2 d6 eb 4f bc 6b 40 de f4 d8 34 12 33 ec')
# CWbytearray(b'b5 76 4f c7 7d 82 66 22 a3 4e 08 aa 65 0c 46 80')
# CWbytearray(b'39 df 21 a1 7a 2c 3c a1 7d 4b b5 b1 b2 4e 5b 79')
# CWbytearray(b'95 57 fc 68 9c cf c7 45 49 e6 2b 21 cd c6 48 9e')
# CWbytearray(b'9d 73 f2 55 a4 9c 96 3a 66 12 b7 16 0a 0e 94 b9')
# CWbytearray(b'89 0e fa 2b 77 7c 3c a3 90 3e b4 b8 72 21 72 71')
# CWbytearray(b'ae 5b 7b 18 b1 7b 1c ca 8b 3f 26 44 8f 8f 22 05')
# CWbytearray(b'35 06 c6 6f cf bc 59 27 b0 04 a2 34 08 bc 99 62')
# CWbytearray(b'95 9a 52 a8 0e 2f dc 77 cb bd 38 6c be 7d db 20')
# CWbytearray(b'da de 18 2d f7 51 39 7b 90 52 87 3b 07 11 79 8a')
# CWbytearray(b'55 f4 c8 4a b8 c6 56 ce 48 80 e4 df f2 bc 34 98')
# CWbytearray(b'6c b0 10 f4 e1 5f d0 d0 d3 27 38 1d 7a 5d a2 3d')
# CWbytearray(b'c4 74 d3 4c a7 b7 a0 f1 0a 0a 31 c2 56 0e cc da')
# CWbytearray(b'5b 13 57 09 7c 05 69 8d 97 94 be 23 53 0f 23 a1')
# CWbytearray(b'88 9b 0c 2d 2a 44 0b 4f 72 32 67 70 d9 23 9b e3')
# CWbytearray(b'c2 d5 f3 75 44 12 45 65 2a d0 c9 99 0d 94 1d 69')
# CWbytearray(b'a3 30 b5 bc 56 70 fe ef c5 21 17 f9 4e 1e af 56')
# CWbytearray(b'e2 d6 f3 1d da 41 77 ed 4a d0 ad 7a a8 6f 24 8e')
# CWbytearray(b'0a 52 98 ea a6 2e 64 df a0 7c b3 84 69 09 12 2d')
# CWbytearray(b'4a 68 7b eb 0f 23 5f be fc 14 7e c5 15 21 3a 08')
# CWbytearray(b'08 72 e6 c3 4c d2 33 b6 32 26 e5 d7 b5 18 72 25')
# CWbytearray(b'ea bd ab a8 65 e6 7f 44 ce 75 21 c3 a4 53 24 13')
# CWbytearray(b'33 ba 5f 8b 8e 8d c2 60 ff 29 bc c3 98 09 7b 9b')
# CWbytearray(b'7e b7 c5 c2 1d 97 2c 63 c5 14 81 22 cc 6a 3b 37')
# CWbytearray(b'10 49 fc d0 43 78 46 78 03 28 4c 73 1b 94 4a c3')
# CWbytearray(b'29 20 e9 65 75 d2 97 96 24 1b 61 6e fc 46 bb 71')
# CWbytearray(b'58 87 14 bd 5c a1 d2 ea 4d 4e 95 70 de 1e 4f b8')
# CWbytearray(b'd2 68 5b 8a dc 4b 06 ab 28 85 1d da ee e8 ce 30')
# CWbytearray(b'1c 3a 1e 56 16 db c1 90 5d 2e 84 2b 42 66 d6 e4')
# CWbytearray(b'bb 60 cc 97 79 f8 02 0c 82 d3 73 8a 35 04 99 52')
# CWbytearray(b'98 d3 76 9c c6 39 ed 20 1d 0e ab bf 14 14 40 ae')
# CWbytearray(b'39 5f 2e 49 d5 66 6c c6 fa 24 7f 63 8a 03 50 e9')
# CWbytearray(b'b9 88 50 80 77 74 f3 fa 07 f8 19 4a 9c b4 3b 5e')
# CWbytearray(b'7b b4 a8 a9 e1 2f 81 3b 7a fc 50 0c 01 42 83 e1')
# CWbytearray(b'0c 6e ee fe 67 c6 d0 f7 1c 3d ff 4c 39 ac ee e1')
# CWbytearray(b'be cd 9f ed fd 6c 42 b2 ad 70 89 1c 4a 42 c5 eb')
# CWbytearray(b'16 56 1a 83 58 b8 a8 5b 4a ff 6b d7 0b 51 32 17')
# CWbytearray(b'ce 79 a1 c4 f4 74 77 10 6a a4 57 2b d1 62 27 d3')
# CWbytearray(b'ce 77 c4 33 48 af fb f4 13 3b 33 21 b7 b7 5e 87')
# CWbytearray(b'00 c0 41 b1 3c 80 e5 ff 5f 65 45 1d 21 25 fc f9')
# CWbytearray(b'56 ee 30 71 66 e0 ee e7 31 a9 87 c4 82 19 04 4d')
# CWbytearray(b'a2 7e e7 0b f1 14 23 d7 8d 55 15 bd 47 5b f4 48')
# CWbytearray(b'04 27 e4 c4 7f 05 f3 ab 5d 2d b7 5c 5c 0c d7 f3')
# CWbytearray(b'f4 81 dd 88 57 1b 39 63 d1 58 a4 6b 97 4e 51 2d')
# CWbytearray(b'e7 76 13 c7 8f d8 83 f3 a9 48 f8 18 28 62 01 d4')
# CWbytearray(b'c7 fe 08 b2 11 c5 7a 15 97 37 80 a6 8e 9e 23 65')
# CWbytearray(b'8a 38 90 2c 98 17 67 c3 4c 29 f2 d0 c5 15 a5 a5')
# CWbytearray(b'67 1e 7f 4d d6 01 b4 44 28 2c ff 12 63 93 10 4d')
# CWbytearray(b'9d 4d 54 17 32 c5 6c fb d3 a0 38 30 83 be 51 ac')
# CWbytearray(b'8b 8f 87 6b 0b 07 b4 f6 a9 4d f0 2e e7 87 39 a1')
# CWbytearray(b'c1 47 01 0e 84 9c 47 98 f9 57 67 dd c1 5c 1c 2a')
# CWbytearray(b'c6 cd d5 88 c4 ad 88 19 65 1c 96 ba 88 88 9b ec')
# CWbytearray(b'3d 00 51 93 7b 8b 2b f0 ca 16 eb 3e 51 00 45 79')
# CWbytearray(b'ae c9 3b 59 b4 4b ce 48 54 7c 03 bf 56 40 e4 a8')
# CWbytearray(b'ce 40 b7 d8 21 f3 50 ab f0 2d 64 31 b3 51 8b fd')
# CWbytearray(b'd3 60 71 6f 0a c2 72 c5 26 7f 1d ea 53 14 d5 75')
# CWbytearray(b'd9 c0 17 be 9f b0 b6 30 ad fc db 0f 25 2f 0c 8c')
# CWbytearray(b'd4 fb a6 53 fb 85 ce a4 cc c8 6e 28 ac e9 be f5')
# CWbytearray(b'69 9b d1 75 6d 65 64 bb 07 dc 1b d8 88 56 2b 5c')
# CWbytearray(b'12 e6 f4 fd 3d 02 90 0f 46 09 39 23 2a 91 37 fc')
# CWbytearray(b'83 32 dc f9 ab 7e c0 cc 23 77 d1 d1 40 12 53 fd')
# CWbytearray(b'a1 49 13 03 79 db 4c 9c 8e 70 35 a9 9e fa 33 a4')
# CWbytearray(b'7d 57 7d 38 ab e6 f1 d2 97 54 ac 51 54 8c fb 6a')
# CWbytearray(b'96 95 33 03 b7 84 38 85 05 eb 1d 48 5d f0 f1 58')
# CWbytearray(b'cc a6 b5 19 e3 9e 2c f7 5f ab 17 69 d4 1c 62 5e')
# CWbytearray(b'91 9b 01 85 18 10 37 a7 2d 47 e8 34 31 31 6d 22')
# CWbytearray(b'90 ac 70 f2 77 b2 5a 36 b5 e3 e6 05 0a f8 b3 68')
# CWbytearray(b'11 59 7d ad 27 5c 2c b6 39 60 ff 5a a5 1c fc 23')
# CWbytearray(b'98 ef 8f 8d 19 fe 5a 40 43 c7 cc aa 1a da 4e 19')
# CWbytearray(b'39 8d 6e 73 6c c2 86 39 6f 36 51 7a 79 64 dd 73')
# CWbytearray(b'38 e8 3e a3 9c a4 00 f2 60 96 01 79 4d dd c9 80')
# CWbytearray(b'b3 cf d7 bb ef f4 24 ef 65 06 84 bd 9f 6d 6b 50')
# CWbytearray(b'c7 2f 3d 85 dc 2d 8c de c3 1e 6b ea f3 79 b9 f4')
# CWbytearray(b'72 25 b1 09 de 2e e7 ea 1d 8d 16 40 40 e9 d9 5c')
# CWbytearray(b'71 b3 ba 34 03 e8 61 56 74 51 3b 96 93 36 c1 2c')
# CWbytearray(b'19 04 5d fe 28 3e 7d 5c dd 0d a6 f2 e9 00 05 e6')
# CWbytearray(b'13 6f 00 52 74 d2 69 29 76 87 2f d1 18 21 b7 f3')
# CWbytearray(b'09 2e fb 5c da 78 41 23 21 b9 67 32 df 18 86 ed')
# CWbytearray(b'6a 4f d8 d1 60 0b 32 ae a7 d4 d9 da 2f 94 2f 82')
# CWbytearray(b'34 52 79 49 18 fd 5d 47 25 25 8b 30 5b 7a b3 31')
# CWbytearray(b'66 fd 81 37 55 11 47 b4 9e 6f 00 cc 56 48 9e 94')
# CWbytearray(b'8c 69 0a fd 59 54 ba 79 7f 59 c6 e2 e2 97 7a d1')
# CWbytearray(b'c3 36 6d c3 8b f7 eb 6e cc 38 09 36 31 10 b1 43')
# CWbytearray(b'67 e5 2f 38 8d 6f b3 f3 bc 7c 62 3e 46 27 46 bf')
# CWbytearray(b'cb 32 4f d3 dd d8 5d cb e9 53 b0 ac e3 6d e9 de')
# CWbytearray(b'48 77 84 55 db cb bd 10 ee 9a 3c 02 75 06 fe 8b')
# CWbytearray(b'49 3f fe 36 ed 46 d5 f0 28 c0 df d6 a7 85 5c 96')
# CWbytearray(b'bd 74 ee 7d 1e 2d fb 25 37 fd 5b 37 05 9b 79 83')
# CWbytearray(b'a2 23 c1 db 02 3d 90 c2 2d 7b e7 05 8e a7 e0 5b')
# CWbytearray(b'27 8c cb 0a 14 f7 24 eb 0a 57 be 76 8b fe 33 8d')
# CWbytearray(b'c1 c3 b5 11 8e 9a aa f8 98 25 b0 76 2a bb 8e c6')
# CWbytearray(b'13 de ee ab ab 26 1d 22 d4 e3 61 b0 60 31 34 9d')
# CWbytearray(b'24 9f ed 09 51 00 b0 68 0c 28 23 cc f2 d8 b2 24')
# CWbytearray(b'cb 7e af 98 d3 bf 47 93 ab 81 0f 27 64 f6 37 c3')
# CWbytearray(b'6b 10 85 17 e6 eb a8 2e 76 dc 88 70 a4 1f 79 5e')
# CWbytearray(b'a5 3a 11 17 f0 ff 0b f5 69 a5 0b 49 3f 95 21 15')
# CWbytearray(b'9b 52 23 c1 aa 66 dc 04 e6 be fc f1 eb b5 ca e7')
# CWbytearray(b'56 0d 6e 4f 76 cf fd fd cd cd bd cf c8 44 cc 23')
# CWbytearray(b'19 d5 29 fb 26 40 2e 39 19 b4 76 09 5e 67 dd 66')
# CWbytearray(b'b3 92 11 08 a4 23 d8 e9 f4 34 21 27 90 86 ab 8b')
# CWbytearray(b'2f 06 cf 76 6b f7 09 a4 04 42 ae d3 0f 81 df e8')
# CWbytearray(b'b5 e2 9d f9 7f f5 e5 a0 a0 25 5a b0 8d 3a 48 9b')
# CWbytearray(b'ef 9c bd 66 38 12 7f ba 41 1d d5 fa 88 33 e4 aa')
# CWbytearray(b'65 ee ee 23 f1 eb 3d f8 4e ed d4 cb bd 5d 93 78')
# CWbytearray(b'c5 86 8e 93 69 f9 fd 47 1e 4e 48 09 cf a7 bd 74')
# CWbytearray(b'ac d8 63 b3 d6 8c 8f fc 40 a9 45 14 68 29 85 37')
# CWbytearray(b'ab 63 5e b3 20 03 86 ac 77 2c 57 58 39 51 3e f3')
# CWbytearray(b'b5 78 3c b1 60 a5 72 13 80 71 f7 47 c5 68 98 dc')
# CWbytearray(b'8c db 23 48 ec f7 e4 70 ea 8e 39 88 99 7c 13 60')
# CWbytearray(b'84 f4 09 04 a0 c1 15 c2 02 d4 b8 c2 a8 d3 a0 ff')
# CWbytearray(b'41 09 df 98 c0 3b 01 41 47 54 2a 7b f2 80 29 7c')
# CWbytearray(b'17 da 69 98 5c 04 93 a9 22 6f a3 9c c3 de a5 e5')
# CWbytearray(b'ea 25 69 be c0 ac 2d 25 3a a4 90 03 b1 e0 72 e5')
# CWbytearray(b'76 ec d3 a2 da 71 6f 59 2e e2 39 52 04 f6 31 19')
# CWbytearray(b'a8 fb f5 3b ad 6d e1 7a 45 38 56 ee 5a ba 7d 2a')
# CWbytearray(b'bf c9 fe f4 28 92 38 5d 34 6a 02 05 df 4a 42 c4')
# CWbytearray(b'7c 70 c6 50 42 0b de ea cb e5 b8 d5 64 35 4c 69')
# CWbytearray(b'e4 5d 91 36 bb a6 86 c0 19 ff 53 81 22 62 4e 9c')
# CWbytearray(b'8d 04 4f 00 30 54 8c 90 39 95 ff 86 a2 ef 92 1b')
# CWbytearray(b'04 4a 94 65 a4 2d db 7f 97 ba 1f 8b 3a 5f 5b 0e')
# CWbytearray(b'7c b9 0e e1 3a b3 34 16 a9 8d 2c 2f a5 af ef 91')
# CWbytearray(b'92 7d 5c ed 25 33 c9 dc f0 38 57 47 d4 5e 7f a8')
# CWbytearray(b'92 3d 0c ed 64 d9 86 6c b2 6d ea b6 5d 16 3d 15')
# CWbytearray(b'30 9a 52 41 0e f2 e5 06 d1 60 f8 05 1c f6 8b fc')
# CWbytearray(b'76 21 c1 c6 80 d9 aa a9 af d6 5c 04 d8 00 52 92')
# CWbytearray(b'78 b6 c5 85 dd 98 16 5c df d6 22 79 57 f3 eb 01')
# CWbytearray(b'07 27 8c 14 51 c2 96 41 03 8e 7d 28 31 cb c5 3a')
# CWbytearray(b'94 8f 3e f5 73 b1 5f ef 92 dc b7 2f eb 3c ec 91')
# CWbytearray(b'61 35 bd 1d b0 b7 a5 d5 9b a7 17 44 4a 67 be 95')
# CWbytearray(b'64 fd cb 48 e2 fc d4 5b d8 c4 a0 8c 8e ab 2f 10')
# CWbytearray(b'2b 8d ef f6 7d 5c db 92 2a d1 6b ce 2d 3f 75 0e')
# CWbytearray(b'a5 b8 83 fa a1 61 e9 b3 de df b2 47 4a 01 67 0a')
# CWbytearray(b'6f 41 9c 8b 0c c2 89 44 69 9b a8 bc 6c 41 7c 7e')
# CWbytearray(b'63 7d 37 40 ad 02 f1 63 2a 3b 12 2e 3c d1 92 b3')
# CWbytearray(b'4a bd 81 bf c9 b1 26 2f 4f 7e df b2 9e 23 4d 30')
# CWbytearray(b'de a3 85 5c c6 57 a1 96 aa 0e 19 f2 15 e4 ad c4')
# CWbytearray(b'48 cd 14 d1 48 df 6e b8 1c ab 3f 8f 64 df f0 77')
# CWbytearray(b'b4 31 f7 e3 ca c5 81 b9 a3 62 78 63 ae 77 e4 ce')
# CWbytearray(b'f0 94 ec 7d 47 3e e7 b8 cd 3f 96 05 ea 4a 01 23')
# CWbytearray(b'29 23 25 4e 1b 45 5c 74 d4 c7 c6 68 7a ca 4b 87')
# CWbytearray(b'ae 40 75 31 5a f0 0f aa e6 fb 4b ac 2f 4a 58 1e')
# CWbytearray(b'39 4d 93 a9 30 6f 1d c9 05 08 5e 38 55 a2 64 5d')
# CWbytearray(b'eb 2e 58 65 58 fd 1f 04 50 6b 3f ca bb e7 b6 33')
# CWbytearray(b'74 5d b9 33 44 93 7b c2 09 95 09 22 59 27 67 44')
# CWbytearray(b'd3 b2 41 09 b8 ad 9f ca b1 52 a9 35 aa 4e 14 80')
# CWbytearray(b'46 c7 98 44 ec ac 2f 5f fe 15 a9 f0 37 39 6a 6c')
# CWbytearray(b'56 44 5a 89 a0 6c 98 f5 c0 ce 7b 90 ea 2f 0e 7a')
# CWbytearray(b'4e 92 e7 7b 4d 3d cf 5b d2 2e 3f f3 e1 12 61 a8')
# CWbytearray(b'b4 41 c8 5a 80 9c e8 8d 0a f4 43 fa 95 48 0a 17')
# CWbytearray(b'8f a7 c7 c2 1a 5d 65 69 0a 19 e8 7a a1 84 84 94')
# CWbytearray(b'e8 50 79 dc 6d 72 19 cd e3 c1 47 1b 54 9f 9b ec')
# CWbytearray(b'2e b9 fa 92 1b ed 56 89 29 a6 84 89 2c 45 ab a0')
# CWbytearray(b'c0 57 4e 84 23 a7 8e 50 0d 4c 43 0d 0a b6 21 c2')
# CWbytearray(b'e6 86 c8 55 a8 7c c7 53 1a 58 cc bf 43 42 db b6')
# CWbytearray(b'0d 9d 2f a3 de 80 7f ff ae 8c d3 f6 46 55 f0 11')
# CWbytearray(b'e3 8b 82 71 f9 83 ea d2 66 5f 74 48 e5 ea fb dc')
# CWbytearray(b'4d a3 08 8a 56 1b 82 d4 dd db 80 e1 ce 2e 11 7b')
# CWbytearray(b'f4 b6 80 5c 76 7f e8 75 8d bb 91 11 b8 63 d1 9a')
# CWbytearray(b'3b e2 66 a7 78 c1 e5 7b c0 6e 8c 85 98 6d 07 32')
# CWbytearray(b'47 08 ba ff f2 aa c6 7f 68 6a 78 d3 a1 60 5d f0')
# CWbytearray(b'97 62 24 1d cc ce 5e bb 50 99 af 17 50 01 ae cc')
# CWbytearray(b'33 5a 99 f3 c4 26 3e a9 9f d3 74 af 62 06 19 93')
# CWbytearray(b'1e 2a 35 c5 02 9d 1c 45 59 32 08 70 37 04 af 8a')
# CWbytearray(b'ed b3 0e 8a 28 22 77 21 c7 94 f2 00 08 a0 91 03')
# CWbytearray(b'2f f5 77 af 37 b3 37 95 64 f5 32 b5 a0 8f 2e 6e')
# CWbytearray(b'44 65 ab 0f cd f1 ef 7f b8 60 a4 87 72 8c 98 d1')
# CWbytearray(b'bb 65 d4 3c 90 97 97 0b 64 a2 a8 ec 1d 11 40 94')
# CWbytearray(b'b3 1e 7b ac 0a 5a 7a 93 ed 98 89 8b 38 55 ef a1')
# CWbytearray(b'27 09 36 e0 d9 9d 3c eb 9f 0f 55 18 4e e5 84 65')
# CWbytearray(b'82 9d 47 54 7c ec 02 49 52 6a 7b c1 3c c4 bd ef')
# CWbytearray(b'0a 92 b2 61 9d 9e 7a 16 e6 51 cc 49 d7 f3 43 78')
# CWbytearray(b'e2 1b 1a 48 9e 5c 3c 4a 80 a1 3f 70 89 58 cb 33')
# CWbytearray(b'9c db 80 60 ff 6b 60 60 e7 fb 13 60 e8 47 10 97')
# CWbytearray(b'c8 68 be 9d 95 43 80 6a 8c 29 93 6c ed a1 72 c3')
# CWbytearray(b'67 39 61 5f 60 5b d7 cf de 77 4f 2c 13 00 3d f9')
# CWbytearray(b'd2 fc 07 22 74 04 f1 34 78 b4 e3 80 e5 7e 41 d8')
# CWbytearray(b'78 03 c8 8c 45 7c af 75 57 ed c6 9a 98 44 02 3a')
# CWbytearray(b'7b 71 74 a2 c9 5d b5 36 94 ee a9 5e 53 de 0b 4d')
# CWbytearray(b'af 68 58 eb ba 44 4b ce b5 c5 50 e5 af 6f 2a 20')
# CWbytearray(b'8d c6 d4 3b b4 0a 88 0c 06 6c db 81 1d ef d0 f4')
# CWbytearray(b'9f 02 15 d7 8e 35 83 1e b5 e0 98 70 6f 03 05 f6')
# CWbytearray(b'69 95 09 c6 e4 c0 51 8a bd 5c 96 2f 78 c2 69 de')
# CWbytearray(b'1e 51 58 8c 92 a7 3c e1 a1 7d bc 36 b3 61 74 2b')
# CWbytearray(b'14 e8 24 b2 85 ed 7b 56 3c 11 04 ec 8d 4f 6e cd')
# CWbytearray(b'cb 55 03 52 be ca 8c d9 96 78 6c 5c f0 2c dc 30')
# CWbytearray(b'2a 94 52 83 20 9b 98 a2 be 73 50 66 1e 3b a8 84')
# CWbytearray(b'b7 d4 e6 1d 29 84 a8 6d 0c 56 15 b1 d6 b8 04 ec')
# CWbytearray(b'be 2a ee 9e d2 9b a0 df 59 04 23 b3 bc 8a db 3e')
# CWbytearray(b'22 da 2f 97 26 5d 30 e7 bd 8b 5f bb 2a 95 d9 9c')
# CWbytearray(b'63 2c a0 e2 2e 84 a7 a5 13 e6 b2 6b fc 33 2e 2e')
# CWbytearray(b'f6 ab 94 63 05 b5 cc 98 c8 9d d7 92 2e ba 2f 4b')
# CWbytearray(b'31 ae 1d 36 94 04 17 10 7e c9 df 70 ef d4 0c d8')
# CWbytearray(b'74 a7 ee 91 6c 3d 1a 03 2a f9 1b 25 1c 9a db a8')
# CWbytearray(b'cc f4 32 b7 58 e6 b6 6e 31 d6 ff c7 63 1e 59 26')
# CWbytearray(b'1a d1 4e 84 b6 8e 79 90 98 7c 78 b7 4d 28 7d d4')
# CWbytearray(b'1d f6 11 c4 6d 28 de 15 b9 53 47 74 c0 ae 32 a2')
# CWbytearray(b'11 f1 4d 5c 8d 8b c8 e4 04 80 a5 76 04 81 41 7a')
# CWbytearray(b'68 09 50 00 39 1f 04 a7 cf 1c d3 82 5b 96 f6 5b')
# CWbytearray(b'fb e1 4a c7 65 4d b4 b1 09 75 20 54 19 70 b5 b7')
# CWbytearray(b'86 e9 12 17 22 dc 57 34 fe c9 e1 55 dd a3 2b 40')
# CWbytearray(b'00 92 6c 71 04 31 29 37 69 0b 37 87 49 9b a1 51')
# CWbytearray(b'10 98 4b 1d 59 62 53 04 df 2c 84 f4 ff 68 b3 05')
# CWbytearray(b'e8 0b 89 fb 8b c5 3b 57 38 a6 92 77 81 0f 92 a3')
# CWbytearray(b'fd 63 4c 20 b8 c9 f7 89 a3 44 aa 47 65 c6 eb 00')
# CWbytearray(b'4c 36 a2 93 fc 61 2f e7 4f 7a 25 40 a2 ad af d2')
# CWbytearray(b'86 41 1f 4b 31 ec 37 1f 55 76 f2 47 da 2e e1 1e')
# CWbytearray(b'3f fb 61 24 b1 1a 85 01 64 1f 0c 29 5a 8f 34 7c')
# CWbytearray(b'3e 6b 66 ff 17 c4 43 d8 06 84 b1 68 5b b9 27 0c')
# CWbytearray(b'48 1f 1a dd f3 4f 38 10 fc 75 64 22 0b 17 77 4e')
# CWbytearray(b'5b 7d 36 c5 f7 96 d1 b8 a4 b1 b8 b3 83 5c 40 aa')
# CWbytearray(b'8a 64 e1 19 24 8c 9f 7d fe 03 4d 16 f0 ca 05 d5')
# CWbytearray(b'c4 62 0b cf b3 6f c1 55 aa 55 8b 18 61 f1 35 43')
# CWbytearray(b'9b b5 29 64 1b 22 3a 5e ad 3f 84 df 35 51 74 0d')
# CWbytearray(b'2c 54 91 6c 1e ec c3 15 e6 c6 96 08 33 c6 fc b4')
# CWbytearray(b'2d bd 83 f3 80 ed 41 5c 8b b5 4b 6f 1c 21 10 57')
# CWbytearray(b'cf 09 a8 df 4f 07 bd cb c4 8e 50 45 d4 11 31 42')
# CWbytearray(b'8d 30 02 79 e1 90 cb f9 4c 59 69 8a c3 d5 3f 7c')
# CWbytearray(b'e7 d1 64 bc ae 9a 34 e6 ed c6 e2 5f 92 99 07 11')
# CWbytearray(b'f5 ee f8 6a ed e6 69 cd c7 6e 0d 04 71 3f 11 02')
# CWbytearray(b'4c 96 00 f2 4e 7b 58 cb 71 8c 5b 67 e5 6c 49 85')
# CWbytearray(b'04 7b 73 38 48 19 8d 9f 8c 40 c5 8d 20 90 0f ae')
# CWbytearray(b'64 81 32 60 0c c3 7a 28 01 a8 23 5a 1e 17 4f 73')
# CWbytearray(b'02 77 7b fd ca 38 51 c4 2e 4c d1 ff 51 cf b6 54')
# CWbytearray(b'3f ce 2b 58 ac e6 ba a7 65 5b fc c6 2d 21 b4 bc')
# CWbytearray(b'2a f5 52 96 ee 4f 08 2f f1 be 23 cc e7 e0 a2 7a')
# CWbytearray(b'54 f4 e3 f0 2e 27 61 9e c0 fd 2d 1a a9 6e 15 02')
# CWbytearray(b'fa ad c9 9e f3 69 52 b2 16 1b 88 10 1e 24 ca 14')
# CWbytearray(b'33 0f b1 e0 3a 76 1d 8a 4a 54 94 7b 72 ef 45 e2')
# CWbytearray(b'1a 6d c5 7e 0b d8 40 c9 6b 5d 2b db e6 ff a5 fb')
# CWbytearray(b'3a 6a e9 20 e9 4d 1b 7a 51 16 fb 74 71 fe 2c 91')
# CWbytearray(b'90 6a 8c 20 a7 f4 16 be 7d 15 62 e7 f3 3b 18 bf')
# CWbytearray(b'07 9b b5 b7 8c e4 62 b5 f2 f6 24 dc 6c 3c 34 97')
# CWbytearray(b'1b e5 18 63 52 06 d0 ee 6d 50 38 31 18 21 e7 2d')
# CWbytearray(b'f9 64 c0 52 7c 7b 8c b8 03 ca 9a 0b b0 85 c6 a3')
# CWbytearray(b'4f f5 87 ea 8a 75 de a3 42 29 9c 92 8b 9e 2f 58')
# CWbytearray(b'0a 49 e3 2e 1b 86 f8 ee 02 99 fb a8 ca 59 65 df')
# CWbytearray(b'8a 50 15 62 ab 34 07 f5 60 2f 1f 5c 31 89 63 1d')
# CWbytearray(b'b1 7a bd af ab 9c 7a d4 31 c8 1f 65 9a a2 cd 47')
# CWbytearray(b'84 20 04 d1 a5 7e 80 c4 ec 00 80 a5 df 83 0a a3')
# CWbytearray(b'17 c4 30 05 3b 3c 5c 47 5e df 51 cf ef 17 93 58')
# CWbytearray(b'6e 0c 56 67 b4 0a e9 58 d1 55 38 69 b5 e9 e1 95')
# CWbytearray(b'77 08 7f 0a 09 37 fa c3 71 10 58 4e 15 32 2b 6d')
# CWbytearray(b'f6 56 25 71 53 51 6d 72 e7 d6 60 ee ab 72 7e b1')
# CWbytearray(b'9e 02 67 f0 f1 c0 93 11 bb b5 da 0b 54 e1 1f 33')
# CWbytearray(b'bb d6 45 b1 05 b3 a3 21 d8 91 44 5f 3b 57 c2 ba')
# CWbytearray(b'd8 f8 da d4 83 c5 d3 d6 4c 72 cc 30 df bc c8 a9')
# CWbytearray(b'3c 23 bf 49 10 bd 15 60 b0 f7 be 73 f0 46 12 57')
# CWbytearray(b'2e bf 41 0c 31 21 10 bd e3 85 14 d7 4b bf 9d a2')
# CWbytearray(b'54 c6 5e 81 42 62 23 01 6a 08 f5 b3 7b d8 cd 07')
# CWbytearray(b'b7 97 72 af 51 f6 2e 30 bd ab 62 ea 1b fc 77 36')
# CWbytearray(b'f1 ee cd 9a 1b a0 2d f9 51 c8 be 73 ac 42 17 2d')
# CWbytearray(b'6b c3 76 b5 7a 74 0d 1f f7 6b 0f 6e d2 15 a9 06')
# CWbytearray(b'70 cc ca f9 91 b6 3c c3 32 16 de 66 7a ff ef 05')
# CWbytearray(b'c6 f6 c5 d8 97 ed 84 f2 e8 7f 14 49 56 9f 58 f0')
# CWbytearray(b'90 18 f9 28 7a 32 43 cd 1d 66 b6 f0 6f d6 1e 7e')
# CWbytearray(b'e8 71 1c fc 63 20 94 84 62 17 88 23 02 05 4f 2e')
# CWbytearray(b'04 c6 32 96 82 8e 4c bd ba b3 4a f3 2f 20 4e 88')
# CWbytearray(b'0a 81 05 5c 92 c4 47 30 92 92 ea cb 8c e6 e9 f6')
# CWbytearray(b'35 c7 d4 51 bf 74 12 5c 7e 33 37 a0 c2 5a 8c b5')
# CWbytearray(b'a0 f8 cc 6c dd 67 d2 26 77 57 74 b0 cd 6f 66 87')
# CWbytearray(b'12 c6 d5 e4 ee cb 6c 06 98 2c 72 16 fa 3f a7 4f')
# CWbytearray(b'bd b8 8f 50 cb a4 6a 35 94 0f 50 c5 c7 b7 82 72')
# CWbytearray(b'ec 62 6c 66 83 44 b6 46 38 11 a0 96 cb 16 41 65')
# CWbytearray(b'd0 88 05 6e 0b 9f c8 a5 b6 7d 44 22 44 29 8a 4f')
# CWbytearray(b'6c d8 cf 26 9b 40 c8 76 a8 45 1c e4 00 fb 3f 3c')
# CWbytearray(b'21 fa 1d e5 78 23 cc 9a 1a 2f 8e 77 9b 61 50 7b')
# CWbytearray(b'5f 7c 4d 98 82 e1 f1 8b a3 ee 0e 11 4b 44 c1 a6')
# CWbytearray(b'a0 aa c9 ab 9e d4 11 44 38 91 99 6f 1e da 82 29')
# CWbytearray(b'bb b2 15 77 00 cf 33 5c 4f 19 80 95 46 86 b3 01')
# CWbytearray(b'1f 28 08 fa 70 2b 28 3a a9 74 10 1c 4e aa bc ec')
# CWbytearray(b'be 4d 1a 2d b6 38 0f 08 e4 4b 05 51 87 04 c7 d6')
# CWbytearray(b'73 25 ec 78 15 7d fa 3b 0b c2 82 8c 1f 7b ed 0c')
# CWbytearray(b'a2 d7 74 36 ee 8e ba 00 5d e4 b0 17 cb 9f ce 81')
# CWbytearray(b'cc ac 15 57 3e ed ca 81 db 2b b4 61 3f b5 57 e2')
# CWbytearray(b'b5 9a 59 a2 85 85 93 ae 29 49 6a c1 d8 55 15 ca')
# CWbytearray(b'c5 e9 00 e4 96 77 0a ce ce 23 a9 2e d7 ed 11 1c')
# CWbytearray(b'08 ae 41 d4 6b 1c bb d7 b2 c5 09 01 85 b9 be 2d')
# CWbytearray(b'7f ff 2c 44 6a 1c 62 f6 a0 13 24 47 e7 38 e5 c4')
# CWbytearray(b'48 26 f5 6a 89 0d 7b 78 3c 2f 36 06 2f 26 b5 00')
# CWbytearray(b'a0 27 e9 aa 32 a1 26 d4 8f 15 4b b9 23 63 85 25')
# CWbytearray(b'ec 03 f5 ea 65 99 23 7d 67 f1 cd 10 30 f3 0b 76')
# CWbytearray(b'db ef 8d 69 ac 70 5d 22 3b 68 cc 4e 6a fa 13 c4')
# CWbytearray(b'a3 88 3d ee dd 99 52 9b d5 33 06 3e 6f 47 52 37')
# CWbytearray(b'e2 ed 88 cd 77 70 96 7f 84 1e 5b 0d c8 a5 ef e5')
# ...
# CWbytearray(b'24 b0 2d 99 78 ac 77 de bb 7c 46 ed b6 80 c5 e7')
# CWbytearray(b'6a ac 3c ab 6e 96 03 84 1f 3c 67 ee a6 96 29 2e')
# CWbytearray(b'e1 a9 38 29 7d 22 3c 9a a8 2c 0f 74 2b 4d 5d eb')
# CWbytearray(b'0d d5 29 d3 90 a4 bd ae 70 1e 73 db 7f 35 11 11')
# CWbytearray(b'5f 5f 85 7a 50 7a 51 99 b7 8d 76 0d f0 0b f2 a9')
# CWbytearray(b'bc a1 5b bb 1c de df ad 02 5f e9 1c 1a 2a cf 8a')
# CWbytearray(b'c5 66 d1 49 3d ad 16 96 e2 72 a8 99 f2 27 85 a1')
# CWbytearray(b'c1 21 4e 36 7e 83 0b 80 5b c2 a6 86 12 5b cd 0f')
# CWbytearray(b'2d 79 d8 71 fc eb 25 05 e8 db 53 2b 91 79 c9 2b')
# CWbytearray(b'4c b7 5e 05 81 10 47 ec c9 00 d9 0c 0f 34 47 6f')
# CWbytearray(b'b4 fa 8c 01 cd 98 0a 71 8f 14 9c aa 7d 1e ad 99')
# CWbytearray(b'e4 c0 2b 39 6b 3e 7f 9b d8 17 c4 c5 cc c5 79 67')
# CWbytearray(b'8a 3a 84 63 73 1f 1b ec 1b 93 bb 4b 1e ac 5e 3b')
# CWbytearray(b'b9 16 02 63 da a9 3c 46 f6 db 04 a0 9d 42 4f f9')
# CWbytearray(b'0a 75 53 78 f3 9e 73 90 1d ac 43 2b 54 a0 09 b3')
# CWbytearray(b'f3 e6 52 e3 99 2d e6 57 17 0b ea 69 2c 38 ca 07')
# CWbytearray(b'a7 18 7c d5 f6 db 1f e9 4f 68 d8 52 d1 cc 0d 3d')
# CWbytearray(b'45 ac 34 25 cc 18 5a 2e 0b 7b a7 60 7f 56 c1 d1')
# CWbytearray(b'5c f2 b3 d2 3e df f8 93 b4 b3 93 0c 3c 22 24 58')
# CWbytearray(b'0a 2c c1 45 62 af ab 2a 17 bd 67 28 27 9f 7d 33')
# CWbytearray(b'2c 56 31 e9 70 2a c8 c4 d0 83 82 9b 95 e6 63 dd')
# CWbytearray(b'7b e4 cd 59 86 20 aa 01 bf 03 87 67 cb 54 14 cd')
# CWbytearray(b'86 2e 80 bd 88 e6 51 b0 b7 a8 f8 74 85 4e 9a 8b')
# CWbytearray(b'e4 64 2d 85 3c 4c 48 32 e5 a2 0b 18 05 20 64 93')
# CWbytearray(b'74 2b a4 2c 5d 3b 7a 4d 39 46 da 3b 1f 37 e6 be')
# CWbytearray(b'f6 8b a0 9e 3b 86 47 c8 98 60 bf 3a 3c 87 8e 20')
# CWbytearray(b'3d 1e 6b c3 51 98 d7 48 2b 7f 3a d2 e2 6e 49 a1')
# CWbytearray(b'60 dc 73 9e 7a b0 46 76 b2 9e 31 7d 81 70 47 f9')
# CWbytearray(b'7d 20 f3 50 88 96 b3 f9 f6 67 32 be 26 06 c0 e0')
# CWbytearray(b'37 6d ba 93 7a 25 19 37 ed 99 b4 73 c2 96 73 53')
# CWbytearray(b'fa a6 e1 cd 05 56 9c 6e 7e 91 a0 29 47 b3 aa db')
# CWbytearray(b'3d e7 dd 98 e4 41 0b 93 d6 96 12 1c 77 f3 e4 9f')
# CWbytearray(b'ad 79 2f ce ae ab e1 9b f1 c4 65 73 db d4 bc 2b')
# CWbytearray(b'0f 85 c8 da 0c d7 f5 42 10 5b d5 1c 47 29 90 f4')
# CWbytearray(b'16 9b 93 cc 8f d2 87 53 85 fd 83 eb 64 f4 4c cb')
# CWbytearray(b'4b b2 af e4 44 45 c2 17 ad 8d 78 d7 30 2c 16 0c')
# CWbytearray(b'3b a1 c2 a4 96 f1 22 dc 56 94 2f 90 c0 25 80 67')
# CWbytearray(b'78 86 28 5e 89 1a 94 ab e5 3d 0c 2b b2 c6 f0 4d')
# CWbytearray(b'ed ef b0 44 af 01 cb c1 f2 84 5a 61 f4 41 3f 93')
# CWbytearray(b'cd b8 fe 39 c9 07 73 b8 4f fa b3 48 e6 9f cd f3')
# CWbytearray(b'c8 1e ea 7f e9 f4 a6 2b a2 d1 72 a0 44 31 c2 0e')
# CWbytearray(b'71 41 cb 6e 88 f0 f9 6d c5 43 95 43 7e df ba 35')
# CWbytearray(b'd9 91 5c c8 fd 0b 06 89 50 91 d6 c9 d7 55 63 1a')
# CWbytearray(b'ee 02 12 91 01 ea c0 8c 2e 87 3d 6e bd 17 cc c5')
# CWbytearray(b'7a cb ea 87 8a ac 29 b2 23 09 8b d2 68 1f a7 41')
# CWbytearray(b'f0 6d 37 c6 2d 61 2b 56 ea 1a 20 20 20 7e 90 3c')
# CWbytearray(b'e4 3c 32 a2 31 03 02 72 f1 79 86 e4 47 96 e6 44')
# CWbytearray(b'0e 35 6a 38 b5 ce 85 f5 51 10 c5 61 72 48 84 5b')
# CWbytearray(b'0a c5 a4 4e d2 7f 09 36 aa 65 67 a0 19 cc 0d c6')
# CWbytearray(b'6c 08 0a d6 5d 62 9b 7e 62 11 a1 2c 93 c8 f1 da')
# CWbytearray(b'09 c8 59 d8 a0 bf 89 7e 62 73 e0 9f 04 00 c8 14')
# CWbytearray(b'50 a5 c0 9c 06 de cc 5c 15 f0 fb 99 a8 b9 20 a7')
# CWbytearray(b'ef 9a ff 2a 34 2c 63 8d 59 3a f8 49 b1 69 b6 e3')
# CWbytearray(b'80 fb fb 18 ba 4d 10 33 b7 ce ea f8 16 a6 48 1d')
# CWbytearray(b'88 e9 09 74 22 a8 a9 f7 86 62 db 88 74 8e c7 d4')
# CWbytearray(b'28 53 04 d4 0b 37 d8 ce f4 3b d8 29 42 70 a5 d0')
# CWbytearray(b'af e4 96 3f ec 89 de 7c af 44 5f 2c 85 9c 99 58')
# CWbytearray(b'75 10 2e cd 8b 99 ea b4 98 79 6e 9b a1 e0 8e 83')
# CWbytearray(b'ca 82 9c 16 1b ef 88 3e d0 82 e5 81 c5 d1 b5 4d')
# CWbytearray(b'5f c7 38 d7 1e cd 12 f3 a6 dd df 83 06 30 1f 49')
# CWbytearray(b'50 91 a9 cb 95 b7 7f 74 73 2c 09 94 2d c0 c3 c5')
# CWbytearray(b'2c a4 61 80 35 50 34 3b 5a 91 ef 16 9b 80 eb 7f')
# CWbytearray(b'36 e7 b0 b0 cd 15 e4 52 5d 6e 37 ac f9 c4 e0 9b')
# CWbytearray(b'88 10 15 8e a5 b7 86 15 4c e2 d9 0d 93 5a 4b c8')
# CWbytearray(b'73 4a 68 81 37 78 af b4 64 30 b4 a0 19 90 7a 76')
# CWbytearray(b'ee 71 65 a9 f8 2d fc a3 e1 f8 a2 d5 7c be b6 79')
# CWbytearray(b'87 96 67 0e ad a4 49 9c c2 90 1a b9 0b eb 36 90')
# CWbytearray(b'8a 44 49 c3 2c ff 14 4e 8c 9e da 7e 4b 6a 34 5b')
# CWbytearray(b'ba d7 90 cc 65 f7 03 45 43 aa 61 76 f8 9e 50 35')
# CWbytearray(b'ea 8f 7d 8b 78 a3 e9 49 1b 3f 48 d8 8d c2 d7 8e')
# CWbytearray(b'2b 91 03 8d 0a 88 69 9e b7 38 5e d1 83 ba 89 1e')
# CWbytearray(b'4d ea a3 5a 15 81 03 89 c8 e5 4c 74 eb c7 dc cf')
# CWbytearray(b'87 46 05 61 6c 9f 02 bc 02 b2 60 07 73 7c 41 c5')
# CWbytearray(b'c3 75 ce 2d e6 61 f8 8c c9 28 ce 7d 01 c0 76 7e')
# CWbytearray(b'aa 9a 3c 24 0e 2b dc b0 00 02 3b a4 72 3b 19 de')
# CWbytearray(b'5f ba 5f 5a c9 8d 9a 7a 41 a9 f8 75 ab 7c 09 36')
# CWbytearray(b'84 ac 05 c0 d4 66 b7 f8 88 ed 1c 71 04 13 91 5d')
# CWbytearray(b'c6 a4 f7 cf e5 17 33 f8 c2 fe 82 e4 0f 45 f8 ed')
# CWbytearray(b'df 77 bb 49 b5 48 57 f5 f2 16 1b 70 28 a6 d6 7e')
# CWbytearray(b'e9 cf 8d f1 10 c3 e9 3a bf 1a a1 2a f2 18 b4 5e')
# CWbytearray(b'd4 46 d4 18 8e 8b e2 2a a4 e6 90 fe bf 01 5e 23')
# CWbytearray(b'32 57 58 b0 a5 28 9e bd fb c2 af db 26 9f 35 fd')
# CWbytearray(b'46 bd 0d ee ba 2d db 48 9d 1d f0 3b 34 ba 73 44')
# CWbytearray(b'21 dd b5 ea 65 8e e3 f3 72 fb 3f 30 6d 9d f0 d8')
# CWbytearray(b'45 dd 98 ee aa 12 0d bc 1b dc 7e 89 25 5c f5 97')
# CWbytearray(b'ed 60 d2 ac 1c ef 27 7a 40 ea 3f e9 c1 d4 15 9f')
# CWbytearray(b'01 51 e3 9c 62 e3 83 3c 03 9e 57 35 0b 8b a3 f9')
# CWbytearray(b'a6 5d f5 ba 21 e3 12 8f ae 29 52 3d b1 9b 98 66')
# CWbytearray(b'04 0d 5a 89 94 25 19 c6 df b3 7a 85 98 1d eb 99')
# CWbytearray(b'0e 7d 45 18 d0 ea d3 b9 45 04 f4 44 ae c0 1a e2')
# CWbytearray(b'a1 d1 d2 b5 38 c8 eb c3 92 bb 6f 31 dd 79 4b 1b')
# CWbytearray(b'07 f1 61 81 b0 b1 17 b6 8f b5 c1 84 b2 09 c1 f9')
# CWbytearray(b'c5 e2 a8 ce 41 4a cb b2 88 79 c3 55 8e 9c 3d 3d')
# CWbytearray(b'4f 0f fc 26 92 a9 82 83 c8 f0 fd 05 55 cd f4 0a')
# CWbytearray(b'e9 17 13 bf b1 2e f0 1b e4 2a 9f 03 dc b5 81 14')
# CWbytearray(b'73 fe aa 3b d5 7b d7 9e 30 7f 91 e7 2c 02 7f a1')
# CWbytearray(b'2d e2 9d 61 87 6e a6 af 4d 79 65 a5 f7 36 c9 24')
# CWbytearray(b'4d a5 f4 0b df 55 ef 2d 30 0e b6 13 d4 f3 31 25')
# CWbytearray(b'63 4b f1 95 59 a5 40 39 71 19 23 fb 0f d4 60 1e')
# CWbytearray(b'81 8e 81 ac e4 b0 f1 47 3b c7 c8 57 9d ec a4 55')
# CWbytearray(b'08 c3 75 de d8 e2 ac bd 75 59 ca b8 e0 60 82 42')
# CWbytearray(b'ff 04 38 4a 1c 48 c5 c6 95 c3 f8 0e 7c d5 2b f8')
# CWbytearray(b'f4 bc 9f 6f c0 8c 95 c2 59 0c 6c c0 fe 85 30 b0')
# CWbytearray(b'd2 2e 05 46 e3 ca aa fd dd da aa f3 1d 1d db 15')
# CWbytearray(b'48 22 e3 31 6f 7b 91 cd cd f7 94 0e e6 36 2b 3a')
# CWbytearray(b'3f 6c 8e 53 34 6c 43 4a 4b f1 cd ae 61 ad 51 ba')
# CWbytearray(b'bb f1 7e 5b 2b 71 2a be c3 39 0c 17 0d c6 0c bb')
# CWbytearray(b'17 ad aa b1 95 d8 7c 4c 3d 60 32 84 a5 96 42 e6')
# CWbytearray(b'01 cc 26 55 cb 24 20 a6 75 52 f8 e3 6f 39 08 dd')
# CWbytearray(b'7b b2 38 d0 c1 27 1b bc 93 d7 db 0d 7b d9 57 3f')
# CWbytearray(b'c6 f8 85 61 96 26 3c 47 2b 99 28 40 fb d9 35 00')
# CWbytearray(b'74 94 10 a4 37 e5 72 a0 43 71 d5 50 b8 1f 62 b5')
# CWbytearray(b'52 db 9d ec 4f 40 41 21 88 ca 80 4a fc 60 d3 0b')
# CWbytearray(b'49 34 66 bb f3 f0 6c 0c f6 46 d6 00 0b 8b 20 35')
# CWbytearray(b'85 21 37 e0 79 1b 82 53 b0 fe 0d 61 82 51 67 0b')
# CWbytearray(b'7f 36 2e 3a e7 68 ff 2c 97 9c 67 7c c0 6e 59 57')
# CWbytearray(b'50 b1 5a 7b 0c ee 5a 89 58 57 db 5b 4b f0 44 58')
# CWbytearray(b'10 bd 54 c0 14 33 6a 7d 33 05 3d 33 66 21 d7 01')
# CWbytearray(b'57 0f d6 3c 22 b4 6e 6f 79 54 d8 b0 39 27 15 a4')
# CWbytearray(b'c0 59 e9 a9 6c b4 2c 50 1e 27 be 5e 33 a5 67 f8')
# CWbytearray(b'0d 7e 3f 00 39 7e 65 ae 07 93 d3 a3 04 92 df b4')
# CWbytearray(b'f6 30 05 6f 91 b2 c9 70 56 00 ab fd 1f 11 c4 b1')
# CWbytearray(b'04 04 69 d8 77 73 a4 be 1a 68 8b a5 a9 e2 bd 27')
# CWbytearray(b'1e 57 96 a7 d5 69 ef f1 e1 2f 71 13 41 ee 3d 1f')
# CWbytearray(b'08 ca 54 0f 34 16 23 29 bf 31 25 7d eb 95 ca 4e')
# CWbytearray(b'4a 93 db cc f4 78 cc 58 10 f0 e8 d1 80 e9 e3 52')
# CWbytearray(b'40 fc b6 2a 7a ad a7 2e 3b 61 de 81 3a 36 1c 2a')
# CWbytearray(b'4a 11 4e 79 a0 1d be b8 fc 0a 48 f5 2b e0 29 9b')
# CWbytearray(b'3a d7 83 51 d9 2c c7 3c 28 b0 04 70 8f b0 34 f0')
# CWbytearray(b'aa 51 fe f2 21 d6 6f 9e 78 f8 86 b2 01 21 71 70')
# CWbytearray(b'72 f8 43 65 b4 f4 4f c4 73 c5 e6 a7 f4 36 6c 29')
# CWbytearray(b'49 ba dd 45 84 a6 96 2f 42 2b 98 26 e3 eb 66 ab')
# CWbytearray(b'69 83 d8 a4 2a be 53 9f a8 13 ca 92 3c 53 5a e9')
# CWbytearray(b'00 79 cb 84 05 3f 33 32 3c 03 33 88 be a5 b3 6c')
# CWbytearray(b'da 49 6e a5 b1 cb 1b 93 72 16 8a 3e c0 82 ee f5')
# CWbytearray(b'68 38 5a 0a c9 cb a9 3e 6e 7c 2a 36 2c 26 e8 96')
# CWbytearray(b'55 3e b2 05 39 7f 38 88 ed 43 76 b7 89 9a 54 b0')
# CWbytearray(b'1f dd aa 4a 3a e1 9e f3 6d 3f 34 4b a2 6e 67 45')
# CWbytearray(b'84 a4 f5 45 7a f5 53 f3 01 1f 1b fe 6c 56 35 27')
# CWbytearray(b'e7 f6 97 9e d0 10 59 cc cf db f8 16 f5 d2 70 88')
# CWbytearray(b'03 bf c9 df 92 31 5e 98 72 a7 81 28 2e ed 3b 7f')
# CWbytearray(b'b7 77 44 55 b7 50 cd 91 44 a3 96 f5 82 e8 62 47')
# CWbytearray(b'80 1a 0f 2f ca 99 54 53 2d 03 de 13 4c 74 2d 97')
# CWbytearray(b'35 a8 c8 9d e3 28 6a b0 be fe f7 53 20 f1 a8 83')
# CWbytearray(b'86 bc 34 57 64 82 aa bd 9a 71 3d c6 6b b6 33 14')
# CWbytearray(b'1f 15 34 5d be 43 70 54 5d ef 35 74 a8 82 46 d1')
# CWbytearray(b'6b d8 d9 36 ce d7 01 b6 49 64 4d 96 c5 7c 76 23')
# CWbytearray(b'51 c8 1a 45 02 03 a4 f6 88 d5 aa ac 43 cf 2a 41')
# CWbytearray(b'7c 0b 89 83 87 50 2b 5d 18 a1 38 24 64 19 91 78')
# CWbytearray(b'8e a8 b1 82 f0 ce 01 1b 07 ab 9f 96 76 e7 68 03')
# CWbytearray(b'23 56 c9 bb 26 fc 3c 13 8a 3d 58 1b 62 2d e8 78')
# CWbytearray(b'1b bc 64 11 66 7d 0d 21 15 af 44 60 54 99 9d b9')
# CWbytearray(b'31 5c 23 c6 59 6d b0 14 82 80 b0 93 df 13 97 ce')
# CWbytearray(b'c4 e6 71 71 e3 15 d8 d1 59 ef 66 25 52 af 5c 2d')
# CWbytearray(b'95 62 c2 2a 27 bb c5 2f ee 64 31 67 f6 9e c5 55')
# CWbytearray(b'b7 67 b9 e5 13 75 7b cd db 34 a3 99 99 4a 69 de')
# CWbytearray(b'c7 51 b1 23 15 b1 96 aa 3e 53 6f b6 96 82 dd 0a')
# CWbytearray(b'24 65 2f e9 44 5d 7a 11 a8 c2 20 7b d8 1a 29 26')
# CWbytearray(b'f4 f6 08 7a 7c 72 6d ef 97 6b 58 8e 39 11 f6 b6')
# CWbytearray(b'70 bc ad 9c 2c f8 a4 8a 1f 4e bb 59 0b 7b 13 ef')
# CWbytearray(b'e1 b9 0f 30 ae b3 28 93 e4 14 f4 9b 99 f9 bc f6')
# CWbytearray(b'd4 b2 29 a1 b1 f8 aa db d8 c1 c2 63 74 a1 c2 d5')
# CWbytearray(b'a1 2c 9f 2e c0 c0 bc 21 88 98 1b 0e e9 79 b4 fd')
# CWbytearray(b'3c 13 35 3e df 0f 48 29 ee f8 65 03 34 ca 36 41')
# CWbytearray(b'b8 50 21 68 ac fa 26 21 1d 68 45 20 ac 83 2f de')
# CWbytearray(b'41 e1 2f 2b f6 8f 0f c7 05 d0 69 08 a7 b2 77 94')
# CWbytearray(b'29 7f d9 68 f0 ea 3c 77 1a 5c ff 5c b5 3f ab 01')
# CWbytearray(b'4e 54 15 68 c8 3b 35 3f 62 eb 42 88 76 84 bc ed')
# CWbytearray(b'9f 04 f3 8d 3a 73 a3 e3 09 28 ff a0 86 a6 2b 78')
# CWbytearray(b'dc fe dd 25 a0 bf d5 56 d9 75 9a d2 f2 8e b8 f6')
# CWbytearray(b'aa a6 80 7c 43 10 30 72 cf da 31 aa 45 c3 06 50')
# CWbytearray(b'f0 c1 28 9b e2 52 70 3c 2c 38 60 a5 cf c3 83 bb')
# CWbytearray(b'bf 44 f7 ec 96 89 f2 ca 09 37 33 97 d6 ad 3a f9')
# CWbytearray(b'f5 52 c2 c3 45 72 4b aa ac cf 1b 6b 75 7c cc 9a')
# CWbytearray(b'a8 3e 3e 80 28 c0 94 0a 0e ca b4 e2 a4 30 73 b1')
# CWbytearray(b'9e 8c e2 3d 43 65 a0 0b 47 f1 8f 44 03 44 58 b3')
# CWbytearray(b'9b 59 c5 84 0d ff 6f ae 2a 40 2d 3b e7 b9 1d bf')
# CWbytearray(b'f8 21 e4 6b 5b 75 37 86 68 a9 aa 86 b1 eb 0d b6')
# CWbytearray(b'8a 27 3a be f1 fd 02 b0 49 af d2 53 ed 31 51 ba')
# CWbytearray(b'5f 5c c3 bd 4f fe 01 f9 a7 20 c9 05 bc 1f ad 0f')
# CWbytearray(b'43 34 68 97 16 41 78 b3 d0 12 21 4c e4 b0 1c d0')
# CWbytearray(b'db 6e 97 01 67 de 7c 8e a8 9e 90 bd 3c 37 c5 f2')
# CWbytearray(b'15 a7 36 1a 65 fd b4 d4 db e1 81 0a dd a0 40 23')
# CWbytearray(b'43 f0 44 8e e4 48 45 ed e4 bc 55 15 12 6e 5e 22')
# CWbytearray(b'01 fa 8e 58 50 ef 2b c1 ba 0e c5 ef fe 02 4d 8e')
# CWbytearray(b'3d a6 9f 8f fd 86 d6 d3 c1 4d 5e 94 52 ed 27 47')
# CWbytearray(b'13 8b dd 66 ee bb 08 c0 d7 be ed c1 fc ce c6 ac')
# CWbytearray(b'2b 15 2d c8 bc 61 12 76 ed 2a 09 1e 57 2f ae 6a')
# CWbytearray(b'7a 3f 7e 43 c9 90 e4 2a d0 12 47 ca c0 f1 60 85')

# %%
from tqdm.notebook import trange
import numpy as np
import time
from Crypto.Cipher import AES

ktp = cw.ktp.Basic()

traces = []
textin = []
keys = []
N = 10000  # Number of traces
plaintext = [
    0x00, 0x11, 0x22, 0x33,
    0x44, 0x55, 0x66, 0x77,
    0x88, 0x99, 0xaa, 0xbb,
    0xcc, 0xdd, 0xee, 0xff
]
# initialize cipher to verify DUT result:
key, text = ktp.next()
cipher = AES.new(bytes(key), AES.MODE_ECB)

for i in trange(N, desc='Capturing traces'):
    # run aux stuff that should come before trace here

    key, text = ktp.next()  # manual creation of a key, text pair can be substituted here
    text =plaintext
    textin.append(text)
    keys.append(key)
    
    ret = cw.capture_trace(scope, target, text, key)
    if not ret:
        print("Failed capture")
        continue

    assert (list(ret.textout) == list(cipher.encrypt(bytes(text)))), "Incorrect encryption result!\nGot {}\nExp {}\n".format(ret.textout, list(text))
        
    traces.append(ret.wave)
    project.traces.append(ret)
# Out:
# Capturing traces:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
np.save('./AES_%s.npy'%Trojan_ID , traces)

# %%
from datetime import datetime
import os

now = datetime.now().strftime('%Y.%m.%d-%H.%M.%S')
os.mkdir(now)

traces_array  = np.asarray([traces.wave for trace in traces])
textin_array  = np.asarray([traces.textin for trace in traces])
textout_array = np.asarray([traces.textout for trace in traces])
keylist_array = np.asarray([traces.key for trace in traces])

np.save('%s/%s_traces'%(now, now), traces_array)
np.save('%s/%s_textin'%(now, now), textin_array)
np.save('%s/%s_textout'%(now, now), textout_array)
np.save('%s/%s_keylist'%(now, now), keylist_array)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 7
#       4 now = datetime.now().strftime('%Y.%m.%d-%H.%M.%S')
#       5 os.mkdir(now)
# ----> 7 traces_array  = np.asarray([traces.wave for trace in traces])
#       8 textin_array  = np.asarray([traces.textin for trace in traces])
#       9 textout_array = np.asarray([traces.textout for trace in traces])
#
# AttributeError: 'list' object has no attribute 'wave'

# %% [markdown]
# This shows how a captured trace can be plotted:

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()
p = figure(plot_width=800)

xrange = range(len(traces[0]))
p.line(xrange, traces[0], line_color="red")
show(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 from bokeh.plotting import figure, show
#       2 from bokeh.io import output_notebook
# ----> 4 output_notebook()
#       5 p = figure(plot_width=800)
#       7 xrange = range(len(traces[0]))
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\output.py:124, in output_notebook(resources, verbose, hide_banner, load_timeout, notebook_type)
#     122 # verify notebook_type first in curstate().output_notebook
#     123 curstate().output_notebook(notebook_type)
# --> 124 run_notebook_hook(notebook_type, "load", resources, verbose, hide_banner, load_timeout)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:357, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     355 if _HOOKS[notebook_type][action] is None:
#     356     raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 357 return _HOOKS[notebook_type][action](*args, **kwargs)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:474, in load_notebook(resources, verbose, hide_banner, load_timeout)
#     471 jl_js = _loading_js(bundle, element_id, load_timeout, register_mime=False)
#     473 if html is not None:
# --> 474     publish_display_data({'text/html': html})
#     475 publish_display_data({
#     476     JS_MIME_TYPE   : nb_js,
#     477     LOAD_MIME_TYPE : jl_js,
#     478 })
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:487, in publish_display_data(data, metadata, source, transient, **kwargs)
#     485 # This import MUST be deferred or it will introduce a hard dependency on IPython
#     486 from IPython.display import publish_display_data
# --> 487 publish_display_data(data, metadata, source, transient=transient, **kwargs)
#
# TypeError: publish_display_data() takes from 1 to 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %%
import matplotlib.pyplot as plt
plt.plot(traces[0]-traces[1])
plt.show()

# %%
np.save('./tr.npy' , traces)

# %%
from tqdm.notebook import trange
import numpy as np
import time
from Crypto.Cipher import AES

ktp = cw.ktp.Basic()

traces_t = []
textin = []
keys = []
N = 20000  # Number of traces

# 평문
plaintext = [
    0x32, 0x43, 0xf6, 0xa8,
    0x88, 0x5a, 0x30, 0x8d,
    0x31, 0x31, 0x98, 0xa2,
    0xe0, 0x37, 0x07, 0x34
]

key, text = ktp.next()
cipher = AES.new(bytes(key), AES.MODE_ECB)

for i in trange(N, desc='Capturing traces'):
    text, key = ktp.next()
    text = plaintext
    
    textin.append(text)
    keys.append(key)
    
    ret = cw.capture_trace(scope, target, text, key)
    if not ret:
        print("Failed capture")
        continue
    
    traces_t.append(ret.wave)
    project.traces.append(ret)
# Out:
# Capturing traces:   0%|          | 0/20000 [00:00<?, ?it/s]

# %%
from datetime import datetime
import os
now = datetime.now().strftime('%Y.%m.%d-%H.%M.%S')
os.mkdir(now)

traces_array  = np.asarray([ret.wave for trace in traces_t])
textin_array  = np.asarray([ret.textin for trace in traces_t])
textout_array = np.asarray([ret.textout for trace in traces_t])
keylist_array = np.asarray([ret.key for trace in traces_t])

np.save('%s/%s_traces'%(now, now), traces_array)
np.save('%s/%s_textin'%(now, now), textin_array)
np.save('%s/%s_textout'%(now, now), textout_array)
np.save('%s/%s_keylist'%(now, now), keylist_array)

# %%
# !pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (3.6.3)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (24.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (2.2.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (2025.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from Jinja2>=2.9->bokeh) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from pandas>=1.2->bokeh) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from pandas>=1.2->bokeh) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.17.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
p = figure(plot_width=800)

xrange = range(len(traces_t[0]))
p.line(xrange, traces_t[0], line_color="red")
show(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 from bokeh.plotting import figure, show
#       2 from bokeh.io import output_notebook
# ----> 3 output_notebook()
#       4 p = figure(plot_width=800)
#       6 xrange = range(len(traces_t[0]))
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\output.py:124, in output_notebook(resources, verbose, hide_banner, load_timeout, notebook_type)
#     122 # verify notebook_type first in curstate().output_notebook
#     123 curstate().output_notebook(notebook_type)
# --> 124 run_notebook_hook(notebook_type, "load", resources, verbose, hide_banner, load_timeout)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:371, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     369 if server is None:
#     370     log.debug("No server instance found for uuid: %r" % server_id)
# --> 371     return
#     373 try:
#     374     for session in server.get_sessions():
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:487, in load_notebook(resources, verbose, hide_banner, load_timeout)
#     485 # This import MUST be deferred or it will introduce a hard dependency on IPython
#     486 from IPython.display import publish_display_data
# --> 487 publish_display_data(data, metadata, source, transient=transient, **kwargs)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:637, in _loading_js(bundle, element_id, load_timeout, register_mime)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\jinja2\environment.py:1295, in Template.render(self, *args, **kwargs)
#    1293     return self.environment.concat(self.root_render_func(ctx))  # type: ignore
#    1294 except Exception:
# -> 1295     self.environment.handle_exception()
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\jinja2\environment.py:942, in Environment.handle_exception(self, source)
#     937 """Exception handling helper.  This is used internally to either raise
#     938 rewritten exceptions or return a rendered traceback for the template.
#     939 """
#     940 from .debug import rewrite_traceback_stack
# --> 942 raise rewrite_traceback_stack(source=source)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\core\_templates\autoload_nb_js.js:1, in top-level template code()
# ----> 1 {% extends "autoload_js.js" %}
#       2
#       3 {% block register_mimetype %}
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\core\_templates\autoload_js.js:113, in top-level template code()
#     111
#     112   {% if bundle %}
# --> 113   const js_urls = {{ bundle.js_urls|tojson }};
#     114   const css_urls = {{ bundle.css_urls|tojson }};
#     115   {% else %}
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\jinja2\filters.py:1721, in do_tojson(eval_ctx, value, indent)
#    1718     kwargs = kwargs.copy()
#    1719     kwargs["indent"] = indent
# -> 1721 return htmlsafe_json_dumps(value, dumps=dumps, **kwargs)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\jinja2\utils.py:669, in htmlsafe_json_dumps(obj, dumps, **kwargs)
#     665 if dumps is None:
#     666     dumps = json.dumps
#     668 return markupsafe.Markup(
# --> 669     dumps(obj, **kwargs)
#     670     .replace("<", "\\u003c")
#     671     .replace(">", "\\u003e")
#     672     .replace("&", "\\u0026")
#     673     .replace("'", "\\u0027")
#     674 )
#
# File ~\ChipWhisperer\winpy\python\Lib\json\__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File ~\ChipWhisperer\winpy\python\Lib\json\encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File ~\ChipWhisperer\winpy\python\Lib\json\encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# File ~\ChipWhisperer\winpy\python\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)    178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type URL is not JSON serializable

# %% [markdown]
# Finally we save our traces and disconnect. By saving the traces, the attack can be repeated in the future without having to repeat the trace acquisition steps above.

# %%
#project.save()
scope.dis()
target.dis()

# %%
# !pip install --upgrade bokeh==2.4.3
# Out:
# Collecting bokeh==2.4.3
#   Downloading bokeh-2.4.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (3.1.6)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (24.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (6.0.2)
# Requirement already satisfied: tornado>=5.1 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (6.4.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (4.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from Jinja2>=2.9->bokeh==2.4.3) (3.0.2)
# Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#    ---------------------------------------- 0.0/18.5 MB ? eta -:--:--
#    --------- ------------------------------ 4.2/18.5 MB 28.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 10.5/18.5 MB 28.5 MB/s eta 0:00:01
#    ---------------------------------------  18.4/18.5 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------- 18.5/18.5 MB 28.5 MB/s eta 0:00:00
# Installing collected packages: bokeh
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 3.6.3
#     Uninstalling bokeh-3.6.3:
#       Successfully uninstalled bokeh-3.6.3
# Successfully installed bokeh-2.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# holoviews 1.20.2 requires bokeh>=3.1, but you have bokeh 2.4.3 which is incompatible.
# panel 1.6.1 requires bokeh<3.7.0,>=3.5.0, but you have bokeh 2.4.3 which is incompatible.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
