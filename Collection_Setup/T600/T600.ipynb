# %% [markdown]
# # Breaking Hardware AES on CW305 FPGA

# %% [markdown]
# This tutorial relies on previous knowledge from the SCA101 course notebooks (in `../courses/sca101/`); make sure you go through these first to understand how a CPA attack works.
#
# In this notebook, we'll apply knowledge from sca101 to break a hardware AES implementation on the CW305 Artix FPGA.
#
# Some out-of-date background on the target FPGA project is can be found here: [Tutorial CW305-1 Building a Project](http://wiki.newae.com/Tutorial_CW305-1_Building_a_Project) (ignore the "capture setup" section, which uses the obsolete ChipWhisperer GUI; this notebook shows all you need to know about capture setup on the CW305 with Jupyter).

# %% [markdown]
# ## Background Theory
# During this tutorial, we'll be working with a hardware AES implementation. This type of attack can be much more difficult than a software AES attack. In the software AES attacks, we needed hundreds or thousands of clock cycles to capture the algorithm's full execution. In contrast, a hardware AES implementation may have a variety of speeds. Depending on the performance of the hardware, a whole spectrum of execution speeds can be achieved by executing many operations in a single clock cycle. It is theoretically possible to execute the entire AES encryption in a single cycle, given enough hardware space and provided that the clock is not too fast. Most hardware accelerators are designed to complete one round or one large part of a round in a single cycle.
#
# This fast execution may cause problems with a regular CPA attack. In software, we found that it was easy to search for the outputs of the s-boxes because these values would need to be loaded from memory onto a high-capacitance data bus. This is not necessarily true on an FPGA, where the output of the s-boxes may be directly fed into the next stage of the algorithm. In general, we may need some more knowledge of the hardware implementation to successfully complete an attack.
#
# In our case, let's suppose that every round of AES is completed in a single clock cycle. Recall the execution of AES:
#
# <img src="img/aes_operations.png" width="250">
#
# Here, every blue block is executed in one clock cycle. This means that an excellent candidate for a CPA attack is the difference between the input and output of the final round. It is likely that this state is stored in a port that is updated every round, so we expect that the Hamming distance between the round input and output is the most important factor on the power consumption. Also, the last round is the easiest to attack because it has no MixColumns operation. We'll use this Hamming distance as the target in our CPA attack.

# %% [markdown]
# ## Capture Notes
#
# Most of the capture settings used below are similar to the standard ChipWhisperer scope settings. However, there are a couple of interesting points:
#
# - We're only capturing 129 samples (the minimum allowed), and the encryption is completed in less than 60 samples with an x4 ADC clock. This makes sense - as we mentioned above, our AES implementation is computing each round in a single clock cycle.
# - We're using EXTCLK x4 for our ADC clock. This means that the FPGA is outputting a clock signal, and we aren't driving it.
#
# Other than these, the last interesting setting is the number of traces. By default, the capture software is ready to capture 5000 traces - many more than were required for software AES! It is difficult for us to measure the small power spikes from the Hamming distance on the last round: these signals are dwarfed by noise and the other operations on the chip. To deal with this small signal level, we need to capture many more traces.

# %% [markdown]
# ## Capture Setup

# %% [markdown]
# Setup is somewhat similar to other targets, except that we are using an external clock (driven from the FPGA). We'll also do the rest of the setup manually:

# %%
FPGA_ID='100t' # change if not using K100t CW305

# %%
Trojan_ID = 'T600'

# %%
import chipwhisperer as cw
scope = cw.scope()
scope.gain.db = 25
scope.adc.samples = 600
scope.adc.offset = 0
scope.adc.basic_mode = "rising_edge"
scope.trigger.triggers = "tio4"
scope.io.tio1 = "serial_rx"
scope.io.tio2 = "serial_tx"
scope.io.hs2 = "disabled"

# %%
bsfile = r"./T600.bit"

# %% [markdown]
# Before setting the ADC clock, we connect to the CW305 board. Here we'll need to specify our bitstream file to load as well as the usual scope and target_type arguments.
#
# Pick the correct bitfile for your CW305 board (e.g. either '35t' or '100t'). By setting `force=False`, the bitfile will only be programmed if the FPGA is uninitialized (e.g. after powering up). Change to `force=True` to always program the FPGA (e.g. if you have generated a new bitfile).

# %%
#target = cw.target(scope, cw.targets.CW305, fpga_id='35t', force=False)
target = cw.target(scope, cw.targets.CW305, fpga_id=FPGA_ID, force=True, bsfile=bsfile)
# Out:
# (ChipWhisperer Target WARNING|File CW305.py:591) Using default Verilog defines (C:\Users\j2217\ChipWhisperer\chipwhisperer\software\chipwhisperer/hardware/firmware/cw305/cw305_aes_defines.v); if this is not what you want, provide them via the defines_files argument

# %% [markdown]
# Next we set all the PLLs. We enable CW305's PLL1; this clock will feed both the target and the CW ADC. As explained [here](http://wiki.newae.com/Tutorial_CW305-1_Building_a_Project#Capture_Setup), **make sure the DIP switches on the CW305 board are set as follows**:
# - J16 = 0
# - K16 = 1

# %%
target.vccint_set(1.0)
# we only need PLL1:
target.pll.pll_enable_set(True)
target.pll.pll_outenable_set(False, 0)
target.pll.pll_outenable_set(True, 1)
target.pll.pll_outenable_set(False, 2)

# run at 10 MHz:
target.pll.pll_outfreq_set(10E6, 1)

# 1ms is plenty of idling time
target.clkusbautooff = True
target.clksleeptime = 1

# %% [markdown]
# CW-Husky requires a different setup when the ADC clock is driven by the target:

# %%
if scope._is_husky:
    scope.clock.clkgen_freq = 10e6
    scope.clock.clkgen_src = 'extclk'
    scope.clock.adc_mul = 8
    # if the target PLL frequency is changed, the above must also be changed accordingly
else:
    scope.clock.adc_src = "extclk_x4"

# %% [markdown]
# Ensure the ADC clock is locked:

# %%
import time
for i in range(5):
    scope.clock.reset_adc()
    time.sleep(1)
    if scope.clock.adc_locked:
        break 
assert (scope.clock.adc_locked), "ADC failed to lock"

# %% [markdown]
# Occasionally the ADC will fail to lock on the first try; when that happens, the above assertion will fail (and on the CW-Lite, the red LED will be on). Simply re-running the above cell again should fix things.

# %% [markdown]
# ## Trace Capture
# Below is the capture loop. The main body of the loop loads some new plaintext, arms the scope, sends the key and plaintext, then finally records and appends our new trace to the `traces[]` list.
#
# Because we're capturing 5000 traces, this takes a bit longer than the attacks against software AES implementations.
#
# Note that the encryption result is read from the target and compared to the expected results, as a sanity check.

# %%
project_file = "./"
project = cw.create_project(project_file, overwrite=True)

# %%
from tqdm.notebook import trange
import numpy as np
import time
from Crypto.Cipher import AES
import random
import time
ktp = cw.ktp.Basic()



traces = []
textin = []
keys = []
N = 10000  # Number of traces

# initialize cipher to verify DUT result:
key, text = ktp.next()
cipher = AES.new(bytes(key), AES.MODE_ECB)
testkey = [[]]
for i in trange(N, desc='Capturing traces'):
    # run aux stuff that should come before trace here
    testkey = []
    key, text = ktp.next()  # manual creation of a key, text pair can be substituted here
    
    text = [0xFF]*16
    for r in range(16):
        key[r] = random.randint(0, 255)
    print(key)
    cipher = AES.new(bytes(key), AES.MODE_ECB)


    textin.append(text)
    keys.append(key)
    
    ret = cw.capture_trace(scope, target, text, key)
    if not ret:
        print("Failed capture")
        continue
    time.sleep(0.2)
    assert (list(ret.textout) == list(cipher.encrypt(bytes(text)))), "Incorrect encryption result!\nGot {}\nExp {}\n".format(ret.textout, list(text))
    
    traces.append(ret.wave)
    project.traces.append(ret)
# Out:
# Capturing traces:   0%|          | 0/10000 [00:00<?, ?it/s]
# CWbytearray(b'8f a0 ad 67 b3 a6 a9 d0 a2 5d 6b 39 e7 29 26 69')
# CWbytearray(b'a7 dd 48 4f 24 2b 46 c9 03 62 7c dc 37 16 15 51')
# CWbytearray(b'57 81 99 f1 4b 73 b5 8e 0a bb 3b 5c f6 b4 83 42')
# CWbytearray(b'1e b0 5e 7c 79 b5 8d ca 96 f1 51 b2 30 3e a7 05')
# CWbytearray(b'd6 de 92 7f 6a d3 3a 24 4a 4e 30 b4 9f 40 d5 aa')
# CWbytearray(b'10 e5 9e 54 3d ae 31 81 61 a4 78 a3 01 1a 56 32')
# CWbytearray(b'ca ba 98 37 56 05 c2 a0 87 77 3f 16 15 9e b6 f9')
# CWbytearray(b'59 02 50 07 86 66 16 aa e1 ff 8d 84 be a0 78 a1')
# CWbytearray(b'7f 38 35 dd c9 32 a7 f0 a6 fd 03 c7 e4 df 05 ff')
# CWbytearray(b'6a 2f 15 d6 5f f6 98 7d 8d 7f 62 86 da 38 1e 76')
# CWbytearray(b'7d 61 36 c4 e1 6e 78 15 be 7a 64 f0 df e3 28 54')
# CWbytearray(b'a0 f3 6c 99 73 22 32 f0 10 7c 33 de eb c8 ed 0f')
# CWbytearray(b'11 8a d7 74 8e 1e c4 e7 8a b8 02 58 1d 0f 09 c7')
# CWbytearray(b'8a d9 8f f1 41 46 cb 50 d5 9b b3 1a a9 49 21 d4')
# CWbytearray(b'ca 18 c3 d2 7c 67 dc 19 9e 92 27 7b db 8e e0 47')
# CWbytearray(b'7c 97 28 9b ab 45 8a 52 9f b8 4a 4b 1c 2a f7 7b')
# CWbytearray(b'5a 13 aa bd 34 d3 ea 26 89 5b f0 7f 86 e8 35 9e')
# CWbytearray(b'2e ec 3e c0 a8 eb f0 44 9f 1f 95 aa 02 af 0c 39')
# CWbytearray(b'0f e5 c0 5f 66 cf 84 a2 dd 81 32 16 11 cd 93 7f')
# CWbytearray(b'6a 95 f2 d8 60 8e 35 a9 fd 95 c0 58 72 c5 d0 d4')
# CWbytearray(b'a5 ce ed 65 35 b9 e2 cb fe 87 fa d0 a3 bc fc 26')
# CWbytearray(b'12 33 d4 53 b8 05 a9 66 b9 27 be a8 09 32 0e 26')
# CWbytearray(b'68 f8 cb be 77 c0 94 03 3d 2c 0a 9a 3a 47 66 55')
# CWbytearray(b'01 49 d3 99 16 51 a4 bb df 57 2f c0 64 e8 6d 98')
# CWbytearray(b'5f 9f c8 b9 b4 d3 7e 69 ac ef a5 c5 51 7d 7e 8c')
# CWbytearray(b'b3 63 3a 2a e4 f9 d3 fb 07 a3 4f 80 33 27 be 5d')
# CWbytearray(b'f9 1d fc 8a 0f 40 2c 4b 42 ba 41 3c 53 98 a8 42')
# CWbytearray(b'4c 4f 63 54 e0 c7 a0 01 22 7d a1 12 80 92 83 d0')
# CWbytearray(b'a8 35 12 ce 59 e9 30 dc 25 51 9b b4 b1 1a 8c 26')
# CWbytearray(b'e1 96 f2 42 c6 f1 14 9f 11 87 e6 aa 29 46 0c 44')
# CWbytearray(b'35 67 eb fc f5 07 8c 1a d3 8f 1c 66 1d 99 13 50')
# CWbytearray(b'fe 37 30 84 f3 cd 64 4f 69 be 66 34 f5 89 4d 81')
# CWbytearray(b'c7 1e 82 53 51 88 0d 86 b0 dc 0a 67 48 58 ad d1')
# CWbytearray(b'7e ff 5a 1e 5b 5a c6 1b c5 3f 18 0c c2 4e d8 6a')
# CWbytearray(b'6e 5f fc 7e ec fc 85 d7 17 3c 09 0e d1 63 30 f6')
# CWbytearray(b'48 81 d4 17 ae aa 1f ba ee 55 2a 13 88 9f 6b 4c')
# CWbytearray(b'25 1f 3d 7b 0b 6e 5a 62 af 77 80 58 37 60 b3 2d')
# CWbytearray(b'6d 13 f4 89 87 43 25 71 55 dc 94 8a c2 60 59 55')
# CWbytearray(b'f9 09 af 68 a4 6e ab b8 ba c6 b2 46 47 83 8d 51')
# CWbytearray(b'cd 2c 5c 1e 5f fe de 95 99 6a d6 08 09 ee c7 0f')
# CWbytearray(b'd5 a6 64 f6 48 33 04 12 5b 60 52 a9 fa 8b 6b 8a')
# CWbytearray(b'55 07 9a 2f fd e1 bc 14 c6 a7 e0 2a f5 0a c5 70')
# CWbytearray(b'bf e2 07 f0 d3 67 4e 9a 5b 8a 83 40 dc 90 f7 3c')
# CWbytearray(b'71 55 e8 47 17 60 b1 0a 29 ac 43 ff 23 f3 d6 28')
# CWbytearray(b'd2 46 c0 36 39 a6 6c ec e9 34 aa 03 65 89 90 13')
# CWbytearray(b'16 13 c6 5b 4a 02 b4 ae 3f f7 f3 e1 9c b4 40 0e')
# CWbytearray(b'd5 57 04 26 1f 3b 40 66 db 28 4f f3 58 f6 5c b0')
# CWbytearray(b'19 9a 9d 89 b0 ed 5d 73 b9 92 84 b3 3f b6 d5 d1')
# CWbytearray(b'8d bf ef 9c 14 32 be 6d b5 c7 77 46 9a c3 b7 de')
# CWbytearray(b'b0 b2 e2 ef 6f 17 18 da 94 65 f9 05 73 f0 b4 fd')
# CWbytearray(b'12 6a f5 ce 9a c5 8a 59 1e b1 3b bd 95 3c 0c b0')
# CWbytearray(b'5a 11 42 ea f2 ff 66 af da 11 6b 65 cc 6d de 9f')
# CWbytearray(b'7b b4 28 04 99 c5 73 42 70 28 bc 65 ad ee 97 1d')
# CWbytearray(b'80 e5 a6 f9 c9 53 54 4a 77 88 70 a9 a6 fb ad a6')
# CWbytearray(b'fe f2 23 50 39 f9 94 01 cd 0e d2 56 89 38 94 a3')
# CWbytearray(b'4d e6 c3 bf 71 76 46 24 c6 b3 ec 63 fe 0d 81 b2')
# CWbytearray(b'9a 37 15 35 0d 30 ff d8 12 02 f9 26 66 27 ad f9')
# CWbytearray(b'28 94 c6 e5 26 3c db 81 a0 bd 20 21 aa 6f 14 17')
# CWbytearray(b'7f d1 28 52 67 d2 92 f7 ad f9 b1 57 35 13 b4 ac')
# CWbytearray(b'fa da e4 64 df c1 99 96 7d d7 0b 82 09 a5 23 da')
# CWbytearray(b'6d bf 5c 41 f7 a5 7f 92 25 e5 fd d3 fb a9 f9 c3')
# CWbytearray(b'84 33 46 6a 9a 6a 2b 69 1e ee c2 a7 85 63 3e c4')
# CWbytearray(b'76 4e c4 22 da 9d aa 4f 32 65 a6 fb 1e 67 e9 89')
# CWbytearray(b'71 6d 01 ec a2 79 57 04 d1 82 60 a1 94 54 81 6d')
# CWbytearray(b'29 37 40 8b 31 e4 d7 25 2d 8b 98 48 93 81 cc a1')
# CWbytearray(b'69 7e a0 e1 dc 1b f8 91 c3 40 78 ca 0f 7b ff 33')
# CWbytearray(b'a8 7f 47 a4 61 9e de 4e d2 8d 56 55 0d 73 3d fe')
# CWbytearray(b'be ac d1 15 61 23 83 d3 ab 00 5d f3 f1 de 0b 90')
# CWbytearray(b'84 f0 6b 86 65 76 52 0f d1 48 35 c0 7c 98 bd 93')
# CWbytearray(b'c8 99 b2 73 1e f2 e6 99 ef de 5b 01 64 81 a9 9c')
# CWbytearray(b'02 dc 17 91 ff 71 b9 08 a9 26 32 42 ca c1 a2 a2')
# CWbytearray(b'7c 19 66 4a fb 42 e4 d6 b0 4a 47 d7 f9 15 34 1c')
# CWbytearray(b'70 01 74 b0 e0 66 ee 87 a6 0e db 8b d4 e2 43 c4')
# CWbytearray(b'9a 41 0c 8d c6 11 99 ed 8d 12 4b 9b b9 e1 a3 92')
# CWbytearray(b'0f f4 fc b7 66 70 39 3c cd 2e 6f e9 fc a3 e6 01')
# CWbytearray(b'f1 da 01 fa b0 91 cc 28 da 61 8c 9f e0 f9 3a 92')
# CWbytearray(b'12 69 bd a3 0c 9c 6b 69 f6 98 5d f2 f8 80 42 24')
# CWbytearray(b'9f b8 36 04 16 7b a9 ad cf af 2f e9 31 2e 3b a4')
# CWbytearray(b'af 5a ac 69 b3 42 60 56 95 5c 8f 62 96 bd f5 80')
# CWbytearray(b'6e 87 51 c4 7a 80 d8 0f 64 11 6f bd e5 5c 86 9e')
# CWbytearray(b'48 c1 b1 d6 f2 96 d9 1a 71 a5 77 82 b1 ae 4a 97')
# CWbytearray(b'23 7c 62 e4 f5 92 fb 1b 6f e8 6d 9f 04 01 b9 0a')
# CWbytearray(b'b3 fd cd c3 b4 3a 93 11 02 41 a1 f3 6d dd a3 3c')
# CWbytearray(b'b9 3d f4 4a fa 0f aa ac 32 e2 ad e4 8c 8e 9d 26')
# CWbytearray(b'61 80 07 5b a2 f9 44 cd d9 ed d7 16 9d 83 cc e5')
# CWbytearray(b'89 3e 63 63 70 0a d1 d2 4b 43 e6 52 a8 9e af 37')
# CWbytearray(b'a4 71 98 43 98 7d a4 b2 6d 4b 47 00 e6 8d 93 41')
# CWbytearray(b'60 ca 75 7e 9c 7c 88 c7 00 42 c9 4b 1f a6 f7 c4')
# CWbytearray(b'9c 04 87 1c d3 c8 03 f8 a0 1e b0 66 3f f3 62 01')
# CWbytearray(b'87 c0 8a 66 c8 f7 e5 3a 0d 36 6b 2e 7f 41 b0 74')
# CWbytearray(b'e2 29 95 94 30 69 ed b5 e1 de 4b 42 35 77 c5 0b')
# CWbytearray(b'c1 91 20 4c 4a c0 78 2b 03 f0 7a 8f 9c 26 84 05')
# CWbytearray(b'd6 01 ee 05 6e 51 4f 24 fb e1 ac 90 ee 67 ae cb')
# CWbytearray(b'af 26 32 56 05 72 df 63 cb 18 d6 aa 09 3c 96 8e')
# CWbytearray(b'bd 8e c4 91 34 4f d5 da 73 0f bc a0 dd fc 50 55')
# CWbytearray(b'fd 46 53 87 82 51 fe 5f 55 50 23 cc a7 c3 3b f1')
# CWbytearray(b'93 56 da 2b a6 ca e2 f4 17 5b 94 11 07 d3 1d ea')
# CWbytearray(b'9a 80 dc 73 eb 0a f4 d8 d1 57 01 00 7a b1 a0 b5')
# CWbytearray(b'ce 33 44 a4 ff 23 46 26 7e 97 0e 94 5f 5a fd 17')
# CWbytearray(b'64 5e 65 8d c8 3c 01 21 a1 e2 8f 4d e5 98 e6 5f')
# CWbytearray(b'5e 6f 29 a6 b9 c4 33 39 3e 75 f6 90 52 38 d4 7f')
# CWbytearray(b'd8 bf 60 c8 c1 85 b6 fb c9 76 01 a7 00 d6 a3 3c')
# CWbytearray(b'89 be ab ec 6c 8d ed 5e 75 5b 23 35 5e 24 42 31')
# CWbytearray(b'c1 f1 9a e0 66 b6 62 7f 6c 26 f4 ab ca a0 80 7c')
# CWbytearray(b'2a fd 7e e1 e1 4d fd 68 d2 15 9b d9 bf 13 cc a7')
# CWbytearray(b'ef b7 8d 9c 8e 9e 0a 3e 7f fd a2 2b af 35 bf 3a')
# CWbytearray(b'89 89 26 f3 3e 94 97 20 9b d1 1f 36 a4 1a 6b c0')
# CWbytearray(b'6a 44 a0 da 3b 19 dd 97 84 6d 0b 09 b1 15 e0 d7')
# CWbytearray(b'a3 5c 56 44 6f 07 61 17 74 4d 18 c7 04 d9 62 e6')
# CWbytearray(b'4e ad d6 37 d3 d7 78 ab 76 ea 89 e1 9f ca ae f6')
# CWbytearray(b'a2 9b 20 4f 7f 9c 2f e8 35 20 77 a0 c5 ce 6c ac')
# CWbytearray(b'8a 87 58 a6 c0 ed 9f 48 84 93 3b f5 96 4a 47 48')
# CWbytearray(b'eb b4 e7 35 fe c1 f8 93 2b a3 89 2c 26 ba fa dc')
# CWbytearray(b'f9 c0 ad bc 0b 2d 90 60 74 9f bd 4a 51 60 17 99')
# CWbytearray(b'8d 44 c8 8a 1b 08 69 dd fe 45 05 94 9b 3d d8 c5')
# CWbytearray(b'88 40 db 6a f1 69 3c b5 c1 02 d7 de 1c 25 69 3b')
# CWbytearray(b'c4 7b d7 21 f6 a5 4c 9c a6 31 95 fc 98 75 85 23')
# CWbytearray(b'85 07 b2 9f e4 26 f3 13 af 0f bf b8 dc af 0a 8f')
# CWbytearray(b'b5 4f 2c a6 45 d7 b1 99 76 e3 c6 55 e7 ac cc 32')
# CWbytearray(b'07 48 2d 7e 76 09 70 d8 dc 00 78 57 b6 0d 4f 71')
# CWbytearray(b'c4 af b9 55 8d cf 50 41 1e f7 d6 27 a9 81 d2 8d')
# CWbytearray(b'31 23 3c cf 62 c3 df c2 7d c2 84 16 94 32 3d 67')
# CWbytearray(b'b0 09 c9 60 09 06 c5 ed 95 6c 51 82 d0 3e 15 0e')
# CWbytearray(b'c7 ca 09 cf de 25 24 46 07 03 f6 d9 3e 5e bd 5f')
# CWbytearray(b'76 5e 26 2a 25 1e f0 f9 86 3c 57 0f 98 03 f1 c7')
# CWbytearray(b'7b cc 8a 38 16 da 90 25 ef 3d 14 1d 44 ec e8 a6')
# CWbytearray(b'9b 72 d5 ca 30 b8 62 5f 7f 25 ff a2 46 d2 ac 5b')
# CWbytearray(b'9f fe 7e ff 00 b3 e8 4f 18 5e 24 3e 0b 28 70 28')
# CWbytearray(b'5d cf bd 69 ce 16 1e ee 67 6b 27 93 fc 08 e2 35')
# CWbytearray(b'c9 ad 90 11 3e f0 aa b0 fe 9c b3 c6 96 b4 b9 77')
# CWbytearray(b'6f dc 70 4a f0 4d 26 d1 ab 2f 87 1f 73 79 f4 c5')
# CWbytearray(b'c2 ea ed ca 9d b7 5d 45 00 84 ae 3f 2e 10 ae 13')
# CWbytearray(b'0d ba 58 31 e4 67 8b 52 19 90 44 b7 3e 45 a8 c7')
# CWbytearray(b'5f f8 79 25 70 44 c5 cb 65 f4 d7 32 ac d5 8e e7')
# CWbytearray(b'2a 29 61 09 1a 5b cf 49 5a 32 30 b4 6d a2 7a 33')
# CWbytearray(b'76 b3 da 3b 3f 4b 6f ea d1 8a 6b 34 00 07 45 b6')
# CWbytearray(b'd5 8e 0d 3c b4 46 7b a3 d2 8f 9a 66 ce 14 e5 78')
# CWbytearray(b'5d 78 97 2a 89 78 b9 9f 66 df dc e5 35 0d f5 32')
# CWbytearray(b'49 6b 42 8b 69 15 3e b6 8a 39 dd 64 f1 d1 84 e1')
# CWbytearray(b'30 3c 74 23 1f c7 79 7d e1 15 75 e5 04 f7 a6 7a')
# CWbytearray(b'c8 e1 be 94 27 ee 3a 97 85 94 1e 5e 18 cb 04 23')
# CWbytearray(b'03 1d 57 f9 e5 6a fe f1 79 d9 f5 0c f5 49 20 59')
# CWbytearray(b'41 fe 68 36 dd 3b c7 ed 60 e7 0b 7c a1 8c 9f b3')
# CWbytearray(b'69 1e 76 1c be ba 5a 34 db 5d 39 c7 98 67 5e a0')
# CWbytearray(b'7d 82 58 05 24 a5 0c 31 33 40 82 0b ac 06 84 d3')
# CWbytearray(b'c9 23 2d 45 c2 b8 62 84 d3 b0 bf 56 fa 62 a5 10')
# CWbytearray(b'94 23 73 99 5a b5 30 ac dc e9 3c 3a 63 17 b6 d4')
# CWbytearray(b'd7 c8 8c aa fa 79 67 6b 15 cc d7 a6 32 8e 11 ec')
# CWbytearray(b'dc b4 0b 73 06 8e bb 82 02 fc 6f 49 7b a5 d7 df')
# CWbytearray(b'a6 ff 06 ca aa 4a d6 a3 6e b0 25 3b 42 6c 20 d8')
# CWbytearray(b'21 11 20 c5 f3 87 9d 03 bd c3 0b be c6 ab 8e 70')
# CWbytearray(b'e9 e5 c7 a2 11 f2 55 fd a2 63 ce 0e ea 2c ad b5')
# CWbytearray(b'3f 71 e7 9b 95 c0 4e 51 7f ca 93 94 43 70 69 44')
# CWbytearray(b'9c ab 67 06 d3 d6 86 59 44 43 43 54 32 c3 a1 e1')
# CWbytearray(b'76 94 77 de f4 1b f4 58 ea ca 23 a4 b3 f1 a7 b2')
# CWbytearray(b'c4 79 8d 30 7d d7 19 aa 32 18 c8 6d 4d 5c 4a 81')
# CWbytearray(b'91 95 5e 9e 9a 82 a7 24 cb b0 06 83 b9 d3 6d 19')
# CWbytearray(b'9c b3 72 6f 1d fd 90 b7 16 68 5b 95 d4 e4 e6 50')
# CWbytearray(b'36 b7 9b bc 44 ea 11 45 ff 74 66 dd dc 66 e1 fd')
# CWbytearray(b'51 6c ff 13 43 c5 13 7d f8 18 7d 65 a7 f8 4c c5')
# CWbytearray(b'0b 92 bc 81 00 23 99 4b 09 e9 87 6d 4c df 22 f4')
# CWbytearray(b'87 65 24 02 6a d2 d5 e7 8a 52 39 3c 69 b4 89 fb')
# CWbytearray(b'e2 64 56 91 cd 9c 92 5c 0a 1e 96 79 6f 9e 0d d4')
# CWbytearray(b'03 c3 db 1c c2 0a 68 3a ef e5 78 62 19 09 e8 62')
# CWbytearray(b'89 ec 71 15 ae ac e6 04 92 1f f6 fa 77 84 7b 8e')
# CWbytearray(b'8d 89 00 70 97 be d9 c7 fd 59 4f bb 2d cf 63 62')
# CWbytearray(b'a3 a0 94 f4 46 a5 d8 2c fc fe 5a 21 60 87 4f dd')
# CWbytearray(b'11 4f d6 e5 45 e0 d4 59 65 aa 52 d7 d2 46 a7 df')
# CWbytearray(b'66 4e 2a b1 73 b5 9b 1b 7a 30 9a c6 4f 9c 73 c2')
# CWbytearray(b'6c 88 c7 44 e8 fa 6d bd df 2d a7 be a0 90 b2 05')
# CWbytearray(b'2d af 43 fb 1f ff 32 bd 3e 17 96 0e 2c 9e 44 27')
# CWbytearray(b'80 9a fb 09 e9 d6 4c 31 76 0a 4e 60 7c 44 73 dd')
# CWbytearray(b'0e b8 cc 92 e6 8c 25 f7 bf a6 3d f4 18 5f fa ec')
# CWbytearray(b'25 d4 62 cb 2e 1b d6 47 18 66 c5 f2 78 7e 95 13')
# CWbytearray(b'78 74 74 7c d4 f6 8b 04 08 5f fb 6e 83 09 57 5f')
# CWbytearray(b'64 d2 59 a1 fd 1e 33 1b 8a 6e 3b 16 fd cc 80 e3')
# CWbytearray(b'19 04 26 d8 d5 92 a2 95 be de 05 56 b5 41 51 1b')
# CWbytearray(b'73 01 4a 75 57 a1 cf a9 4a e4 62 da 1c 41 ed c3')
# CWbytearray(b'd0 e1 15 0e 80 8f 8d 4d e2 06 7f 11 19 2e a2 c6')
# CWbytearray(b'45 77 28 7f d5 e4 03 e5 7c 16 8c bd 3d 3f 86 1d')
# CWbytearray(b'6c b2 81 af 2c d8 c7 09 c2 27 00 59 1b 94 8a 0e')
# CWbytearray(b'a7 39 6a d1 e5 e3 77 f5 63 e6 08 24 05 51 25 52')
# CWbytearray(b'7f bd 68 51 6f 14 98 98 d0 66 f9 26 74 e2 94 da')
# CWbytearray(b'47 ea c0 43 88 f6 34 5e f0 ea 49 0b 9b 92 93 1c')
# CWbytearray(b'7d cc 75 78 4d 31 ec 72 36 b6 5f b0 6e 49 b9 40')
# CWbytearray(b'45 1d 82 e9 1f 87 d9 3e b8 3a dd 69 c5 cf ed 35')
# CWbytearray(b'69 f6 b2 ee 18 7b c8 13 9c 1c 30 38 f1 06 e2 6f')
# CWbytearray(b'be ca b5 fc 23 52 9b a9 04 69 fd 94 54 55 7e b6')
# CWbytearray(b'ec cb 80 34 3e ee 09 95 8d 68 47 06 f6 69 75 0d')
# CWbytearray(b'1a 19 a1 a3 da e1 ad c9 13 6b 84 16 e2 a8 b9 7f')
# CWbytearray(b'18 3f 8a ff 9e b9 e4 94 aa 45 5f 41 d2 81 03 b4')
# CWbytearray(b'a2 29 e5 28 4c 54 00 fd 7a ec f7 e4 c7 d9 c3 f3')
# CWbytearray(b'3a 4b 2b 57 b1 b6 4f 69 81 d5 ed c2 32 a3 30 df')
# CWbytearray(b'0e e9 e2 75 cf cf a3 15 08 45 be 5c 24 df 74 08')
# CWbytearray(b'94 5d 60 fb ec a0 e2 3a 34 dc 85 11 5f 0c 78 46')
# CWbytearray(b'8c 2e 0e fa ff 4e ec 6e 3b f7 9f 86 6f 32 43 d7')
# CWbytearray(b'f9 6e f8 09 ba 19 fd 69 77 71 c8 d8 d6 51 0a fb')
# CWbytearray(b'f2 e3 20 84 9f 33 ef 53 22 d0 df fb 68 80 69 15')
# CWbytearray(b'35 6e a3 1f 82 0f c1 a2 32 7e 5c 2d d2 d0 58 3a')
# CWbytearray(b'd4 0e fc c6 14 16 0d e0 69 fe 28 19 25 86 bf 62')
# CWbytearray(b'2e 16 fa 40 44 31 1b 65 e2 90 ec 4b 31 c2 2f 0b')
# CWbytearray(b'f0 f8 70 fd b7 a5 1e 17 a7 00 97 06 e5 26 8d 66')
# CWbytearray(b'fa 14 be 90 13 40 37 c0 e1 a0 74 f3 df e2 b6 03')
# CWbytearray(b'b4 dd 09 02 32 9e 6f 76 d5 cc f9 4b 78 74 8b 0e')
# CWbytearray(b'a2 cd 68 8e 33 1d 05 cc 82 d7 60 96 46 a1 41 64')
# CWbytearray(b'a1 02 e4 1a 5e 8a c2 42 56 5b e7 9d a9 cd 48 af')
# CWbytearray(b'64 04 20 24 1f 1c 17 a2 96 10 84 43 0a 90 7c de')
# CWbytearray(b'38 7c 64 d7 8f d8 54 2d a9 3d b7 e0 cd df b4 96')
# CWbytearray(b'4f 00 be 09 42 ac 19 1b 18 b5 36 7a e4 93 8d 01')
# CWbytearray(b'5c 86 a1 a9 a4 d2 35 f2 1e 49 03 8f 34 db aa 51')
# CWbytearray(b'b5 cd fa d1 a9 81 80 6f 96 e7 7f fa 20 b7 94 24')
# CWbytearray(b'56 7f 22 f7 dd 0e c6 3b 13 7a bf c0 b1 f3 1d 88')
# CWbytearray(b'53 54 40 25 f8 00 eb 25 ff ab 3a 2b 76 33 cd 74')
# CWbytearray(b'9a 37 bf 49 91 98 b6 94 8d 26 b6 cc 8d 19 92 4c')
# CWbytearray(b'67 07 23 92 17 34 30 05 81 5c 5a f3 16 8e 19 eb')
# CWbytearray(b'9c ad 99 f3 7b f5 f2 2c 6e ec c5 c7 5f 62 0f c5')
# CWbytearray(b'fd 6a 57 47 64 93 2f 86 dd d2 6b 35 87 bd 74 2a')
# CWbytearray(b'24 a6 13 8a 38 50 cf d7 38 7c 12 a5 cb 60 0e 14')
# CWbytearray(b'8d 36 7c b0 78 29 d0 45 d0 e6 be f4 fd b4 63 ec')
# CWbytearray(b'ac f2 85 e9 f6 9f 2b 56 5b 0c 31 66 b4 c4 b7 0c')
# CWbytearray(b'8c 36 fb 87 99 29 5c 4a 62 ab 4b f6 1b 43 6e 53')
# CWbytearray(b'c3 b8 35 89 d4 2a ed 5d 17 aa 94 4f ac dd 80 27')
# CWbytearray(b'60 e9 4b 12 24 76 1e b2 49 dd 32 35 2a f4 52 ab')
# CWbytearray(b'ee 0b 74 a7 cd fc 9b dd 10 91 6c e1 df 8e 84 ef')
# CWbytearray(b'7e 84 ba b7 f1 0e ec bb b9 8f 28 70 db 5d f7 c8')
# CWbytearray(b'd6 d2 75 8b db cc b3 5f 90 28 de 67 9d 3e e7 fa')
# CWbytearray(b'9b c4 ee 70 15 aa 89 4c de b8 d1 4d c0 0c bd 46')
# CWbytearray(b'40 11 40 80 bd 5c 2b 94 d6 99 2f 26 3d eb dc ed')
# CWbytearray(b'5b 7b 0a 2f b0 35 2a 0f 84 53 5f 5d e0 3f f5 7e')
# CWbytearray(b'58 23 6b b8 22 d5 47 d9 97 7e 59 8e 82 6b 0f 19')
# CWbytearray(b'10 08 2b 96 50 95 ba ce 22 5e 17 56 00 95 0e ea')
# CWbytearray(b'40 f3 45 34 7b b6 63 7d 76 78 aa fb 29 84 97 56')
# CWbytearray(b'8c df 2d 7f 88 1e 08 02 d2 65 ca f3 98 97 22 d6')
# CWbytearray(b'd5 28 88 57 b8 77 bf 7d 06 22 34 ca 2a 5c b7 a7')
# CWbytearray(b'92 6e 40 dc 70 bc 6c a9 79 25 45 32 be 79 34 61')
# CWbytearray(b'59 62 0f ec a5 0d be 6b 0a 40 81 7a 26 a2 76 d5')
# CWbytearray(b'81 7f 7c 46 72 68 1a da 28 56 a4 30 2b fe 06 e5')
# CWbytearray(b'63 05 da 39 ee b1 84 8c 3a 1e 41 ab ea 50 05 4c')
# CWbytearray(b'43 e4 f1 01 6d d0 1a 4a a8 44 c4 a3 00 56 a8 63')
# CWbytearray(b'2d a9 6d 98 9c 0a 91 f3 e5 7a 04 9b 3c 24 e3 a9')
# CWbytearray(b'5a bf 2d 1e ee 21 cb 8a 56 2d 17 b1 55 5b b7 74')
# CWbytearray(b'95 3d 57 b6 24 b8 2d 04 62 07 eb 07 f7 b5 1e 17')
# CWbytearray(b'3f b5 65 0e 7b 75 f4 00 35 21 f6 a2 64 91 ac c9')
# CWbytearray(b'df df 9f 86 d3 73 0d de 5a a3 3e 20 4c bb 1d d1')
# CWbytearray(b'2c 64 99 ce e6 b0 2a 0f bf 6a b0 ae 4e 88 34 e2')
# CWbytearray(b'b6 f6 43 ba ee f5 74 d8 36 4d b0 86 88 af 02 87')
# CWbytearray(b'd8 31 41 67 62 97 8b b2 05 82 b3 2a 62 c5 30 8a')
# CWbytearray(b'f8 bc a3 fe d6 4b d8 53 64 41 37 89 c9 5a eb f2')
# CWbytearray(b'09 8c 50 03 59 54 9a 3b c2 f2 fc 4d 3d 04 22 19')
# CWbytearray(b'd0 9e 5e 6a 12 03 05 85 b3 01 24 09 8a 61 dd 91')
# CWbytearray(b'd6 cf 73 00 09 29 95 ad ef 4e fc e1 46 51 64 20')
# CWbytearray(b'9a 28 58 2f 42 a2 e3 d6 00 bf 22 98 61 6a df 07')
# CWbytearray(b'b5 70 a5 da d0 75 cc 83 9b 73 f6 fa 1e 04 96 ab')
# CWbytearray(b'b3 77 5a 65 aa 31 34 a2 13 47 99 8a 02 db 01 a3')
# CWbytearray(b'71 a5 d7 fb a9 50 fd d5 94 16 92 49 77 03 b4 d4')
# CWbytearray(b'c3 3a ec e9 4f d1 e7 5a b0 da 04 02 95 40 54 c7')
# CWbytearray(b'11 a1 7f 19 70 75 64 27 80 49 b2 1e ce 2c 6c 21')
# CWbytearray(b'2b ea 84 cf 10 2e d8 e4 ac f6 c7 7f 28 88 c4 01')
# CWbytearray(b'27 09 32 81 61 fb 18 62 ba bb dd e3 92 50 5f ff')
# CWbytearray(b'dc c5 04 b0 98 a7 aa df 67 be 80 06 91 02 4c bb')
# CWbytearray(b'58 4c e8 0e d3 5b 37 a0 98 32 3f bc 48 7a cb 06')
# CWbytearray(b'9a 57 3b 9f f8 bf 8e 3c e1 7d 9a af db b5 3c 36')
# CWbytearray(b'e3 8d 32 5b 43 7d 67 06 2e 0d cf 89 b3 95 30 82')
# CWbytearray(b'b7 ce eb 38 5c 54 98 03 64 65 a5 1b bc 29 fd 79')
# CWbytearray(b'88 20 38 ac 57 6c 2e 8e a4 74 7e 5c 43 2a 86 48')
# CWbytearray(b'3c 75 01 59 33 db 66 6f db c3 ef 1b ad b3 e9 e4')
# CWbytearray(b'9a 89 35 14 4e 21 72 ee 3c 73 4c 44 33 77 bb a5')
# CWbytearray(b'a2 ac 36 a1 44 07 40 fc b3 c7 c3 64 b2 9b 6c 9e')
# CWbytearray(b'84 ef 15 d2 1c 1b 5f 23 0d c6 95 94 8f 36 e5 80')
# CWbytearray(b'54 ac 2c 7e aa 1b d2 c8 e8 f3 0c 7e 7c d4 9b 60')
# CWbytearray(b'f7 f5 55 6e 61 23 35 b3 97 aa b0 2a f6 db 25 16')
# CWbytearray(b'f7 af 32 43 15 5f 01 20 22 a2 11 c8 1d ee 9d 72')
# CWbytearray(b'96 d2 9c 0b 9d bd 35 f2 1f 9c 1a f7 a1 52 92 67')
# CWbytearray(b'66 55 8c 67 94 79 82 15 98 33 5e c9 4c 74 2a 87')
# CWbytearray(b'16 07 55 22 89 3d 49 e9 b7 22 a3 d2 03 40 5a 40')
# CWbytearray(b'81 81 87 a4 58 d6 35 ba c7 ef 70 7f dd b1 79 9e')
# CWbytearray(b'35 91 34 c8 73 9e ae 78 76 ed 64 7d 12 41 55 55')
# CWbytearray(b'04 7c 21 f3 c7 6e a6 17 b0 74 b7 67 4f 28 7c 0b')
# CWbytearray(b'1a 27 8b 94 6f 0c d4 d3 fd ac 21 32 35 71 50 79')
# CWbytearray(b'b5 5f 82 90 6e 32 bd 63 f3 6e 25 4d 2f 69 38 66')
# CWbytearray(b'98 a7 d2 ce 85 61 1f 1a 94 31 03 4a aa 08 3a d7')
# CWbytearray(b'df 68 70 55 9e 90 7c fa 0c e9 25 f8 0b 49 c7 89')
# CWbytearray(b'df 68 7b a3 fc 3c 77 87 96 d0 34 03 26 69 b2 57')
# CWbytearray(b'65 4c e1 68 8b a4 8d 3b 6c 13 bb 56 53 a3 89 12')
# CWbytearray(b'ec 7a b1 40 ca 2d 87 d5 58 52 8b d3 f6 37 1b 1e')
# CWbytearray(b'b3 a4 ac 5a 33 cf 42 95 bd b8 ca 62 db b2 bf 41')
# CWbytearray(b'1e a7 3a 3c 9e 79 88 05 50 62 cc 5f fa ad 48 6d')
# CWbytearray(b'67 ca a5 44 4e b9 dc fd 1f 66 f1 9e 73 d2 c6 17')
# CWbytearray(b'fd 43 5e 47 94 84 47 10 ff cd 4e f6 fa 98 15 ae')
# CWbytearray(b'7d 1d 5b 63 8f 16 cd b4 f5 a3 e4 3f b5 8f 03 d6')
# CWbytearray(b'9c 2d 08 ea 90 17 6a fe 24 6a 34 3d d1 a7 5c 36')
# CWbytearray(b'9f 32 b8 d6 f9 b7 d9 82 4a bc 37 4b ef f8 00 dc')
# CWbytearray(b'e4 78 d1 3d dd a9 60 e1 20 f8 79 8c c1 5b 2c 3f')
# CWbytearray(b'ba 38 f0 d1 08 3e 6e 28 27 ac 5d 88 07 24 bd e7')
# CWbytearray(b'86 98 a5 e4 60 2f 78 02 27 74 f7 9c d7 c9 f8 1b')
# CWbytearray(b'c2 f5 0c 85 e2 a0 a0 af 88 39 bd 9a 40 25 dd ed')
# CWbytearray(b'25 fa 2c 05 45 11 06 6b ae 3b c5 e8 e6 c2 62 bb')
# CWbytearray(b'2b 93 75 63 85 8b 38 8e dc b3 36 dc 7e d5 86 7d')
# CWbytearray(b'c4 83 7a 7c e5 9c 33 f0 5d bc e8 48 c0 51 f0 c9')
# CWbytearray(b'81 df 93 0e 48 de a0 41 3b 4a c7 ad 60 98 2b 6e')
# CWbytearray(b'62 fb f3 0b 4b 9e 16 13 90 4f 7a 44 5a ad 1d 33')
# CWbytearray(b'b6 d7 41 ac 6f cf e6 f3 35 4d 94 d5 e5 2d 9d 07')
# CWbytearray(b'ac 4a 89 cf 6f 5a 83 88 72 48 d2 0c c4 b6 b9 27')
# CWbytearray(b'7f ba da de fe 2f fe c1 2a 6d 18 ed 0d 54 3f 1e')
# CWbytearray(b'6d ee 3b e7 8c 0d fd d3 ec 57 7d f3 dc 99 a5 83')
# CWbytearray(b'43 7a 5e 92 d6 ba cc cb b3 97 b0 c7 27 35 bc 1a')
# CWbytearray(b'49 06 c6 bf d6 25 77 c3 10 8a f8 be ba da 85 51')
# CWbytearray(b'8f 20 20 42 33 6c ac 00 52 21 fe b7 f3 42 7c af')
# CWbytearray(b'd4 01 68 c7 44 b3 cb 89 61 e0 eb 91 24 5f f4 fb')
# CWbytearray(b'94 d5 5e 4b 9f 18 91 e3 86 10 f5 3e cb 5b 25 9f')
# CWbytearray(b'd5 33 bf 1d 63 de a0 c3 4c 6b 98 f4 76 c5 3e a5')
# CWbytearray(b'99 90 76 5b 42 e7 69 72 2a 95 4b cd fe f9 f7 5f')
# CWbytearray(b'be 1d 8d df e6 ca ab fa f8 37 fc 3d c5 37 80 e4')
# CWbytearray(b'8f 64 03 d9 bd 3f 11 fc fc c4 d3 0c aa 5c 07 9a')
# CWbytearray(b'f5 7a b7 e6 12 5d 44 72 0d 69 02 88 4b 87 d1 f8')
# CWbytearray(b'e2 f4 c3 6f 3c 96 4c b0 3b f9 92 f2 86 5b 21 67')
# CWbytearray(b'5a 8b f5 6d 36 b7 9d c7 76 ce 48 89 da 53 8b a9')
# CWbytearray(b'd2 4a bc f4 76 7b 37 3f a2 9c 22 89 bf 2a 2f 96')
# CWbytearray(b'35 98 9c 49 aa 1c cc a7 d6 9e 78 36 d9 31 99 bc')
# CWbytearray(b'4c 93 07 e8 73 c6 56 3f ec 9a 75 3f a3 63 5d b8')
# CWbytearray(b'58 c9 1a f5 6e 13 a4 ad dd a9 51 a0 22 bb ce 3a')
# CWbytearray(b'b6 17 29 7c 5a 69 32 c2 d7 6c b6 1b 0a b4 54 0a')
# CWbytearray(b'a5 08 37 b7 56 62 3b a5 0e 38 2d 73 65 45 f0 f2')
# CWbytearray(b'cc 60 fb 62 10 af 8f 9d c5 59 7b c7 37 62 17 8e')
# CWbytearray(b'eb 90 34 15 78 6f f5 e3 b9 4d 02 ce 09 d7 4c 72')
# CWbytearray(b'fa 80 65 69 9d 4e 79 78 7b cd 7e 6b a7 72 1d 4e')
# CWbytearray(b'35 67 f8 8e 7e de 13 b4 4d 7d 16 b4 5a 01 7c 39')
# CWbytearray(b'c3 dd 16 ec 54 05 40 c8 8d d5 42 3c 2b 6d d5 be')
# CWbytearray(b'bd 0f 00 8e 8a a6 97 02 df cd 72 4b 70 4e 63 d5')
# CWbytearray(b'cf fb ce e2 2d ae e3 56 77 d1 ba b6 bb 29 3c 83')
# CWbytearray(b'02 89 1a d6 c8 27 06 24 29 48 b8 ea a9 6a 4f 2b')
# CWbytearray(b'6d ab 85 ab 6d 3f f1 c5 83 b4 ac 77 55 58 c0 96')
# CWbytearray(b'39 09 47 be 01 2d 2d a8 6e 42 f1 7e dc 42 4b 4d')
# CWbytearray(b'29 7e 99 d9 bb 14 81 18 4c f1 e3 bc 86 90 3d 55')
# CWbytearray(b'b5 f4 9e d7 6a 53 f2 4c 2c 0e 46 44 20 91 3e 63')
# CWbytearray(b'f0 1f 0c e2 d0 fe f7 88 06 12 8f ef 26 b2 1b dc')
# CWbytearray(b'1a b9 87 e6 bd 51 42 46 94 a7 6f e2 80 da 45 41')
# CWbytearray(b'ef 5e 80 57 ad 08 1c 4e 67 3e e5 3e ab a1 b4 7f')
# CWbytearray(b'83 cf f3 2b 47 91 ce 77 b4 c2 cc 0e 82 27 c9 33')
# CWbytearray(b'a2 59 2c 16 a1 c7 9d 29 8a 53 97 24 d9 13 92 9a')
# CWbytearray(b'61 0f fc 68 30 a3 e5 b0 1f df bd 18 2e 12 66 a4')
# CWbytearray(b'e7 f9 66 44 8b 5b 5b 6c ae 94 38 f1 2d 90 81 3a')
# CWbytearray(b'c1 4a fa 41 07 80 d9 85 4e 96 4f 25 da a2 a0 a7')
# CWbytearray(b'ab 29 98 58 43 64 41 69 90 30 ed 3d 4e 49 bb 4b')
# CWbytearray(b'ea 89 ed 0b ef 4c 1c 9d db 90 bd c2 73 dd 26 e1')
# CWbytearray(b'c5 95 8a 56 b0 4a 5f 12 e8 05 97 f7 93 a3 98 b7')
# CWbytearray(b'fb 60 08 8b 0e b0 66 e4 36 fc 75 f1 72 9a 4b fc')
# CWbytearray(b'7c ec cc e7 4e 0d df 8a e0 70 62 af 96 8c bf d8')
# CWbytearray(b'c7 fe 8a 65 c4 42 f3 c3 c3 36 67 32 e3 bc 1d 45')
# CWbytearray(b'36 95 8e dc 3b 91 7b 89 eb 4f b0 38 0b a7 2c bd')
# CWbytearray(b'04 69 30 74 09 01 d1 d5 5d 31 d4 03 04 8d 1c 55')
# CWbytearray(b'ed e3 3e 5e 3d a7 28 8c 14 33 f9 00 65 f7 1a 21')
# CWbytearray(b'a6 53 d6 63 00 c4 fa b9 31 60 ab 7e 39 e6 85 cd')
# CWbytearray(b'eb 9c 30 f7 60 56 bd ef bb 27 79 8a 4d 53 56 db')
# CWbytearray(b'a4 49 46 59 c2 6c 1e a2 58 5e 87 10 2f 0b af 59')
# CWbytearray(b'b4 05 9a 92 d2 7f ff 22 c5 85 56 7c 56 ee b9 62')
# CWbytearray(b'0b 29 17 fc 17 d6 46 70 c6 cc 9c db de 66 b2 69')
# CWbytearray(b'f6 ee 7b 6d fc ce b9 99 47 45 b2 e3 d1 c9 05 d9')
# CWbytearray(b'f3 b9 66 42 d9 8a ca 69 b5 9c b9 7d 78 f0 39 62')
# CWbytearray(b'83 1e ee 94 f2 5c 26 67 96 9b 0a 78 36 37 f1 a7')
# CWbytearray(b'40 ce ae 7b 44 8d 6b d8 c8 4e cc 39 a7 6a 52 5a')
# CWbytearray(b'b0 24 a5 f7 e9 b1 61 7f 64 97 8c 0f 76 e4 f8 14')
# CWbytearray(b'02 0f f5 dd 1d 8a a6 9a f1 78 5a 1d 70 56 40 86')
# CWbytearray(b'19 26 71 39 68 5b 4d 64 f5 c5 e3 cc 3b ec ff 0e')
# CWbytearray(b'95 a1 f8 19 dc 22 0b 48 1f 71 64 cf c5 a5 aa aa')
# CWbytearray(b'19 1b 03 f3 f8 de e6 5a f6 25 fd 1f e9 8d f4 13')
# CWbytearray(b'58 f1 5a 68 6b 8c c1 9c a7 86 15 41 ff 2b 7c 12')
# CWbytearray(b'8a 88 c6 00 de 73 c1 92 41 2f 24 59 3f 6f e6 eb')
# CWbytearray(b'b7 b2 28 ef 58 4e 5d b8 56 9e 59 11 aa a5 fc 31')
# CWbytearray(b'43 11 a9 0b 32 50 82 bb 14 0e 57 84 a2 5a d4 fe')
# CWbytearray(b'5c dc 7b 91 c3 4f 05 23 82 b0 10 0a 4a d0 52 3f')
# CWbytearray(b'2c 49 5c 23 ee 7d da 14 a2 3d 60 7b 92 61 e5 bb')
# CWbytearray(b'46 e2 db 12 55 f1 7b 6b 4b 93 65 da ce 64 58 85')
# CWbytearray(b'2f 46 e1 db 56 2d 7f 01 0a 24 4c fa 03 51 e2 32')
# CWbytearray(b'0f f3 50 76 55 39 d6 f2 7b c9 d7 de f5 dc ea 4a')
# CWbytearray(b'84 96 66 6c f1 30 6b 77 3f e6 4e c8 53 33 fc 93')
# CWbytearray(b'f0 eb d6 70 3e ae 41 90 60 1e f4 2c 31 49 5d 9d')
# CWbytearray(b'74 9c 76 7e 4d b5 fd 2f 18 19 b9 51 65 41 0d 64')
# CWbytearray(b'b8 3c 06 c5 9f 2e 8a a8 ce d7 a9 50 02 b9 a7 e6')
# CWbytearray(b'f2 93 4f bb 72 f5 e5 4c 79 51 37 dc f7 0f 73 32')
# CWbytearray(b'12 d0 3d fc 56 c6 4a 4a 23 ac dc 03 54 e8 c7 b4')
# CWbytearray(b'fd bb c2 85 c7 d8 c5 05 4b 7b 71 52 c1 f8 6a 99')
# CWbytearray(b'cb 14 e4 67 21 d4 60 da d8 9a 0c 09 e0 8f e8 a6')
# CWbytearray(b'52 be f6 3b 93 73 07 d0 30 87 eb 4d 8e 6a 5c 6e')
# CWbytearray(b'46 b2 be c5 23 a3 70 81 c4 33 62 1b 73 a4 d1 db')
# CWbytearray(b'f6 b2 60 48 eb d1 9e e4 e6 47 58 41 a6 3a bf b4')
# CWbytearray(b'13 2f 12 00 ec ff 1c ed d3 49 c4 01 09 42 5a 16')
# CWbytearray(b'11 ef 87 ac 6d e9 b3 97 fa 37 69 10 f8 2a 30 6d')
# CWbytearray(b'23 7b 45 de 95 38 1a bb ff 7c ac 6b 9a 9f 9d 1c')
# CWbytearray(b'a1 6a 1f f6 07 0c e1 10 50 e6 60 84 57 48 ad 40')
# CWbytearray(b'e9 2b b6 d3 4f 43 59 b7 54 fe 89 00 ac 85 d0 65')
# CWbytearray(b'e3 2e b7 da 15 85 23 95 df 56 33 29 2f e3 2f da')
# CWbytearray(b'b4 09 23 14 8b bb 85 d4 90 92 84 b9 ef ec ab 3f')
# CWbytearray(b'c7 fe 2e 7c 3f 7a a7 38 08 8d 53 18 f4 90 9d 32')
# CWbytearray(b'69 db 66 c4 52 41 a3 fb f0 22 a6 ca 48 2a 48 7a')
# CWbytearray(b'20 8f 30 72 03 83 07 52 52 43 da 9d e3 f9 f6 ba')
# CWbytearray(b'88 72 67 d5 85 5f c5 7c 9f bc dc 0d 64 71 1d b5')
# CWbytearray(b'50 b4 23 62 1e 36 9e 9c a2 c5 44 aa 3a cd 53 b6')
# CWbytearray(b'4a 67 0d 8f ab bc e4 ad 8b 90 58 1f 6d 00 27 f7')
# CWbytearray(b'dd 6e 41 fb 42 c4 f2 7e 51 fd c1 1c e6 40 2f ac')
# CWbytearray(b'4e 6e b0 9f 97 3c e8 ad d0 94 8b ae 47 c8 34 5c')
# CWbytearray(b'28 be d9 de bf 0f e6 36 13 75 8d 39 90 63 43 a5')
# CWbytearray(b'0f fb 98 d2 de da 59 74 9e aa 81 e3 c5 6d 0d b7')
# CWbytearray(b'a3 2f 02 05 83 99 83 c5 31 9f a7 8c f3 7e 6f 86')
# CWbytearray(b'8c ad 42 e7 11 51 cf a0 d4 0b fb 52 f1 13 bc e2')
# CWbytearray(b'4c a7 84 25 09 a9 89 a9 28 15 05 8b 29 8a 4d 24')
# CWbytearray(b'99 79 5a dd 64 7e 4b d6 68 38 5b ac 8f ae 49 12')
# CWbytearray(b'cc fc 60 d8 88 cc ee ee 82 1d bd 8e d9 d1 b2 fd')
# CWbytearray(b'37 35 fa bf b2 1e c9 47 42 b9 37 77 1e 9c 11 cc')
# CWbytearray(b'd7 cc 8f 63 a0 5e 11 06 d7 d4 8e 89 eb d4 17 e6')
# CWbytearray(b'53 8a 1c 59 0a 2a 0e 6f ee 90 54 f6 95 83 5a f0')
# CWbytearray(b'0a 7b 8a 22 7c 89 e0 7b de d7 58 85 95 42 4d 61')
# CWbytearray(b'ed 2e d0 ef 6d bb bc 94 13 04 80 b3 cc f9 f9 39')
# CWbytearray(b'46 26 40 0a 4e 20 7a 46 a6 e7 83 79 1e 05 12 60')
# CWbytearray(b'99 50 6e d6 5c 7e 48 ef f1 a1 c4 4d a5 d3 2f 00')
# CWbytearray(b'a4 f7 36 e5 90 3a 56 7f c6 f4 cf b5 81 3f 4c 8f')
# CWbytearray(b'c4 e3 d3 a4 a4 4b 49 d2 a1 32 13 9a d6 ad 29 d8')
# CWbytearray(b'69 d2 13 6b 8c fe 45 38 6b 9b a6 b3 45 0d df c9')
# CWbytearray(b'12 9a c1 bf da df 39 d6 c5 32 ab 92 9c 34 02 9e')
# CWbytearray(b'8f 7d e2 aa c0 70 73 cd 36 ec d3 b2 ff 70 bc 50')
# CWbytearray(b'b7 98 91 ab 51 5e a4 eb cf 94 9f fc a6 7c bd c3')
# CWbytearray(b'78 b9 63 7e 7d 42 56 6b 4c d8 dd e2 99 9e a1 17')
# CWbytearray(b'f0 46 15 59 30 84 46 d5 9d 72 5e d9 1e 79 1d 45')
# CWbytearray(b'87 71 65 36 9b 14 8c 49 56 43 5d 2e 83 96 e3 8a')
# CWbytearray(b'de 3f 0c b6 97 38 dd 74 8f b0 53 41 0a 01 28 8c')
# CWbytearray(b'03 88 02 4a c6 08 22 82 e8 94 37 5b 25 85 cb 4c')
# CWbytearray(b'ec 42 95 30 94 89 3c de 26 52 36 48 3a f6 3f a1')
# CWbytearray(b'9f 5d a2 ef be ac 26 63 29 ba e8 06 6d 28 db 4c')
# CWbytearray(b'42 dd 76 d2 ed c5 1f 52 18 ab 60 df 61 59 5b 6c')
# CWbytearray(b'cb 34 0f f7 69 7f 8f b7 4e 9d 54 1e 05 42 9f cc')
# CWbytearray(b'7f 46 f1 59 22 38 7d cb ee d9 84 76 d5 5f 64 f7')
# CWbytearray(b'71 b4 97 7b 73 99 85 12 f1 22 fa 6e 8d 8f 4b e6')
# CWbytearray(b'69 76 c0 fb 84 60 1c d2 0c 68 39 f7 17 3d 72 75')
# CWbytearray(b'4a f6 61 14 a6 1e dd 0b 87 25 f3 9d a9 3e 11 6c')
# CWbytearray(b'21 6c 2e 5f 98 da c4 97 3b 46 bc 94 b4 6d da 91')
# CWbytearray(b'38 8a 1e e4 04 06 84 78 88 2d 88 41 08 c0 17 f3')
# CWbytearray(b'58 2c f4 2d ec bd 0c ff 0a 2c c6 87 f0 0e d0 7d')
# CWbytearray(b'17 aa 9e d5 8f e0 a6 ba da 14 a6 78 33 b6 fb b1')
# CWbytearray(b'05 be 69 19 82 e7 0c 7b e5 d3 5f dd 82 48 a4 10')
# CWbytearray(b'5b bd b6 13 16 96 04 29 5a 75 ef 0f 8f 9c c7 3a')
# CWbytearray(b'42 68 ef 0a 62 5f 58 71 a4 7a ab 4f 75 c1 32 78')
# CWbytearray(b'29 c2 f7 24 0c 32 b7 c2 1b 8d f4 30 76 40 59 ad')
# CWbytearray(b'fb 3c 18 5e 33 f8 20 d3 b5 d4 85 8e 7d c5 38 24')
# CWbytearray(b'2d 49 53 25 74 f5 65 91 ce 1f f2 fe be 6d 91 f3')
# CWbytearray(b'c9 3f 8a b7 61 68 6e a0 dd ac 14 09 1b 65 4c 10')
# CWbytearray(b'ef a9 66 0f 6f 9c 1a 77 7e ef f3 91 c1 d9 3a 85')
# CWbytearray(b'af 99 b4 c8 36 e3 ee 85 ee c4 eb 56 59 60 68 67')
# CWbytearray(b'04 46 98 2a 4d 3f 15 37 3b 7f 73 30 4c d3 8e ed')
# CWbytearray(b'd5 cf f7 e6 e0 ea 20 f2 90 0c ed ce 79 83 f6 2b')
# CWbytearray(b'84 f0 bf 0c 62 7e c8 32 53 ef f8 00 22 15 e5 14')
# CWbytearray(b'0d 32 05 64 81 9d a0 da 1e 56 9e 57 55 8e 13 ba')
# CWbytearray(b'd7 1b dd da 01 31 03 74 be 35 36 e0 fd d4 76 8a')
# CWbytearray(b'e2 f3 24 12 8f 12 c6 55 02 32 04 5d f1 0c d5 0f')
# CWbytearray(b'9c eb ce 37 ee 52 c0 8f 24 0c 93 63 4a cb 14 bb')
# CWbytearray(b'09 0b a3 32 b0 0e 53 32 f4 c9 f8 02 58 fb 3c fc')
# CWbytearray(b'34 7a 97 cf 68 25 e9 b8 25 67 28 77 12 47 9c a8')
# CWbytearray(b'a8 46 bc 7c 50 17 d7 a5 45 cf 29 1a 03 cd 46 ae')
# CWbytearray(b'a9 42 cd e9 ca c8 b3 ed b0 b8 40 79 51 33 56 0f')
# CWbytearray(b'bc 5f 55 85 bc 02 22 05 13 91 ee 52 36 f3 4c e7')
# CWbytearray(b'e1 35 d5 e6 55 f2 cf f4 e9 a1 9f 6d e8 9a 41 a6')
# CWbytearray(b'7e 10 62 b3 85 38 3a 6d b1 6d 87 1b c9 b0 bd 22')
# CWbytearray(b'17 bc f7 07 51 0c 02 9b aa 29 58 99 b7 bc 96 04')
# CWbytearray(b'29 b6 fb e1 90 7f cc 48 b5 9b 27 b6 5f ee a6 0e')
# CWbytearray(b'84 5a 0a 8a 7d 8a 0a 57 cc 73 d7 ed 15 50 40 8e')
# CWbytearray(b'5c 90 64 e1 6a 22 6f 5c f9 93 af 93 de e8 21 0a')
# CWbytearray(b'c1 9c 6c 90 6c 4f 50 95 80 d5 b5 e2 63 1c 2e 4b')
# CWbytearray(b'cd 11 3c fc 31 9c 9f 76 29 e9 55 c9 4e e1 15 52')
# CWbytearray(b'c0 88 0b 45 38 1a a5 04 50 26 18 b3 87 bd a4 41')
# CWbytearray(b'52 96 df b8 53 1d 43 89 d7 f4 de da 47 72 a5 71')
# CWbytearray(b'07 01 a2 97 b6 b9 80 16 0d 30 de 7b 26 05 2d 2e')
# CWbytearray(b'61 e5 de 0f 45 3f 55 fb 5d 6e 10 47 76 7e d1 a4')
# CWbytearray(b'4a 58 25 c4 d1 97 58 1a 73 3b b4 01 f2 b4 e3 eb')
# CWbytearray(b'd0 ee a4 91 43 15 ad 05 03 5b 63 8f 1c 18 3c 07')
# CWbytearray(b'ca d3 24 8c fd 0c 7a 8f e1 2c a6 c8 47 ec 9f 3b')
# CWbytearray(b'd2 e2 fb db 54 45 60 6d 22 35 1d be f2 84 42 55')
# CWbytearray(b'c2 9c a7 cb ca c4 57 e6 63 2e 1a c4 7b 4a 07 be')
# CWbytearray(b'7e 5c f8 fe 89 51 3e c3 fa f1 4d 00 75 dc be 52')
# CWbytearray(b'79 f9 7b 84 cd 60 7b af 40 19 08 8b dc d8 a6 40')
# CWbytearray(b'60 81 76 96 ea ef 65 31 49 4c f4 85 c8 eb d0 81')
# CWbytearray(b'3c 55 69 2b 5b 79 8f 6c 85 4e d4 14 da 2f 69 2e')
# CWbytearray(b'dd f1 1c 85 86 d8 4c ec 01 07 3c 61 5c 4a 51 b1')
# CWbytearray(b'75 48 76 f2 a3 95 96 7b 3d 19 bb 02 8d 7e ae 57')
# CWbytearray(b'0e c7 28 53 15 47 82 24 21 10 3e b5 17 fb 88 80')
# CWbytearray(b'46 bb 58 f5 cc 57 96 91 b4 d0 77 e1 f6 62 49 1d')
# CWbytearray(b'5f 9e 54 3f bd 25 ea 9a e0 4c 38 7d 76 e8 61 d0')
# CWbytearray(b'cd 26 e7 b6 e5 b4 88 f7 85 f1 5f 96 ed e4 66 d0')
# CWbytearray(b'86 8b 96 4f 9a a8 72 1e c1 f5 d4 fb 03 14 06 35')
# CWbytearray(b'2d 08 5b 0a 92 69 c3 bf 7f 9c a6 22 93 b5 f5 85')
# CWbytearray(b'cd f6 b1 8f 19 38 69 e2 b5 bf 96 22 11 97 c8 89')
# CWbytearray(b'37 94 3c d9 ca b1 78 db 78 ed a9 b3 9d e3 f1 3e')
# CWbytearray(b'e9 a6 71 91 bd 2c b6 f0 11 f4 5f 1b 23 8a 01 54')
# CWbytearray(b'f2 cb a9 87 bd f0 5b 91 1d b0 bd 05 c6 8d 88 e6')
# CWbytearray(b'09 a6 ff 72 e2 d0 e0 5e d9 b4 27 21 57 f9 98 9b')
# CWbytearray(b'91 1b e9 8d 57 f2 7b 2d f9 1e 67 43 fe 16 c9 20')
# CWbytearray(b'36 9f e9 e2 8c 51 04 f4 32 18 34 9f 4c cd 02 e3')
# CWbytearray(b'1b 4d a7 f7 11 5d 61 7e bb 09 8e ea aa 59 b1 1b')
# CWbytearray(b'b0 e7 1b 00 36 12 87 91 54 4b 33 42 ee 81 5d d0')
# CWbytearray(b'10 be 9c a4 37 ef 9c 43 89 35 1a af d4 20 f9 1e')
# CWbytearray(b'53 5f 37 7e 65 19 b3 64 36 89 c5 4e e1 6e cc 51')
# CWbytearray(b'5e ad e2 92 ea 76 ba 85 ca b2 75 5d 88 f5 38 5d')
# CWbytearray(b'95 08 a4 f2 92 8d a6 a6 64 a1 03 f1 10 31 d8 5f')
# CWbytearray(b'08 77 4a 6e 86 d5 8b 28 6f 47 af 49 d9 03 df 10')
# CWbytearray(b'8a 4e 2f d7 57 5d 64 09 e8 7b 2d c8 f8 b1 dc 5f')
# CWbytearray(b'71 33 c5 e7 e7 22 ec 48 eb 03 c2 36 8a b8 b1 15')
# CWbytearray(b'60 70 6d 6f 44 7f c0 46 7a ac 67 11 27 02 7e 3e')
# CWbytearray(b'e4 fd 4c 9d 22 b3 ce f9 95 9a c5 a7 be d9 f1 94')
# CWbytearray(b'7f 99 ec 67 12 f0 8b d1 29 c2 e3 95 a2 b7 4a c5')
# CWbytearray(b'c4 ac 6e eb ec 57 be 00 d6 4d 1e 70 9a 18 5c ce')
# CWbytearray(b'dd fc 2c a1 67 b6 0c 36 a6 8a f9 ac 72 fc 67 4d')
# CWbytearray(b'd2 03 0e 5f 9c 9c 66 f3 6f b5 bb fb 22 a6 b9 38')
# CWbytearray(b'58 5a 05 b1 0f 43 7a e7 67 8f fb e8 9b 55 a3 7b')
# CWbytearray(b'72 2d 11 50 a2 e0 1b c8 98 ad 46 f2 22 69 25 9f')
# CWbytearray(b'22 71 99 b2 08 72 74 5e 7e 76 b3 2e fe 6d 54 4e')
# CWbytearray(b'9d d7 7f 41 bc 4f cd d8 82 44 b0 7c bf 4d 68 dc')
# CWbytearray(b'51 31 1d 04 eb bd 2a 9b f0 9a a9 9f 2e 08 6c 56')
# CWbytearray(b'39 ff 9a 58 78 be 95 40 ba ba 56 be 47 af 67 b7')
# CWbytearray(b'36 86 ac 88 cf 08 1c 56 d1 e7 03 77 e7 12 18 88')
# CWbytearray(b'02 84 e0 d4 e5 f8 58 84 cd d1 75 28 7a 57 4f 65')
# CWbytearray(b'ba 71 5c df 44 2a 9f 01 6c 88 e9 2e 48 f8 55 3e')
# CWbytearray(b'78 b6 ae e9 22 db ee c0 0e 23 da 8e 71 56 fd 62')
# CWbytearray(b'20 58 bc 5b b8 f1 d6 c7 eb c4 9f 67 0f 27 9c 9f')
# CWbytearray(b'3b 09 eb 40 f6 b7 a2 6a c4 48 4a 09 22 af d0 0c')
# CWbytearray(b'8a e1 89 7d 80 d0 a1 d9 d2 7c 56 a5 ff 3b d0 f0')
# CWbytearray(b'42 be 0c 7e 34 36 91 1f 68 e4 4b 2f 06 fd d2 d5')
# CWbytearray(b'1c 21 74 08 95 04 2c 43 8d 01 d5 dd 13 78 07 91')
# CWbytearray(b'25 e3 62 3d 3a 2d f5 22 15 98 eb 1b 12 f6 cb 13')
# CWbytearray(b'38 6a aa ac 72 52 3e d7 90 71 85 bd 74 0d d5 fe')
# CWbytearray(b'3d b4 3f 86 1a 75 72 d5 8c 41 27 ae 28 3e d7 39')
# CWbytearray(b'45 58 0f 7f 7e 4f 0e 06 de 70 b4 a0 2a 47 89 60')
# CWbytearray(b'b4 1c f0 e7 f1 51 ec 27 89 eb 2e a1 6b 36 df 7e')
# CWbytearray(b'53 df bc 7e 22 26 15 04 c7 75 f9 d6 d9 c0 a0 b3')
# CWbytearray(b'f1 63 33 87 cc 24 49 e4 a0 4b 79 62 cf 6d 56 df')
# CWbytearray(b'5b 64 31 42 a6 43 5c 4e 6d 52 8f 82 cf e5 b9 4f')
# CWbytearray(b'fb e4 8c 82 5d cf 17 11 df 15 40 5b 5c 19 c8 4f')
# CWbytearray(b'76 7b 03 04 5c 23 02 88 70 35 3f f0 dc a6 16 16')
# CWbytearray(b'00 5c 29 f2 89 e5 ea 18 51 8a 8c 2f 86 0e 15 a9')
# CWbytearray(b'a9 1c 9b 5e a3 79 de b0 16 2e 2c 28 2d f4 b8 34')
# CWbytearray(b'43 b0 fa fc bb 97 49 fa d5 0a aa 38 3d d9 7b 8a')
# CWbytearray(b'99 e0 0c 4b de ac 06 ed eb f0 5f 4e a5 7a 03 91')
# CWbytearray(b'42 bb 7d b1 ce 89 fe 1b 12 bf 97 94 a8 eb 5a 0b')
# CWbytearray(b'd3 66 07 09 12 0a 17 29 b4 15 1f db f3 58 17 0b')
# CWbytearray(b'21 f1 3c 62 59 cc 74 78 1f 89 17 a7 b0 5f 0d 3f')
# CWbytearray(b'5a 7f 91 99 a0 0e bd 3f 85 8f d1 6a f6 bd be 8f')
# CWbytearray(b'72 f1 e2 8e ee a4 ed cd 3d fa 51 a5 5d c1 1b 4f')
# CWbytearray(b'87 8d 1e 78 ac 4d 10 1d ef cc b1 b8 9f b4 0b 0a')
# CWbytearray(b'd5 b4 b1 2e 84 37 ba 1c 18 4a 9d 6d 89 bc ec 66')
# CWbytearray(b'96 da 3d 5c 04 fd 06 02 a0 7e 18 b8 74 4f bf 16')
# CWbytearray(b'61 45 28 56 25 e4 d0 8c da 61 b2 76 37 d6 b6 35')
# CWbytearray(b'6a 82 ec 35 b2 38 ea 39 d1 7c 71 0a fc ad cf ca')
# CWbytearray(b'd1 72 aa 4d 23 10 48 25 6a a4 da 8b db ed 65 41')
# CWbytearray(b'b7 e4 f0 e0 45 5f d2 5a 7a 32 96 ff da b5 9e a2')
# CWbytearray(b'fb 08 08 a9 06 da 32 62 25 9e c2 10 0d 21 6b db')
# CWbytearray(b'a4 2d 22 90 bf f3 65 aa 5c 31 72 5c b7 84 6d f6')
# CWbytearray(b'57 05 3e 4e 74 dd 97 f6 f4 e3 31 0b be 80 0e 2a')
# CWbytearray(b'1c 55 78 08 45 33 f9 8c 4a f4 50 b7 3d fe 20 fa')
# CWbytearray(b'52 98 d3 f5 a9 4b b0 59 dc fd f8 89 7e 7a eb 5d')
# CWbytearray(b'c0 e1 1c d5 f6 93 a5 ff c6 88 88 fa 4c f0 c0 53')
# CWbytearray(b'88 2d ee 6c 24 41 02 d0 98 e5 35 de db 1b 6d 5a')
# CWbytearray(b'24 cf 28 e4 b5 4a 76 f6 9c 37 d2 06 bf f1 a3 90')
# CWbytearray(b'7b 8d 19 e3 36 a6 15 35 3f 68 3c 13 6e db 96 c2')
# CWbytearray(b'a1 c3 6e 38 d3 63 6e 27 79 9c de 6f e4 61 17 7b')
# CWbytearray(b'ff 9d 14 34 01 f7 45 de e0 61 e0 62 1c 9f 1e d7')
# CWbytearray(b'ec f2 ee 6f 7b d8 9d 23 0f 88 dc 44 29 c2 d6 43')
# CWbytearray(b'c8 ce e7 c8 1d 1e b0 6b 83 e6 63 2a 29 f5 e5 97')
# CWbytearray(b'2b 56 54 c3 6d 6f d0 7c da 15 00 d6 27 62 1f c4')
# CWbytearray(b'09 ca 74 8e cf 66 f1 4c 0c e3 8f f1 b5 6a d7 98')
# CWbytearray(b'9f a3 65 7d 98 f8 95 54 eb d2 73 86 ae 8c 1e ce')
# CWbytearray(b'e6 65 26 5e e7 02 45 e3 c7 81 db b5 3c 5e b4 90')
# CWbytearray(b'16 20 d5 5e 3c f2 dd c8 01 59 06 bf 3e db b4 62')
# CWbytearray(b'ec 6a 93 84 4d 3b 68 ab 64 89 a8 84 a3 aa a4 10')
# CWbytearray(b'd9 82 42 65 be b4 17 7b e8 8e c9 02 7d 34 1c be')
# CWbytearray(b'7f 24 24 8d 85 f6 c1 50 dd b6 ae cf b2 56 21 95')
# CWbytearray(b'e1 94 0a 33 34 7f 52 ab 43 38 95 b5 1a d6 7f d0')
# CWbytearray(b'9f fb 4f fe 0c 92 5d 10 66 99 65 06 ab 6f a1 80')
# CWbytearray(b'5c e1 c8 b9 38 eb 7a 1a 37 00 9e e7 68 c5 38 54')
# CWbytearray(b'a1 6b c7 aa d4 dc 3f bc 08 29 5c e8 c3 dd d6 d4')
# CWbytearray(b'aa 47 fb 97 a3 fb 89 d5 39 3e f7 c1 f3 e0 a2 06')
# CWbytearray(b'c0 f3 0d b2 40 f7 90 d7 d5 6c 59 af 3c 42 b4 9b')
# CWbytearray(b'12 43 4b e0 70 55 3c 18 fa 8a 5a 72 e5 91 f0 a9')
# CWbytearray(b'3b a7 97 30 bb 55 85 9c ae f5 fd e5 08 82 b3 80')
# CWbytearray(b'58 6f 0f bd ac e8 4c 7f 75 eb 62 38 53 3f 02 08')
# CWbytearray(b'f2 e1 fd 35 3c de d1 0b b5 c7 7a 9e 2d 86 2a 9a')
# CWbytearray(b'7a 61 6d 5d 1f 48 e1 15 00 97 ca 68 46 09 40 e5')
# CWbytearray(b'35 d0 96 af da 38 99 8b 4d 0b 67 cc 42 b4 1b 33')
# CWbytearray(b'e6 15 87 26 72 96 14 9a 81 82 54 d4 33 3f ea 1c')
# CWbytearray(b'7b b6 ad db 20 1f b3 bb 4f a7 d3 09 7d 76 a7 9b')
# CWbytearray(b'b6 a1 06 23 ca 96 05 7c 33 6a 2e 4a c7 48 1b 9b')
# CWbytearray(b'86 52 e7 5a f8 fc a5 2a ce 3e fd 16 f2 91 03 bd')
# CWbytearray(b'5d 00 ae 86 61 37 85 f7 1e f4 14 47 ae 48 71 c9')
# CWbytearray(b'08 ed 2d 1d 4b 2a 94 c9 bd 7e 43 7b 94 f4 0e c9')
# CWbytearray(b'87 43 88 84 e8 9d 91 31 74 ff 87 a8 6f 1d d4 1c')
# CWbytearray(b'4e 40 4e ac 3d be bf 2a 1e a0 bd 56 d7 92 55 87')
# CWbytearray(b'1a e3 1f ae 66 16 8e ea f7 ed 92 cf 3b 45 4d b6')
# CWbytearray(b'2d 20 21 9b ca 37 d5 0e f7 53 a6 9d c7 5b e9 02')
# CWbytearray(b'e6 24 2c 8e 3f ec 57 34 d7 74 fc b4 17 b1 0c b8')
# CWbytearray(b'a2 1a 3b 26 f4 ab f9 8e 6e ad d9 15 21 e7 aa 56')
# CWbytearray(b'37 9e c6 a6 ed 60 b3 24 a6 d6 9e a9 fd 7b 4c a1')
# CWbytearray(b'86 10 96 42 46 57 cb b8 d4 34 43 20 72 01 85 34')
# CWbytearray(b'25 d4 6a 18 29 32 c2 b2 38 64 5a 07 d4 71 d2 a6')
# CWbytearray(b'2b 3b b3 e5 d9 5f 1e 30 40 0b 08 ba eb 05 a0 73')
# CWbytearray(b'5c 61 b5 08 75 7a c5 c8 28 16 0b 92 55 10 4a 52')
# CWbytearray(b'01 21 9c 24 3f 47 36 d7 f0 44 15 2a fc 45 70 cd')
# CWbytearray(b'cf 36 99 cb db fa 8b f7 f3 11 3c ac a8 4e c7 4f')
# CWbytearray(b'1c 50 87 48 e9 66 5a e7 f8 f1 61 19 47 3f 52 88')
# CWbytearray(b'0e b1 50 d1 ce 02 db 31 ab 49 ee 6f 3e 7a aa e6')
# CWbytearray(b'18 89 1c 12 72 2d b6 6b bb cd 66 da a5 fa 2f e3')
# CWbytearray(b'f8 98 ba 9b d1 8a b7 92 6f f5 b6 e6 2e 57 fe 18')
# CWbytearray(b'95 cb fb d8 dd fd 12 1a 70 0f 4c cf 17 c5 5d 2b')
# CWbytearray(b'b1 bb e1 d2 5d 53 cf 08 a2 39 5e 68 cb 6f c9 88')
# CWbytearray(b'50 ef ff dd 9e 61 37 d2 cc 0a ad 63 17 ac ae e7')
# CWbytearray(b'6e db ff 2e 5b 9c 86 8b fb 50 7f ff 00 41 a1 7e')
# CWbytearray(b'17 82 72 04 6e 43 39 68 97 7a 74 f8 18 a2 44 45')
# CWbytearray(b'7e 30 c7 b3 eb 89 6a f7 93 80 9d 0b 20 76 52 9a')
# CWbytearray(b'0d cc 67 07 3c 06 11 19 6d c4 f1 b8 d4 20 f3 ec')
# CWbytearray(b'cc 08 ab 77 55 c1 3f 67 3a c5 42 2c ba 19 3d e8')
# CWbytearray(b'e8 6b fa 78 ba 4c cd be 1a 0e 07 d5 d7 2e aa fd')
# CWbytearray(b'ce d4 a9 aa 60 2e 7c 1c 49 7f 60 e7 57 91 db 05')
# CWbytearray(b'd8 0b 4c 32 06 f2 28 9f 35 e4 3d 8f f9 08 a3 83')
# CWbytearray(b'8a f5 31 72 8d c9 c5 45 7a 23 4c 3f 49 da c6 ed')
# CWbytearray(b'35 d7 65 eb ab 52 70 ad 30 dd ed a2 c3 c2 00 13')
# CWbytearray(b'87 d0 4f cd b4 9a ae c9 e4 59 15 39 37 79 29 2c')
# CWbytearray(b'c2 a6 8b e3 76 02 5f ef 35 cd 8e 35 5b 12 44 86')
# CWbytearray(b'1b 33 e1 5f 4c b1 8a 7d f9 79 48 c5 d3 14 fb 48')
# CWbytearray(b'c7 b6 26 c7 00 42 2e 6b 32 6a 66 61 13 5c 38 cf')
# CWbytearray(b'2b 59 8e 56 00 4b 1f b7 db 52 cb 2c c8 a6 e1 05')
# CWbytearray(b'22 08 97 96 c5 81 56 c4 ca 22 76 b1 23 f6 2d 6d')
# CWbytearray(b'b5 65 73 a8 3d f2 f3 c8 5c 3e 7c 6c 92 18 d4 11')
# CWbytearray(b'24 50 da 0f a4 a5 00 34 fe ca 10 c7 3d b2 79 a7')
# CWbytearray(b'e5 5b dd 8f e3 b1 c5 ae d5 59 57 e3 42 2d 9b 34')
# CWbytearray(b'06 f1 51 28 dd 24 18 11 72 7f 07 12 57 50 bf e8')
# CWbytearray(b'55 e3 60 3a 29 ae 41 4e cd 08 9b ef f0 66 d4 94')
# CWbytearray(b'50 ba 0b 7b 26 3b bf fb 5c 21 60 11 24 7c 60 1d')
# CWbytearray(b'25 a6 65 eb d3 7d 00 6b 85 4d b6 d1 d4 be 7c a3')
# CWbytearray(b'68 16 e1 12 49 34 00 bf 92 be 07 71 41 11 2f bd')
# CWbytearray(b'73 7e 34 a5 3f fc 63 9c 68 41 2a f9 5b e4 17 d2')
# CWbytearray(b'88 8b b2 6e a7 da 32 97 72 d9 f3 9d d6 36 1d 42')
# CWbytearray(b'09 d3 16 7a 7e ad 19 ad 99 17 36 73 50 84 b8 e0')
# CWbytearray(b'ca 24 a5 c2 04 42 12 30 5b e9 27 3f 42 78 1f 8f')
# CWbytearray(b'8b c5 b4 5c 30 6c 05 08 80 6e 34 a8 df cd 44 f3')
# CWbytearray(b'8c 14 5e 0a 7c 88 ac b0 04 79 7b df 40 58 73 fc')
# CWbytearray(b'db 68 ce aa 59 14 95 d3 38 5f ef d7 f3 9c 11 55')
# CWbytearray(b'94 75 66 da 4f f2 d7 69 93 ed 4e e5 24 af 4f 85')
# CWbytearray(b'79 51 11 49 c2 bf 63 2d 07 fa 37 f0 2b 71 27 76')
# CWbytearray(b'64 3c 31 dd 9f 8a f3 f2 3d b9 ad 78 c3 59 9e 69')
# CWbytearray(b'3c 03 56 cb 05 5f f4 74 72 ac 1e ac a1 dd e1 0e')
# CWbytearray(b'ae 5e 60 0c e5 0d 69 81 0a 30 87 2f 66 fc 24 0e')
# CWbytearray(b'b0 58 3d 41 e6 34 ea 93 0c e8 d5 fe 9f 93 0a 57')
# CWbytearray(b'38 c9 fc 77 a9 6a 02 7e 2c 3f 29 5b 70 53 42 61')
# CWbytearray(b'00 f5 11 55 17 c2 69 34 80 94 e7 1d 41 a8 d2 e8')
# CWbytearray(b'ac b8 b8 7c d3 b4 93 37 8e ab e7 30 97 55 7f 53')
# CWbytearray(b'15 74 bc 62 f7 50 d3 e1 09 98 e2 ea 0e 6d 12 c7')
# CWbytearray(b'cc cf 41 c5 98 b4 cc 65 51 be ae 55 87 c6 97 2b')
# CWbytearray(b'68 95 d6 bf fe 93 69 47 c5 55 4c 6e 35 fd a3 a9')
# CWbytearray(b'6e fb 7c 95 7a 86 f0 0b 8f d1 ba 1b 88 73 65 92')
# CWbytearray(b'4b 06 69 b3 a6 58 93 56 45 dc 74 03 28 40 ba bc')
# CWbytearray(b'bc 59 65 9c b7 21 9e 4d f1 f0 3f ee ea 42 43 19')
# CWbytearray(b'20 51 98 41 13 71 33 c1 57 02 c8 c0 68 5e cd f6')
# CWbytearray(b'df 6f c6 5c bf 62 1a b5 91 88 ce 62 bd af 39 fe')
# CWbytearray(b'30 40 d3 03 63 ee 97 ef 98 21 f4 1c d0 d8 f8 a7')
# CWbytearray(b'a9 e9 05 1e eb ef fa 2b bd b4 7e 86 15 2f 52 6b')
# CWbytearray(b'7c 7d bc 7d 8c f2 a2 27 74 23 53 d5 d5 ec 1e b5')
# CWbytearray(b'03 bc b3 b7 eb a9 49 2a 32 a8 92 05 53 a7 dc a6')
# CWbytearray(b'43 83 db c0 1e 1e 19 fe c1 c7 66 23 18 13 53 a4')
# CWbytearray(b'94 cc 55 b8 67 9e 95 52 e3 a8 80 82 6c 74 21 8e')
# CWbytearray(b'85 1e 4b 11 e1 b2 22 80 6e 95 e9 c8 cc 5f 5c a9')
# CWbytearray(b'3a b1 74 bf 72 f3 23 5f 03 1e 72 a1 7e 01 32 bd')
# CWbytearray(b'f5 00 8a ed 17 06 96 20 a9 4e 57 4b 0e 3c 85 26')
# CWbytearray(b'aa 21 be 16 72 6d a5 65 78 b2 5a b1 cf b8 dc ec')
# CWbytearray(b'c6 71 db 6d 1f b4 76 e1 a9 4b 2e c9 b5 c6 b5 3e')
# CWbytearray(b'd9 2a 74 9f 33 f1 70 8b fa fe 48 3e 71 f3 4d 12')
# CWbytearray(b'89 0d 0d 9d a1 3a 7a c8 b8 4f b3 07 e0 e5 d0 de')
# CWbytearray(b'0e 24 57 83 df 46 19 df 37 4f 02 2b 16 c7 e6 05')
# CWbytearray(b'e0 88 43 a0 7c ea 2e 4f 43 99 25 33 3e 44 1d a3')
# CWbytearray(b'70 dc 3d f0 df 37 6c 8a b8 57 43 fb 46 37 81 19')
# CWbytearray(b'b6 c6 d8 d2 70 10 25 33 62 19 6d 46 c8 f2 2e 4f')
# CWbytearray(b'79 ce c2 0f bc 5e a9 42 1d 75 ce c5 e4 4d 51 ab')
# CWbytearray(b'ed db 46 4f a9 56 be 02 98 97 51 8b 04 4d 04 82')
# CWbytearray(b'a8 f5 c8 5a 0a 71 a5 e7 4d b9 ef a5 3c de c4 22')
# CWbytearray(b'ae d3 4f 5b e9 0b cf 97 f2 fd a6 e9 25 17 c5 13')
# CWbytearray(b'b9 e2 1a 44 11 9e 16 6e 5f 68 09 5d b1 3f e0 f6')
# CWbytearray(b'c1 fd e2 a7 b7 60 c5 58 c2 1e 5c e5 86 f7 97 05')
# CWbytearray(b'32 c2 e4 a4 5b a9 7a 41 34 77 91 2a 5f bb 7f 81')
# CWbytearray(b'7c 14 21 5b 7c 54 08 e6 97 0a 50 7e b2 af 02 dd')
# CWbytearray(b'68 9a 12 43 4a 93 4f 6f 32 03 09 8a 37 89 fb 41')
# CWbytearray(b'1c a0 92 a3 1e 13 cd 47 53 29 6b f7 51 10 e5 35')
# CWbytearray(b'64 0a 8c fe 68 10 07 2d 38 5d b9 3c c6 be 2c bb')
# CWbytearray(b'50 7c 7c 0a 21 d1 03 42 88 d1 41 fa a7 78 b9 48')
# CWbytearray(b'0d 81 92 99 ff 17 6f 98 b4 c6 87 c6 35 45 76 38')
# CWbytearray(b'e7 0d 30 20 a6 50 70 68 30 07 ad ad 7c 2b c9 62')
# CWbytearray(b'39 7f b7 1c 1d f6 14 ad 36 5f 2a 38 33 82 34 c5')
# CWbytearray(b'19 95 c0 71 ea f1 96 3e 38 c5 c4 81 a9 d3 5a 35')
# CWbytearray(b'10 14 0b 3e db 7a c5 d7 96 bd 93 8c 9e 93 41 98')
# CWbytearray(b'a2 a2 da 49 1f a0 fc 09 ab 13 fa 10 44 89 c1 3d')
# CWbytearray(b'd1 90 b3 60 52 9b 53 72 88 8a c5 bd 9e 7d c8 a6')
# CWbytearray(b'29 28 dc 61 05 fb 6d 05 05 81 a8 fd 49 eb 95 10')
# CWbytearray(b'99 46 a9 ba 46 3d f2 20 33 c4 0c 6f 3c 0a dd 05')
# CWbytearray(b'6c 58 1d ac bd 8a 2d bd 5a 42 db 79 fe f9 d9 36')
# CWbytearray(b'c2 1e 19 c7 a8 28 02 80 89 bc fc a0 e2 17 14 45')
# CWbytearray(b'10 c7 52 7b 05 5a d6 a4 40 41 35 9a 8b 8f fb 7b')
# CWbytearray(b'ed dd 53 00 bf 35 f6 8e 81 e6 bb 03 3b 83 44 ea')
# CWbytearray(b'de 55 de ad cc 1b 6c 7e eb f5 b4 d9 65 c5 df c2')
# CWbytearray(b'a3 3a d2 97 7a 5f 69 c2 57 ad 74 9c 0c 58 26 50')
# CWbytearray(b'4d 87 33 fe 32 83 58 8f 3c a1 38 64 fc 8b 1e 35')
# CWbytearray(b'a7 86 03 aa cb da 50 00 03 4a 8d 3d 1e b8 60 79')
# CWbytearray(b'3b 4d 3f 10 3a 16 7f c5 24 aa e9 e3 0f 38 d9 ee')
# CWbytearray(b'88 d2 3a a1 6c b0 8b 7b 7c c2 6a ad 68 3a c0 3e')
# CWbytearray(b'df 78 03 a6 84 cd 56 20 30 53 70 d3 27 22 ee 7d')
# CWbytearray(b'ca ce a5 aa b9 52 d5 53 63 c4 d5 d3 76 c9 42 3c')
# CWbytearray(b'62 bd 6a 5e cc 3c 4d 58 c0 74 b1 f3 9c b6 4f 34')
# CWbytearray(b'0f 5e 62 a7 16 00 98 44 1a 89 2d 5b b5 28 53 cc')
# CWbytearray(b'62 42 24 9c 0a c9 92 62 1e bf b6 11 84 06 ff ad')
# CWbytearray(b'3e 5c ea e8 c5 cc 00 8a 32 b8 65 48 1a 9b d7 9a')
# CWbytearray(b'2c 34 6d be 09 d1 ec 49 ac 63 f1 8d 74 8a e3 4a')
# CWbytearray(b'99 b7 db bd bc fb 7d 49 61 c6 ae 63 b4 b2 95 3f')
# CWbytearray(b'5a f4 79 8e 34 23 55 04 09 07 5b 3d 27 75 7f fc')
# CWbytearray(b'a0 cd e6 63 1c b1 a2 a3 06 01 45 32 7b 3b 74 21')
# CWbytearray(b'ec 11 1c 81 43 0a cd 39 fa 7c a8 6c a4 e2 9b ee')
# CWbytearray(b'95 6d 83 c3 bf 5d d1 6c 67 0b 08 42 02 79 e0 c9')
# CWbytearray(b'60 98 8d 3d 5c 0f d3 65 a3 6b fc 1f 2d 5a ae 87')
# CWbytearray(b'73 b5 02 e6 53 c9 64 a0 33 14 54 b9 23 31 06 43')
# CWbytearray(b'dd c7 8f 7e 11 fb 19 4a da 5e 88 8b 0b c6 96 3c')
# CWbytearray(b'77 63 6c 2d c4 d0 2d 92 5d 22 4e 82 97 be cf f9')
# CWbytearray(b'8a d2 2c 3b 5d 82 95 3d 21 37 fc 8e c0 68 ea 28')
# CWbytearray(b'63 44 61 1e 50 7d f6 83 87 04 d3 64 44 a7 04 c1')
# CWbytearray(b'6e d0 32 4c 95 9d f7 75 18 d3 95 8c ce 4f a8 9d')
# CWbytearray(b'cf ff d6 62 b2 50 45 2c 21 a2 71 94 4a 19 dc c7')
# CWbytearray(b'68 13 a6 3c 09 46 06 cb 16 62 a6 72 c0 8e eb f5')
# CWbytearray(b'db 7e b3 d2 c7 6a 0c e1 5f 23 af 2e c8 b2 05 b4')
# CWbytearray(b'f5 cd ae 5f a4 6b a9 7e 09 5c 9a 6f 48 b8 7e d7')
# CWbytearray(b'90 03 9e 6b 59 2e d8 15 0b 5b 45 4a 9f a3 44 ae')
# CWbytearray(b'12 4a fe 48 1c b5 ed bb 55 2b 2e 9e fa 39 64 02')
# CWbytearray(b'd5 6e 41 fd c1 d0 60 33 52 c2 91 7c 3d f5 a5 a2')
# CWbytearray(b'f7 37 c4 c3 a9 e8 2a 1a 39 d8 5f cf 58 fc 3a 64')
# CWbytearray(b'94 9e 41 8b a3 24 25 6b 7d 63 5e b4 be ae e6 3d')
# CWbytearray(b'4f f3 df ca a6 ee 96 fe a4 de 73 2a f3 f0 00 74')
# CWbytearray(b'5f 9b 79 5d 44 1a fc 40 59 c4 8c 53 3b 22 f8 8a')
# CWbytearray(b'7c ff 71 9b 6a 43 61 aa 21 8f 64 be b3 26 df 85')
# CWbytearray(b'd8 d1 e1 39 d2 ff d6 32 80 1b 06 0c e5 23 3e bf')
# CWbytearray(b'c1 0d 6a 2f 2d 5e 81 1c 78 dd 45 fe a6 0f 04 9e')
# CWbytearray(b'ed 56 0e ae 65 b3 af 43 22 05 cb b6 0f 2e 79 14')
# CWbytearray(b'1f 58 76 a2 1d 95 ca 69 bb 5e f4 38 e9 5e ee 54')
# CWbytearray(b'10 5b f5 19 9a ed 73 d6 c1 82 9b 13 12 22 21 f6')
# CWbytearray(b'c6 e3 3d d7 72 53 6b e7 b1 0d 3b 48 22 0f 6f 23')
# CWbytearray(b'2d 86 3f c7 36 4a 3a 06 af a3 65 68 8f 38 35 59')
# CWbytearray(b'60 df 68 50 02 74 af 3c 6a 12 9b 5b 4f 51 59 dd')
# CWbytearray(b'0f da 42 fd 34 bc a1 10 c1 ce 08 ab a4 69 ae e5')
# CWbytearray(b'8b 09 10 9b 48 fb f5 f8 57 9d 72 f0 ef 94 99 26')
# CWbytearray(b'cc 95 88 41 81 8f 0a fe f1 96 87 e1 ab 40 24 fc')
# CWbytearray(b'38 3e d4 bb 54 1d 2f 59 ce 4c a7 4d 52 07 2f 2e')
# ...
# CWbytearray(b'71 26 2a c7 ee b7 35 d8 de 7b 9c c0 0b 75 c6 b3')
# CWbytearray(b'ff 6b 0e 49 ae 49 1b af e0 a1 f5 35 c0 f0 dd 17')
# CWbytearray(b'e8 bd bf b0 b8 f8 c2 6e 52 db 2d fd 2b d0 77 a4')
# CWbytearray(b'bb 55 4f 72 be 5a 07 eb a1 9a 00 61 c9 4d 14 72')
# CWbytearray(b'fe 27 72 65 93 a2 b2 67 bd 56 94 d7 4a 97 3c 61')
# CWbytearray(b'7f e0 d3 58 0c 71 5b 65 d8 c4 a7 fd 37 94 ec 09')
# CWbytearray(b'50 d6 43 b0 3b ff d0 59 f0 39 4a 80 5f c2 6d 49')
# CWbytearray(b'f3 19 bd 93 e3 38 72 bb 21 f4 fa cd 1a 21 58 0c')
# CWbytearray(b'4e 4e 2b c2 b8 58 1a 16 0b a8 6d 73 67 0a ff bc')
# CWbytearray(b'49 1c de 4d a8 e3 1e 66 3b 2d c9 29 70 d9 6d 64')
# CWbytearray(b'01 41 87 9a e7 55 76 82 ae 70 c6 55 f9 00 17 44')
# CWbytearray(b'67 c7 79 19 b8 07 8d eb a6 44 a7 5b 63 b1 17 76')
# CWbytearray(b'c0 c1 f2 8c 8f 71 eb 7e 96 44 b7 75 06 fe 68 27')
# CWbytearray(b'3e 3b d2 ac bd 91 b7 57 3f c5 b1 bf 9f a4 8b 64')
# CWbytearray(b'ab 13 4e f9 96 0c fb 69 72 df 90 90 39 6f 58 b1')
# CWbytearray(b'7d e6 4f bb 14 22 07 f6 99 3d 22 a9 76 89 90 e8')
# CWbytearray(b'55 48 e1 a5 21 31 19 c5 e1 49 68 72 6b 4e 9b 8c')
# CWbytearray(b'1f f7 aa 63 f5 40 89 de b0 92 4c f7 45 00 be 36')
# CWbytearray(b'6d 6f bf 56 5f b3 af 15 8b 45 ff e6 e2 63 35 12')
# CWbytearray(b'a1 8b 35 8e af a4 8a b2 39 f2 84 83 e9 ee 47 17')
# CWbytearray(b'14 3d 73 b2 81 c1 16 55 a4 25 4e e2 fc a3 12 c6')
# CWbytearray(b'b3 c1 1b a4 52 4d 06 c6 28 dc 81 b9 44 22 fc 6d')
# CWbytearray(b'7a 65 94 c8 1a 59 d2 e2 29 58 a2 29 fb 1c 91 16')
# CWbytearray(b'fd e9 e2 bd e5 1b 5b 7a a6 4d b0 c8 1b 2c 07 92')
# CWbytearray(b'fd 1a 3d 24 a5 1c d7 69 34 10 3d c3 dc 50 0c 55')
# CWbytearray(b'90 79 ef 8f ee 98 8e a4 02 5b 92 0b 76 48 ad a0')
# CWbytearray(b'37 31 05 55 91 cf ee 83 2e fa a8 c1 73 12 e1 a2')
# CWbytearray(b'19 71 ff 0f ba ca a0 f9 0d b3 ac 06 9e 2a 5f 41')
# CWbytearray(b'51 3a a7 63 88 d2 06 d4 27 2b f8 18 33 97 7e d5')
# CWbytearray(b'3f a5 39 d5 2c 13 fe b1 15 72 ac 22 42 76 71 3c')
# CWbytearray(b'6a 69 cc 46 0f 82 54 e1 99 66 86 f3 49 01 47 40')
# CWbytearray(b'ce b4 30 e9 92 31 ea 19 98 e9 46 be 7c 9e 70 0c')
# CWbytearray(b'd3 0d 4c ff dc 1d 17 b1 b6 ea bc dd 53 5c 82 d0')
# CWbytearray(b'fa c6 93 60 57 a1 c4 1b 20 6b 78 e2 80 6d 6f 42')
# CWbytearray(b'ff 91 3f c7 e8 7a 15 03 5f d0 6f 72 bf 69 8b c4')
# CWbytearray(b'b4 30 7b 8e 1d e1 30 37 3f 4c e4 82 83 8c 17 a9')
# CWbytearray(b'7c a3 b1 b8 bc 13 d9 7d cb 3c 36 b0 22 e7 0c 09')
# CWbytearray(b'85 56 3e ee 8c 2a 90 fe 9b d7 4e 5f 38 5b 41 38')
# CWbytearray(b'36 8b e1 2b 8a 6a ae 7c 5b f7 d0 96 04 c4 06 f7')
# CWbytearray(b'dc c8 ff 9a f2 e1 29 b5 3a c0 f3 9a f1 71 c4 74')
# CWbytearray(b'03 09 b8 b6 c0 b5 95 08 8a e5 d0 92 44 58 e4 39')
# CWbytearray(b'5b 3f 05 16 26 b8 4c bb 2b 31 fb fc cc fb 06 6d')
# CWbytearray(b'57 46 d2 3f b9 a3 49 06 b5 a2 20 f0 0c c2 78 96')
# CWbytearray(b'40 38 d2 57 01 72 59 8b bc 6d 04 c3 c7 58 54 4e')
# CWbytearray(b'bb e1 e1 0a ef f3 12 f2 0f cd eb e7 a4 4e 7a 39')
# CWbytearray(b'6a b8 a4 c0 e6 55 17 75 5b 1e e6 af 46 f9 fd 19')
# CWbytearray(b'8c 79 06 6c 0c 07 cf be 44 81 39 51 05 68 ca 1e')
# CWbytearray(b'8b d1 34 d7 2c 56 ee a4 ba 0a 8d c6 c2 c4 40 ad')
# CWbytearray(b'63 57 d4 b3 5f a1 89 e1 14 e5 37 21 ce 56 a9 94')
# CWbytearray(b'de 05 0b 00 a2 bb 6d 65 28 96 47 0a 2d bd ce 6f')
# CWbytearray(b'97 80 19 6f fd 04 e5 25 b9 e6 1e 26 e5 51 71 71')
# CWbytearray(b'b7 6c 07 2a 9a 1c fc 23 44 ae 44 d5 53 de 1b 1a')
# CWbytearray(b'de 3b 82 18 98 90 e8 fc 4b a4 cb 19 af c5 83 6b')
# CWbytearray(b'13 28 c1 c3 fb bb e4 92 e8 c6 04 28 b1 b5 7c 52')
# CWbytearray(b'5d e2 89 88 07 67 cd f0 6b 63 91 6d 30 44 82 8a')
# CWbytearray(b'bc 3d a7 5a c1 7e a0 c4 0b 1a 4a 9b 97 1d 5d 06')
# CWbytearray(b'8c 6e 3e 9e 4b 1a 52 66 9b 21 02 4b d7 97 bf 77')
# CWbytearray(b'4c 02 fc a1 98 ca b9 c7 fc 5e cf 5d 83 82 c8 9d')
# CWbytearray(b'70 d3 d3 aa 22 1e e7 e5 5c 4b 3f b2 b8 54 77 14')
# CWbytearray(b'27 c1 90 b7 ba f4 6f 0e f2 3e b6 48 d0 d2 d3 15')
# CWbytearray(b'f7 c2 c2 a2 c3 44 08 ea 2f 86 74 cb 14 ce 91 3a')
# CWbytearray(b'b4 1d 50 13 8e f0 81 40 22 e6 2f 84 cc 70 d6 4a')
# CWbytearray(b'50 d8 2a 41 05 53 15 34 2c 90 b0 43 52 f6 d8 7b')
# CWbytearray(b'e7 33 0c d1 ae bd fc 30 d5 7c a9 0f 62 ef 08 65')
# CWbytearray(b'ab 58 60 6d d7 b4 0c ac 62 dd be 74 f8 3f 45 79')
# CWbytearray(b'b3 cd 57 2c 02 69 3e 0a bd db 00 a3 e1 7e 8c d2')
# CWbytearray(b'e4 09 54 fb c2 e0 61 80 e6 2c d9 9c 0c 98 cf e2')
# CWbytearray(b'10 ae 32 15 94 8a 0e 88 c3 b9 17 79 18 49 6b 8b')
# CWbytearray(b'00 2b a7 31 21 9e 7b 83 87 c2 13 30 2c a8 48 2d')
# CWbytearray(b'6e 62 a4 08 86 9b 00 3f 95 93 2f d3 7e 4d f7 ba')
# CWbytearray(b'0c b3 15 9d 0a 1d af b9 43 31 d8 f3 03 ae 4e 15')
# CWbytearray(b'20 35 15 d5 0e d4 0a 13 87 aa bb a7 0a 11 77 d0')
# CWbytearray(b'd3 a5 cc d1 80 a7 a8 7f de 58 c4 a3 c4 63 e4 58')
# CWbytearray(b'1d 92 c6 80 c2 5a 09 68 53 68 32 84 23 e3 5a 79')
# CWbytearray(b'd1 01 30 22 a2 7b 7e 4f d4 8b f0 06 cb ef ba 16')
# CWbytearray(b'be 5d 6b 7e d6 26 b0 9e af df 60 cb 6a f3 5b 02')
# CWbytearray(b'22 1c f2 6f 58 f3 9e fc cd a2 6b af dd 04 8c f0')
# CWbytearray(b'fb e9 62 1f 81 3c 88 66 4c d5 47 88 3b e6 16 31')
# CWbytearray(b'e0 d7 dd 4b 2a 42 5d 48 f0 a9 52 31 00 71 30 9f')
# CWbytearray(b'70 8b 37 4c 7d cf 91 4f 2e f6 ac b5 7e bb 2e 57')
# CWbytearray(b'99 9b 22 71 5b 61 22 29 f8 64 fc db 53 fe 67 ba')
# CWbytearray(b'4d 78 62 b8 7d f6 d7 01 12 02 91 07 1b 67 a2 fd')
# CWbytearray(b'2e b6 3a c6 8c d3 ec 3b 89 2e 57 77 ed db 0e 4b')
# CWbytearray(b'25 9f 32 b3 7b 90 64 d4 a9 e6 bf 56 e5 e5 0f 4f')
# CWbytearray(b'6b 7f 74 e6 35 0f 17 ce fd 05 9c eb 8f d7 78 06')
# CWbytearray(b'6c 40 8c 26 46 30 cf 0c 63 c3 ac 93 8f 16 6e 0d')
# CWbytearray(b'd9 44 6b e7 49 21 24 21 fd d6 a8 08 d5 58 be 34')
# CWbytearray(b'36 7b a0 c9 b1 70 5f 30 6a de 4a c8 b6 0e 95 f5')
# CWbytearray(b'a6 24 69 1a 51 30 54 1b 96 62 08 b0 5a 71 9a 9b')
# CWbytearray(b'25 04 a2 3a 00 35 00 37 79 4c d0 10 62 cf 70 c2')
# CWbytearray(b'c0 7a f9 81 3e da 5b 5c ce 8b 20 20 70 09 c7 2a')
# CWbytearray(b'74 5f ce 39 5e 48 34 31 0f 3f 11 4d 0c 4e 65 a6')
# CWbytearray(b'15 d8 c3 da 2b a4 ac 04 1a 3a 04 a1 4e 94 3b 61')
# CWbytearray(b'fd c8 48 db 22 28 29 32 9c 9d fe 7c 49 88 06 46')
# CWbytearray(b'81 db ee 42 dc dc a7 16 73 28 69 4c fd cf 95 c1')
# CWbytearray(b'06 24 6d 03 c8 75 03 dd 7e dd 7e 7b c6 3e 51 d0')
# CWbytearray(b'39 38 ab bb 41 8d 57 9c da 96 6c 73 fa 3c 60 b6')
# CWbytearray(b'c0 a7 8c 47 98 8f 9a 34 75 23 85 90 0d 58 75 29')
# CWbytearray(b'ef 88 b8 85 61 03 fd 20 4b e3 8f 7c 86 68 a7 80')
# CWbytearray(b'ed eb 67 68 ea f3 b1 f5 3f c4 04 de c7 f2 72 e0')
# CWbytearray(b'a1 1b d3 78 54 a6 f2 14 28 32 75 ff 94 e7 7c ac')
# CWbytearray(b'f0 df 5b b5 53 84 dd 85 a3 02 56 23 ab d8 60 88')
# CWbytearray(b'ce 15 41 65 f5 ee b3 4c 5c f0 4c ec 54 3f 33 9c')
# CWbytearray(b'd7 63 29 e3 c8 d0 8b f1 48 68 0a 17 17 bf 82 18')
# CWbytearray(b'06 e0 a8 b1 c2 b7 91 da 42 56 6b 47 71 21 eb 32')
# CWbytearray(b'f0 38 d3 5b b1 32 1a 4e 19 20 d4 6e 49 ed 2a ca')
# CWbytearray(b'ce d7 72 24 49 b4 63 82 77 40 15 22 64 42 b2 45')
# CWbytearray(b'7d 65 2c 73 39 17 77 03 b9 fe c0 26 e5 9f a5 8b')
# CWbytearray(b'7d b7 17 cc f3 07 58 58 cf 18 4e 44 f0 79 59 85')
# CWbytearray(b'35 97 67 5e c6 99 6b ca 21 97 64 e5 c2 a7 e7 ce')
# CWbytearray(b'61 fe 5b bc ba 92 6b f7 7e 0a 72 e1 89 b8 43 f4')
# CWbytearray(b'9e 43 d7 0e 21 ca 37 e6 d0 a1 56 01 19 60 0f f0')
# CWbytearray(b'ae f6 bc 88 df 37 f9 5e 37 a0 b6 7b bc 60 1f 84')
# CWbytearray(b'e6 ca 9d 9a 36 92 9f 41 96 0f 5f e2 02 a0 0f 63')
# CWbytearray(b'33 ac d8 5e f5 9d 5c dc 56 d7 ac ce 3e 0e d9 12')
# CWbytearray(b'e4 86 9e f5 d4 64 41 3a 7c ee 9b 2d 37 9b f3 0b')
# CWbytearray(b'28 b6 de 84 d1 e1 0e 86 b1 47 59 c4 31 d0 9b f6')
# CWbytearray(b'2b 13 0e b0 9c 6a 0a 64 f9 a4 3f 5d 9e 8c 83 b5')
# CWbytearray(b'7b 2b d7 da 78 1e 41 b4 68 b7 3c 6e c4 80 9c 4a')
# CWbytearray(b'5c c0 dd ee 11 ef ba c7 87 87 38 d1 08 c5 01 cf')
# CWbytearray(b'a0 bd 05 b4 ff 94 ea 99 fd 43 32 30 ce ca 24 bc')
# CWbytearray(b'8a f5 ea 5a c5 10 7e 67 45 56 fa 52 7f c0 7f 84')
# CWbytearray(b'07 57 cb fc 3e 3d 38 f3 27 13 2a ef 2d 6e 49 50')
# CWbytearray(b'7f 51 73 4f 8b 8b b6 dc e4 54 ea ac 47 3f 69 94')
# CWbytearray(b'd8 17 9a 60 80 ed ba 82 7b c3 03 b7 f0 1a c7 b5')
# CWbytearray(b'52 8d 2c 3d 39 0e e0 ee 43 a0 46 d1 27 d5 a1 b3')
# CWbytearray(b'24 28 7e b2 89 77 ca ce e8 48 a0 07 2f 9e a7 3c')
# CWbytearray(b'18 3f 3f d2 0b 7e 0a 0a 87 29 83 b5 7f 60 29 48')
# CWbytearray(b'94 c8 49 0c cd a4 51 c2 3d d7 39 35 99 cd 2f 97')
# CWbytearray(b'2f 75 77 ff 4e 90 ef 7b e5 b6 45 83 54 2e e5 45')
# CWbytearray(b'01 bf 0b b9 86 55 4e 74 10 64 e3 27 60 c7 90 44')
# CWbytearray(b'd0 d9 25 7d e7 61 a3 22 01 52 c5 94 cc 57 d8 89')
# CWbytearray(b'8c b4 7d 38 45 28 7f 64 44 b5 f2 69 b8 b7 5c 30')
# CWbytearray(b'1b 08 da 6e 39 9a f4 15 7a 4e 7c b6 0c 71 0d e0')
# CWbytearray(b'7b 3c 6f 1c f1 4f b2 28 75 b7 95 35 d8 54 aa f4')
# CWbytearray(b'08 1b 79 7e 59 a7 d5 cb 80 d7 79 d8 c9 c2 22 c0')
# CWbytearray(b'7b 18 04 ac 39 49 f4 dd 24 21 14 2c 8c 02 ed dc')
# CWbytearray(b'16 cc 34 76 49 c5 8d 21 f6 a8 61 7f a5 49 17 9f')
# CWbytearray(b'a7 b7 a3 3c f5 9a ca 0c 18 8f 27 a6 87 97 f8 4b')
# CWbytearray(b'73 fb 16 d7 3c 43 b9 6d e0 15 11 db b1 c4 6a ba')
# CWbytearray(b'0e 56 06 eb 72 a7 99 cc 2e 95 08 dc 03 83 29 15')
# CWbytearray(b'22 e3 2e ba 25 0f 4a 96 61 76 8f ba 75 67 1e b3')
# CWbytearray(b'80 c6 16 7b 53 d8 75 fe b9 02 ea a5 38 10 70 0c')
# CWbytearray(b'bd c4 35 66 1a f4 0a f8 19 be 7b 79 12 39 8b b4')
# CWbytearray(b'6f a1 24 64 1d 1f e9 c6 ca ac 0d 1f b2 e0 9d 02')
# CWbytearray(b'c3 5a 8c 6d b7 b1 d9 5a 43 67 2d f4 d3 28 cb 5e')
# CWbytearray(b'38 9e d4 62 21 b6 8e 32 b3 2f 23 1f 91 f0 91 36')
# CWbytearray(b'45 70 36 f1 90 22 ca 4a 29 71 3f 65 f5 a0 2f 62')
# CWbytearray(b'52 76 72 c4 79 36 55 c2 12 5b c2 ac 37 2a e1 39')
# CWbytearray(b'0c 5f 42 c9 7f a0 68 2f e4 86 54 24 0c 05 98 82')
# CWbytearray(b'7a 70 fe 06 c6 47 ca f0 29 70 0b b6 f9 20 05 d8')
# CWbytearray(b'3d ef d2 74 66 18 8f be f0 e6 61 8b c6 cc 09 8b')
# CWbytearray(b'da dc 4c ec a4 fe 7f 60 56 cc 72 dc a0 da 9e da')
# CWbytearray(b'e4 e7 ac 86 72 57 9d 17 b9 34 75 97 42 26 38 7f')
# CWbytearray(b'27 35 48 db f2 9b 66 eb 71 58 6f 39 79 99 60 a1')
# CWbytearray(b'8b d4 54 62 4d 25 db f0 04 09 d2 25 9d 9a ee 92')
# CWbytearray(b'b4 5e e7 b8 8e 21 a6 e8 ec fa 38 cd a6 7c 30 d0')
# CWbytearray(b'88 23 8a a1 3d 85 7e 50 30 ab d4 25 bc 09 8b b6')
# CWbytearray(b'51 ed 76 db a0 36 5d d0 ea a1 eb e2 f0 33 d2 bf')
# CWbytearray(b'0c a9 fc ca f2 57 70 1f 41 d1 4e e0 8e c8 1a e0')
# CWbytearray(b'6f 42 54 4a e4 5d f7 73 77 59 c4 85 8a c6 99 46')
# CWbytearray(b'66 d2 3d 49 88 ad eb 73 ab 80 6e 13 6d 48 08 49')
# CWbytearray(b'fc 4d 07 2c c4 97 24 f0 07 fa c0 c7 10 c9 65 46')
# CWbytearray(b'cc 4a f6 69 33 f2 c8 4c e5 f6 97 9c 33 fe 79 63')
# CWbytearray(b'cc 25 bb 4c 31 e7 e2 33 65 47 f4 5c 24 db aa af')
# CWbytearray(b'7e c6 d4 8a 59 44 40 0b 22 66 8c ec 4a 32 a2 b4')
# CWbytearray(b'b4 2f 31 c1 09 79 e8 db a4 96 da 35 32 d4 78 0f')
# CWbytearray(b'8e b3 4b 01 de e7 31 ed 28 e1 ac 7e 61 b7 d7 92')
# CWbytearray(b'51 03 bd 9f d9 44 c0 c1 c6 25 08 1e 7a d2 f7 5c')
# CWbytearray(b'04 78 c8 8f 0f 53 5c e7 a2 0d 1d 1a e1 18 ac 49')
# CWbytearray(b'4b 83 a4 48 b7 d6 3f ac b4 91 7d a9 20 6b 97 b2')
# CWbytearray(b'71 01 30 29 f1 86 35 1e e5 54 6c fa 9c d2 33 1b')
# CWbytearray(b'40 0f 34 1c a1 85 fa d8 bd 96 52 7a f2 f1 8d 52')
# CWbytearray(b'd4 7c 69 ec 18 cf 41 c0 9b c8 17 42 a2 73 e5 9f')
# CWbytearray(b'b9 e8 0a 03 58 5d b3 cc a4 a6 e6 73 7f c6 ba 7c')
# CWbytearray(b'dc bd 53 e8 e4 b9 a6 ed 6b f2 82 73 91 91 1d 0a')
# CWbytearray(b'77 9b 2f 3b 25 90 4a 04 b5 ca 5b 09 54 50 eb ad')
# CWbytearray(b'c9 fd 9d ed fb a3 f8 ad e9 6b 3b 2d 9c 6f 66 56')
# CWbytearray(b'28 94 cc af fa c5 a5 53 91 60 b1 9a d8 9e 75 86')
# CWbytearray(b'8b af 1a ce 47 e1 06 39 9a 50 37 e0 6a 21 63 81')
# CWbytearray(b'7c b9 39 42 a2 8a 5e 40 65 27 af d9 9a 60 40 93')
# CWbytearray(b'db 25 31 e3 4e 5b dd 48 0c 04 66 98 8d 71 f0 33')
# CWbytearray(b'e5 db af 06 6f d9 1c ba 51 2f 34 bf 0c 86 4f f9')
# CWbytearray(b'd0 57 b4 27 f5 58 4b 21 1b d2 9f a0 28 27 6e 2a')
# CWbytearray(b'51 eb d3 ac 46 37 c9 fd c3 7d e4 e2 42 7e 67 0b')
# CWbytearray(b'b3 4d 08 bd 80 a0 ad 99 64 b9 60 8c ef 6d a1 79')
# CWbytearray(b'26 47 f7 de 61 5e a1 72 64 59 6b 1a 41 5f 04 47')
# CWbytearray(b'7a 2c 23 05 8c 43 20 3f c6 6a cc 18 22 4f 54 e1')
# CWbytearray(b'cc bc 2c 39 60 bd e9 a5 e8 56 83 80 82 10 db 56')
# CWbytearray(b'f2 30 e2 dd 9b c6 e6 b9 d5 7f cc f4 f3 82 ae b6')
# CWbytearray(b'f9 de d3 8e 99 7c b4 f6 d1 07 b9 08 da d5 3f f1')
# CWbytearray(b'46 52 1b ad 8f 6d 29 3a 9f 5c 44 c3 6f 9a f9 5a')
# CWbytearray(b'3f 3b 36 04 d2 55 3d 3c 1c 6e 1f db 8d a1 92 51')
# CWbytearray(b'23 58 cc 16 dd 85 a5 40 ab 3e 22 28 2b 1d 0b 41')
# CWbytearray(b'da bd 8d 87 74 ef 2f fa c7 fa f6 e0 dc 44 83 a6')
# CWbytearray(b'6e d6 dd 15 51 c0 95 9c d3 36 b8 f3 a2 1e ae ce')
# CWbytearray(b'52 0a df 73 fc ad a3 f5 00 c2 6f 78 92 2f e8 ee')
# CWbytearray(b'1c 3e 0b dd 98 e0 1e 07 e8 47 ff 74 dd aa 2b 4c')
# CWbytearray(b'9a 4c 64 4b 23 a8 33 57 96 b7 4d 9e dc b6 6a 2e')
# CWbytearray(b'00 19 db 34 85 ef 7d b4 a8 09 54 d4 36 7e be 39')
# CWbytearray(b'02 36 6e 0a 74 b9 c0 e5 98 49 ab b7 f6 04 c9 59')
# CWbytearray(b'45 70 58 e0 17 df 7d a0 56 fe 52 21 04 a4 64 39')
# CWbytearray(b'3f 08 5c 7a 60 1c 15 f9 be 99 dd d2 db 5b 7b 7a')
# CWbytearray(b'12 89 97 d9 02 24 72 fc 4d 17 d1 2c 91 9d 55 1a')
# CWbytearray(b'58 30 a9 0e ac f1 6e 15 0f 37 c5 ba 8c 56 b2 60')
# CWbytearray(b'5b d3 9e 20 a9 8d ca 06 83 e9 c1 a7 d8 fb cd 9e')
# CWbytearray(b'20 e3 ec 27 c7 9d ee f7 ef a3 6a 82 bb 6d c3 27')
# CWbytearray(b'a8 18 9d 36 7c e8 47 91 5f dc b2 2e e4 94 0b e4')
# CWbytearray(b'50 be 54 c0 19 dc 7e 79 41 8b cd 1d 56 68 b3 a9')
# CWbytearray(b'10 38 2d 85 0f 2f 96 dd 24 49 01 93 e0 81 fe 2d')
# CWbytearray(b'40 4b 48 88 09 d8 2d 0c d0 be 48 de 6a 32 0a d5')
# CWbytearray(b'ca 91 9f 5f 28 dc 69 a7 e1 53 df 12 bc 3c c4 56')
# CWbytearray(b'4f d4 bc 4e dd e3 ee 49 8d 7e 6b b0 a9 3a 0c a4')
# CWbytearray(b'a4 9e 7e e1 46 8f 83 2f bf 47 dd f1 05 ae 84 aa')
# CWbytearray(b'e4 08 fd cb fe 89 1a 19 a3 f7 99 4b 59 0c 7a 37')
# CWbytearray(b'8a 45 b9 8d b7 c0 69 f0 93 03 d1 f3 11 a1 b6 21')
# CWbytearray(b'84 c9 20 26 a3 fc c4 a7 98 d1 36 46 a6 25 3c 9b')
# CWbytearray(b'dc d5 a5 cf c4 16 11 ef 26 9f 51 26 4f 91 3f ff')
# CWbytearray(b'49 2e 26 27 23 81 f5 a9 23 9b 0a 05 e4 ac 28 d6')
# CWbytearray(b'29 6e 39 52 d6 01 29 77 cc a4 f4 bd 41 47 de a4')
# CWbytearray(b'e9 2a 94 be fe 5b 44 95 52 49 1a d9 ea 9b ce 2e')
# CWbytearray(b'81 58 d9 6e d3 be 50 10 50 c2 4a c6 f9 96 3c 7a')
# CWbytearray(b'2c 8e 59 a3 53 fa bc 0f f2 24 9a 2a 91 b4 ca 99')
# CWbytearray(b'61 12 70 dc 2d 11 fa 18 9c 55 a9 7a 20 11 39 4a')
# CWbytearray(b'3c 56 fe 9e c9 a6 d3 da ee ab ba ad 26 a7 6d dd')
# CWbytearray(b'e9 ba 74 d2 c4 d7 06 40 5a fd 9d 1e 8f fa 71 a1')
# CWbytearray(b'ce c6 ae 2a 4d 36 9e 57 c1 9f d8 d2 d5 60 14 72')
# CWbytearray(b'1a 49 9f 0b 73 70 32 3b 8c 33 06 5c 4c 70 d0 62')
# CWbytearray(b'48 60 d5 b0 7e cf 32 07 84 b5 0f a8 67 9a ed e7')
# CWbytearray(b'c2 bb fe 8f 18 83 fe 81 ff 2f ba 4f 4d 2c 57 7a')
# CWbytearray(b'88 fd a3 a4 7b 18 e2 f3 08 b6 6f 90 c0 1b 13 5a')
# CWbytearray(b'cc 4c e5 7f 55 cc 54 79 b4 56 93 6f 78 1f 81 eb')
# CWbytearray(b'32 fe 55 d0 4d 89 0e 2a 2d d2 b2 8c cf 48 22 ae')
# CWbytearray(b'a1 e6 f5 fd 48 ef de 5e 58 04 92 9f 7b 52 d0 24')
# CWbytearray(b'77 4f 5c f9 ad 25 cc d1 8b 2e 52 1b e1 f5 ce 94')
# CWbytearray(b'ba 0a 41 00 c7 55 8e aa 41 44 6d cd ea 6b e5 36')
# CWbytearray(b'e0 91 48 56 6a 1c 78 b5 93 79 3f 17 55 4e d4 1b')
# CWbytearray(b'06 f7 2a b4 ba d3 9a 1a 43 2c 9c d9 17 86 6f 0f')
# CWbytearray(b'57 22 17 77 c7 88 08 5f 06 07 58 84 23 99 1f 59')
# CWbytearray(b'99 70 bd 01 78 11 06 ae 2d 22 bb 47 fc ee 7a b5')
# CWbytearray(b'70 89 fb ed 77 a5 ce 2a ab d8 f1 ec c5 fd 8b 8c')
# CWbytearray(b'9f 89 f6 cf a0 22 cc 2b 9b 81 f7 4f 59 00 82 38')
# CWbytearray(b'55 b0 e8 6b 1b 6a 5f e8 e3 4a d5 99 c7 25 68 3d')
# CWbytearray(b'bf 14 f2 04 70 5c d2 97 53 8c 9f 43 95 fa 05 9a')
# CWbytearray(b'08 b0 3e c2 45 b1 ff cc 44 4e c1 19 8a 53 72 2a')
# CWbytearray(b'9b 8a 91 a2 7a 00 3d 33 f9 7b 6e 99 e9 b1 2d f3')
# CWbytearray(b'c6 fb fe 01 2d 77 9f 8f fc 04 a9 4e cf 01 15 ae')
# CWbytearray(b'23 0a d1 f7 f5 b7 d5 31 99 66 67 29 8b e2 e0 0b')
# CWbytearray(b'c3 2e 4f d6 78 df 34 6d 64 93 db 01 34 e3 f3 a2')
# CWbytearray(b'fb b5 9b 64 92 d2 c8 d4 2a ad 06 c1 85 0e 7a 66')

# %%
np.save('./AES_%s.npy'%Trojan_ID , traces)

# %%
from datetime import datetime
import os

now = datetime.now().strftime('%Y.%m.%d-%H.%M.%S')
os.mkdir(now)

traces_array  = np.asarray([traces.wave for trace in traces])
textin_array  = np.asarray([traces.textin for trace in traces])
textout_array = np.asarray([traces.textout for trace in traces])
keylist_array = np.asarray([traces.key for trace in traces])

np.save('%s/%s_traces'%(now, now), traces_array)
np.save('%s/%s_textin'%(now, now), textin_array)
np.save('%s/%s_textout'%(now, now), textout_array)
np.save('%s/%s_keylist'%(now, now), keylist_array)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 7
#       4 now = datetime.now().strftime('%Y.%m.%d-%H.%M.%S')
#       5 os.mkdir(now)
# ----> 7 traces_array  = np.asarray([traces.wave for trace in traces])
#       8 textin_array  = np.asarray([traces.textin for trace in traces])
#       9 textout_array = np.asarray([traces.textout for trace in traces])
#
# AttributeError: 'list' object has no attribute 'wave'

# %% [markdown]
# This shows how a captured trace can be plotted:

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()
p = figure(plot_width=800)

xrange = range(len(traces[0]))
p.line(xrange, traces[0], line_color="red")
show(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 from bokeh.plotting import figure, show
#       2 from bokeh.io import output_notebook
# ----> 4 output_notebook()
#       5 p = figure(plot_width=800)
#       7 xrange = range(len(traces[0]))
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\output.py:124, in output_notebook(resources, verbose, hide_banner, load_timeout, notebook_type)
#     122 # verify notebook_type first in curstate().output_notebook
#     123 curstate().output_notebook(notebook_type)
# --> 124 run_notebook_hook(notebook_type, "load", resources, verbose, hide_banner, load_timeout)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:357, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     355 if _HOOKS[notebook_type][action] is None:
#     356     raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 357 return _HOOKS[notebook_type][action](*args, **kwargs)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:474, in load_notebook(resources, verbose, hide_banner, load_timeout)
#     471 jl_js = _loading_js(bundle, element_id, load_timeout, register_mime=False)
#     473 if html is not None:
# --> 474     publish_display_data({'text/html': html})
#     475 publish_display_data({
#     476     JS_MIME_TYPE   : nb_js,
#     477     LOAD_MIME_TYPE : jl_js,
#     478 })
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:487, in publish_display_data(data, metadata, source, transient, **kwargs)
#     485 # This import MUST be deferred or it will introduce a hard dependency on IPython
#     486 from IPython.display import publish_display_data
# --> 487 publish_display_data(data, metadata, source, transient=transient, **kwargs)
#
# TypeError: publish_display_data() takes from 1 to 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %%
import matplotlib.pyplot as plt
plt.plot(traces[0]-traces[1])
plt.show()

# %%
np.save('./tr.npy' , traces)

# %%
from tqdm.notebook import trange
import numpy as np
import time
from Crypto.Cipher import AES

ktp = cw.ktp.Basic()

traces_t = []
textin = []
keys = []
N = 20000  # Number of traces

# 평문
plaintext = [
    0x32, 0x43, 0xf6, 0xa8,
    0x88, 0x5a, 0x30, 0x8d,
    0x31, 0x31, 0x98, 0xa2,
    0xe0, 0x37, 0x07, 0x34
]

key, text = ktp.next()
cipher = AES.new(bytes(key), AES.MODE_ECB)

for i in trange(N, desc='Capturing traces'):
    text, key = ktp.next()
    text = plaintext
    
    textin.append(text)
    keys.append(key)
    
    ret = cw.capture_trace(scope, target, text, key)
    if not ret:
        print("Failed capture")
        continue
    
    traces_t.append(ret.wave)
    project.traces.append(ret)
# Out:
# Capturing traces:   0%|          | 0/20000 [00:00<?, ?it/s]

# %%
from datetime import datetime
import os
now = datetime.now().strftime('%Y.%m.%d-%H.%M.%S')
os.mkdir(now)

traces_array  = np.asarray([ret.wave for trace in traces_t])
textin_array  = np.asarray([ret.textin for trace in traces_t])
textout_array = np.asarray([ret.textout for trace in traces_t])
keylist_array = np.asarray([ret.key for trace in traces_t])

np.save('%s/%s_traces'%(now, now), traces_array)
np.save('%s/%s_textin'%(now, now), textin_array)
np.save('%s/%s_textout'%(now, now), textout_array)
np.save('%s/%s_keylist'%(now, now), keylist_array)

# %%
# !pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (3.6.3)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (24.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (2.2.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh) (2025.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from Jinja2>=2.9->bokeh) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from pandas>=1.2->bokeh) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from pandas>=1.2->bokeh) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.17.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
p = figure(plot_width=800)

xrange = range(len(traces_t[0]))
p.line(xrange, traces_t[0], line_color="red")
show(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 from bokeh.plotting import figure, show
#       2 from bokeh.io import output_notebook
# ----> 3 output_notebook()
#       4 p = figure(plot_width=800)
#       6 xrange = range(len(traces_t[0]))
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\output.py:124, in output_notebook(resources, verbose, hide_banner, load_timeout, notebook_type)
#     122 # verify notebook_type first in curstate().output_notebook
#     123 curstate().output_notebook(notebook_type)
# --> 124 run_notebook_hook(notebook_type, "load", resources, verbose, hide_banner, load_timeout)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:371, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     369 if server is None:
#     370     log.debug("No server instance found for uuid: %r" % server_id)
# --> 371     return
#     373 try:
#     374     for session in server.get_sessions():
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:487, in load_notebook(resources, verbose, hide_banner, load_timeout)
#     485 # This import MUST be deferred or it will introduce a hard dependency on IPython
#     486 from IPython.display import publish_display_data
# --> 487 publish_display_data(data, metadata, source, transient=transient, **kwargs)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\io\notebook.py:637, in _loading_js(bundle, element_id, load_timeout, register_mime)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\jinja2\environment.py:1295, in Template.render(self, *args, **kwargs)
#    1293     return self.environment.concat(self.root_render_func(ctx))  # type: ignore
#    1294 except Exception:
# -> 1295     self.environment.handle_exception()
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\jinja2\environment.py:942, in Environment.handle_exception(self, source)
#     937 """Exception handling helper.  This is used internally to either raise
#     938 rewritten exceptions or return a rendered traceback for the template.
#     939 """
#     940 from .debug import rewrite_traceback_stack
# --> 942 raise rewrite_traceback_stack(source=source)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\core\_templates\autoload_nb_js.js:1, in top-level template code()
# ----> 1 {% extends "autoload_js.js" %}
#       2
#       3 {% block register_mimetype %}
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\bokeh\core\_templates\autoload_js.js:113, in top-level template code()
#     111
#     112   {% if bundle %}
# --> 113   const js_urls = {{ bundle.js_urls|tojson }};
#     114   const css_urls = {{ bundle.css_urls|tojson }};
#     115   {% else %}
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\jinja2\filters.py:1721, in do_tojson(eval_ctx, value, indent)
#    1718     kwargs = kwargs.copy()
#    1719     kwargs["indent"] = indent
# -> 1721 return htmlsafe_json_dumps(value, dumps=dumps, **kwargs)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\jinja2\utils.py:669, in htmlsafe_json_dumps(obj, dumps, **kwargs)
#     665 if dumps is None:
#     666     dumps = json.dumps
#     668 return markupsafe.Markup(
# --> 669     dumps(obj, **kwargs)
#     670     .replace("<", "\\u003c")
#     671     .replace(">", "\\u003e")
#     672     .replace("&", "\\u0026")
#     673     .replace("'", "\\u0027")
#     674 )
#
# File ~\ChipWhisperer\winpy\python\Lib\json\__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File ~\ChipWhisperer\winpy\python\Lib\json\encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File ~\ChipWhisperer\winpy\python\Lib\json\encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# File ~\ChipWhisperer\winpy\python\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)    178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type URL is not JSON serializable

# %% [markdown]
# Finally we save our traces and disconnect. By saving the traces, the attack can be repeated in the future without having to repeat the trace acquisition steps above.

# %%
#project.save()
scope.dis()
target.dis()

# %%
# !pip install --upgrade bokeh==2.4.3
# Out:
# Collecting bokeh==2.4.3
#   Downloading bokeh-2.4.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (3.1.6)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (24.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (6.0.2)
# Requirement already satisfied: tornado>=5.1 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (6.4.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from bokeh==2.4.3) (4.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lab\chipwhisperer\cwenv\lib\site-packages (from Jinja2>=2.9->bokeh==2.4.3) (3.0.2)
# Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#    ---------------------------------------- 0.0/18.5 MB ? eta -:--:--
#    --------- ------------------------------ 4.2/18.5 MB 28.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 10.5/18.5 MB 28.5 MB/s eta 0:00:01
#    ---------------------------------------  18.4/18.5 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------- 18.5/18.5 MB 28.5 MB/s eta 0:00:00
# Installing collected packages: bokeh
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 3.6.3
#     Uninstalling bokeh-3.6.3:
#       Successfully uninstalled bokeh-3.6.3
# Successfully installed bokeh-2.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# holoviews 1.20.2 requires bokeh>=3.1, but you have bokeh 2.4.3 which is incompatible.
# panel 1.6.1 requires bokeh<3.7.0,>=3.5.0, but you have bokeh 2.4.3 which is incompatible.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
